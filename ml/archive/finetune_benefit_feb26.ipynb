# %%
import torch
from misc import normalize_loss
import json
import os
import torch.nn.functional as F
from models import AE, MultiClassClassifier, BinaryClassifier, VAE
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from semisupervised_train_feb25_2 import train_semisupervised, CompoundDataset#, evaluate_head_auc, evaluate_adversary_auc
from misc import get_dropbox_dir

from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# %%
def evaluate_head_auc(head_ouputs, head_targets, adversary_outputs, adversary_targets, head, adversary):
    if len(head_ouputs) == 0:
        return 0
    head_probs = head.logits_to_proba(head_ouputs.detach()).numpy()
    head_targets_np = head_targets.numpy()
    nan_mask = ~np.isnan(head_targets_np)
    # print(nan_mask)
    # print(head_targets_np)
    # print(head_probs[nan_mask])
    # print(head_targets_np[nan_mask])
    # nan_mask = ~torch.isnan(head_targets)
    if head.num_classes > 2:
        head_auc = roc_auc_score(head_targets_np[nan_mask], head_probs[nan_mask],
                                average='weighted', multi_class='ovo')
    else:
        head_auc = roc_auc_score(head_targets_np[nan_mask], head_probs[nan_mask],
                                average='weighted')
    return head_auc

def evaluate_adversary_auc(head_ouputs, head_targets, adversary_outputs, adversary_targets,head, adversary):
    if len(adversary_outputs) == 0:
        return 0
    adversary_probs = adversary.logits_to_proba(adversary_outputs.detach()).numpy()
    adversary_targets_np = adversary_targets.numpy()
    nan_mask = ~np.isnan(adversary_targets_np)

    if adversary.num_classes > 2:
        adversary_auc = roc_auc_score(adversary_targets_np[nan_mask], adversary_probs[nan_mask],
                                    average='weighted', multi_class='ovo')
    else:
        adversary_auc = roc_auc_score(adversary_targets_np[nan_mask], adversary_probs[nan_mask],
                                    average='weighted')
    return adversary_auc

end_state_eval_funcs = {
    # 'head_accuracy': evaluate_head_accuracy,
    # 'adversary_accuracy': evaluate_adversary_accuracy,
    'head_auc': evaluate_head_auc,
    'adversary_auc': evaluate_adversary_auc
}

# %%
dropbox_dir = get_dropbox_dir()
# data_dir = f'{dropbox_dir}/development_CohortCombination/benefit_study_feb20'
data_dir = f'{dropbox_dir}/development_CohortCombination/mskcc_prediction_study_feb19'
output_dir = os.path.join(data_dir,'finetune_adversarial_network_Feb25')
os.makedirs(output_dir, exist_ok=True)

pretrain_model_id = 'feb26_AE_4_with_head-0.2_and_adversary-5'
pretrain_load_dir = f'{dropbox_dir}/development_CohortCombination/reconstruction_study_feb16/adversarial_network_Feb25/{pretrain_model_id}_0'

# head_col = 'Benefit'
adv_col = 'Sex'
# head_col_mapper = {'CB': 1, 'NCB': 0, 'ICB': np.nan}
adv_col_mapper = {'M': 1, 'F': 0}

head_col = 'MSKCC'
head_col_mapper = {'FAVORABLE': 1, 'POOR': 0, 'INTERMEDIATE': np.nan}

batch_size = 64
num_epochs = 200
encoder_weight = 0
head_weight = 1
adversary_weight = 0
latent_dim = 26
hidden_size = 14
dropout_rate = 0
activation = 'tanh'
use_batch_norm = False
noise_factor = 0.05
learning_rate = 2.7224595522366062e-05
beta = 0
val_frac = 0

finetune_id = 2
model_id = pretrain_model_id + f'_finetune_{finetune_id}'

for subset_num in range(0,30):
    model_subdir = f'{model_id}_{subset_num}'
    model_dir = os.path.join(output_dir, model_subdir)
    os.makedirs(model_dir, exist_ok=True)

    X_train = pd.read_csv(os.path.join(data_dir, f'X_train_{subset_num}.csv'),index_col=0)
    y_train = pd.read_csv(os.path.join(data_dir, f'y_train_{subset_num}.csv'),index_col=0)
    X_test = pd.read_csv(os.path.join(data_dir, f'X_test_{subset_num}.csv'),index_col=0)
    y_test = pd.read_csv(os.path.join(data_dir, f'y_test_{subset_num}.csv'),index_col=0)

    # apply the mapper to the head and adv columns
    y_train[head_col] = y_train[head_col].map(head_col_mapper)
    y_train[adv_col] = y_train[adv_col].map(adv_col_mapper)
    y_test[head_col] = y_test[head_col].map(head_col_mapper)
    y_test[adv_col] = y_test[adv_col].map(adv_col_mapper)

    train_dataset = CompoundDataset(X_train, y_train[head_col], y_train[adv_col])

    num_classes_head = train_dataset.get_num_classes_head()
    num_classes_adv = train_dataset.get_num_classes_adv()

    weights_head = train_dataset.get_class_weights_head()
    weights_adv = train_dataset.get_class_weights_adv()

    # Split the training dataset into training and validation sets
    if val_frac>0:
        train_size = int((1-val_frac) * len(train_dataset))
        val_size = len(train_dataset) - train_size

        train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    test_dataset = CompoundDataset(X_test, y_test[head_col], y_test[adv_col])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


    # %%
    # create the models
    input_dim = X_train.shape[1]                                      
    # encoder = AE(input_size=input_dim, latent_size=latent_dim, hidden_size=32, num_hidden_layers=1, 
    #                 dropout_rate=0.2,use_batch_norm=True,act_on_latent_layer=True, activation='tanh')

    encoder = AE(input_size=input_dim, latent_size=latent_dim, hidden_size=hidden_size, num_hidden_layers=1, 
                    dropout_rate=dropout_rate,use_batch_norm=use_batch_norm,act_on_latent_layer=True, activation=activation)

    encoder.load_state_dict(torch.load(os.path.join(pretrain_load_dir, 'encoder.pth')))

    if num_classes_head > 2:
        head = MultiClassClassifier(latent_dim, hidden_size=4, num_hidden_layers=0, num_classes=num_classes_head)
    else:
        head = BinaryClassifier(latent_dim, hidden_size=4, num_hidden_layers=0)

    if num_classes_adv > 2:
        adversary = MultiClassClassifier(latent_dim, hidden_size=4, num_hidden_layers=1, num_classes=num_classes_adv)
    else:
        adversary = BinaryClassifier(latent_dim, hidden_size=4, num_hidden_layers=1)

    head_info = {'class_weight': weights_head, 'num_classes': num_classes_head}
    adversary_info = {'class_weight': weights_adv, 'num_classes': num_classes_adv}

    head.define_loss(class_weight=weights_head)
    adversary.define_loss(class_weight=weights_adv)


    # %%
    dataloader_dct = {'train': train_loader, 'test': test_loader}
    if val_frac>0:
        dataloader_dct['val'] = val_loader



    # %%

    # TODO: allow adversary to have extra training
    # TODO: retrain adversary on fixed latent space at the end of training
    # TODO: allow for multiple heads and multiple adversaries   
    # TODO define loss-weights in the model object
    # TODO ordinal category loss and head
    # TODO: Update the TGEM model to be a encoder-style model class "TGEM_Encoder"
    # TODO: add a "task" (binary, regression, multi, etc) to the model class
    # TODO: add a "goal" (reduce, adversarial, primary) (method: define_goal)

    encoder, head, adversary, output_data = train_semisupervised(dataloader_dct,encoder,head,adversary,
                        save_dir=model_dir,
                        num_epochs=num_epochs,
                        learning_rate=learning_rate,
                        noise_factor= noise_factor,
                        encoder_weight=encoder_weight,
                        head_weight=head_weight,
                        beta= beta,
                        adversary_weight=adversary_weight,
                        end_state_eval_funcs=end_state_eval_funcs)
# Out:
# Epoch [1/200], train Loss: 0.9982
# train head_auc 0.664381454625357
# Epoch [11/200], train Loss: 0.9239
# train head_auc 0.8888156449132059
# Epoch [21/200], train Loss: 0.8620
# train head_auc 0.9158866183256427
# Epoch [31/200], train Loss: 0.8423
# train head_auc 0.9341683146561196
# Epoch [41/200], train Loss: 0.8020
# train head_auc 0.9483629971434849
# Epoch [51/200], train Loss: 0.7795
# train head_auc 0.9601406284333114
# Epoch [61/200], train Loss: 0.7433
# train head_auc 0.9696330476818282
# Epoch [71/200], train Loss: 0.7093
# train head_auc 0.9758294880246099
# Epoch [81/200], train Loss: 0.6811
# train head_auc 0.9813667325862447
# Epoch [91/200], train Loss: 0.6445
# train head_auc 0.9852340145023072
# Epoch [101/200], train Loss: 0.6286
# train head_auc 0.987695012085256
# Epoch [111/200], train Loss: 0.5933
# train head_auc 0.9897165458141067
# Epoch [121/200], train Loss: 0.5524
# train head_auc 0.9912546693034499
# Epoch [131/200], train Loss: 0.5146
# train head_auc 0.9924851680949243
# Epoch [141/200], train Loss: 0.4939
# train head_auc 0.9942430235113161
# Epoch [151/200], train Loss: 0.4607
# train head_auc 0.9945506482091848
# Epoch [161/200], train Loss: 0.4400
# train head_auc 0.9951219512195121
# Epoch [171/200], train Loss: 0.4024
# train head_auc 0.995385629531971
# Epoch [181/200], train Loss: 0.3786
# train head_auc 0.995385629531971
# Epoch [191/200], train Loss: 0.3703
# train head_auc 0.99560536145902
# KMM Adversary AUC: 0.4182
# Random Forest Adversary AUC: 0.4723
# End state train Losses: {'reconstruction': 3.0924737453460693, 'head': 0.07061974704265594, 'adversary': 0.35757166147232056}
# train head_auc 0.9955
# train adversary_auc 0.4815
# End state test Losses: {'reconstruction': 2.9663281440734863, 'head': 0.28494149446487427, 'adversary': 0.35917776823043823}
# test head_auc 0.9080
# test adversary_auc 0.4921
# Epoch [1/200], train Loss: 0.9917
# train head_auc 0.7465592334494774
# Epoch [11/200], train Loss: 0.9170
# train head_auc 0.885191637630662
# Epoch [21/200], train Loss: 0.8742
# train head_auc 0.9143728222996516
# Epoch [31/200], train Loss: 0.8581
# train head_auc 0.9339721254355401
# Epoch [41/200], train Loss: 0.8333
# train head_auc 0.9476480836236933
# Epoch [51/200], train Loss: 0.8085
# train head_auc 0.9569250871080139
# Epoch [61/200], train Loss: 0.7817
# train head_auc 0.9645470383275262
# Epoch [71/200], train Loss: 0.7426
# train head_auc 0.9712979094076655
# Epoch [81/200], train Loss: 0.7306
# train head_auc 0.9770034843205575
# Epoch [91/200], train Loss: 0.6948
# train head_auc 0.9800087108013937
# Epoch [101/200], train Loss: 0.6809
# train head_auc 0.983493031358885
# Epoch [111/200], train Loss: 0.6575
# train head_auc 0.985801393728223
# Epoch [121/200], train Loss: 0.6328
# train head_auc 0.9881968641114982
# Epoch [131/200], train Loss: 0.6295
# train head_auc 0.9892421602787456
# Epoch [141/200], train Loss: 0.5761
# train head_auc 0.9912020905923344
# Epoch [151/200], train Loss: 0.5652
# train head_auc 0.9923344947735191
# Epoch [161/200], train Loss: 0.5309
# train head_auc 0.9936411149825783
# Epoch [171/200], train Loss: 0.5069
# train head_auc 0.9944686411149825
# Epoch [181/200], train Loss: 0.4796
# train head_auc 0.9950348432055749
# Epoch [191/200], train Loss: 0.4706
# train head_auc 0.9956445993031359
# KMM Adversary AUC: 0.4698
# Random Forest Adversary AUC: 0.4553
# End state train Losses: {'reconstruction': 2.067312479019165, 'head': 0.09834618121385574, 'adversary': 0.33686918020248413}
# train head_auc 0.9960
# train adversary_auc 0.5109
# End state test Losses: {'reconstruction': 1.9851049184799194, 'head': 0.33748236298561096, 'adversary': 0.36827585101127625}
# test head_auc 0.8782
# test adversary_auc 0.4879
# Epoch [1/200], train Loss: 1.0118
# train head_auc 0.5924516749759469
# Epoch [11/200], train Loss: 0.9509
# train head_auc 0.8598355637190589
# Epoch [21/200], train Loss: 0.8989
# train head_auc 0.8965713286101635
# Epoch [31/200], train Loss: 0.8738
# train head_auc 0.9185690544913846
# Epoch [41/200], train Loss: 0.8305
# train head_auc 0.9346628181579637
# Epoch [51/200], train Loss: 0.8254
# train head_auc 0.9471704714423161
# Epoch [61/200], train Loss: 0.8263
# train head_auc 0.9567042770926265
# Epoch [71/200], train Loss: 0.7334
# train head_auc 0.9644887606052654
# Epoch [81/200], train Loss: 0.7284
# train head_auc 0.9706988541939999
# Epoch [91/200], train Loss: 0.7030
# train head_auc 0.9759468206070148
# Epoch [101/200], train Loss: 0.6733
# train head_auc 0.9804950581649611
# Epoch [111/200], train Loss: 0.6317
# train head_auc 0.9842123677075133
# Epoch [121/200], train Loss: 0.5820
# train head_auc 0.9875360797690895
# Epoch [131/200], train Loss: 0.5509
# train head_auc 0.9897664654946208
# Epoch [141/200], train Loss: 0.5186
# train head_auc 0.992040584273594
# Epoch [151/200], train Loss: 0.5244
# train head_auc 0.9931776436630806
# Epoch [161/200], train Loss: 0.4883
# train head_auc 0.9940960377853582
# Epoch [171/200], train Loss: 0.4682
# train head_auc 0.9950581649610776
# Epoch [181/200], train Loss: 0.4489
# train head_auc 0.9954517624420538
# Epoch [191/200], train Loss: 0.4101
# train head_auc 0.9961077582436806
# KMM Adversary AUC: 0.5893
# Random Forest Adversary AUC: 0.5733
# End state train Losses: {'reconstruction': 1.7080918550491333, 'head': 0.08970528841018677, 'adversary': 0.3622678518295288}
# train head_auc 0.9966
# train adversary_auc 0.5360
# End state test Losses: {'reconstruction': 1.6885319948196411, 'head': 0.31285786628723145, 'adversary': 0.35748085379600525}
# test head_auc 0.8754
# test adversary_auc 0.4511
# Epoch [1/200], train Loss: 0.9936
# train head_auc 0.5239219802326598
# Epoch [11/200], train Loss: 0.8907
# train head_auc 0.8592670340243156
# Epoch [21/200], train Loss: 0.8804
# train head_auc 0.9008134347940173
# Epoch [31/200], train Loss: 0.8499
# train head_auc 0.9202309105221727
# Epoch [41/200], train Loss: 0.8233
# train head_auc 0.9350126825854982
# Epoch [51/200], train Loss: 0.7937
# train head_auc 0.9463832764803639
# Epoch [61/200], train Loss: 0.7884
# train head_auc 0.9565293448788595
# Epoch [71/200], train Loss: 0.7421
# train head_auc 0.9644012944983819
# Epoch [81/200], train Loss: 0.7352
# train head_auc 0.9704364558733491
# Epoch [91/200], train Loss: 0.6950
# train head_auc 0.9764716172483162
# Epoch [101/200], train Loss: 0.6692
# train head_auc 0.9807574564856119
# Epoch [111/200], train Loss: 0.6234
# train head_auc 0.9850870287763492
# Epoch [121/200], train Loss: 0.6202
# train head_auc 0.9882795416775999
# Epoch [131/200], train Loss: 0.5790
# train head_auc 0.990772325723782
# Epoch [141/200], train Loss: 0.5704
# train head_auc 0.992871512288988
# Epoch [151/200], train Loss: 0.5295
# train head_auc 0.9944021691594508
# Epoch [161/200], train Loss: 0.4881
# train head_auc 0.9952330971748448
# Epoch [171/200], train Loss: 0.4903
# train head_auc 0.9956704277092627
# Epoch [181/200], train Loss: 0.4446
# train head_auc 0.9963264235108895
# Epoch [191/200], train Loss: 0.4188
# train head_auc 0.9966762879384239
# KMM Adversary AUC: 0.5807
# Random Forest Adversary AUC: 0.6110
# End state train Losses: {'reconstruction': 1.4690090417861938, 'head': 0.08980832248926163, 'adversary': 0.3642638325691223}
# train head_auc 0.9969
# train adversary_auc 0.4453
# End state test Losses: {'reconstruction': 1.384854793548584, 'head': 0.2215368151664734, 'adversary': 0.35686609148979187}
# test head_auc 0.9559
# test adversary_auc 0.4994
# Epoch [1/200], train Loss: 0.9918
# train head_auc 0.4541240269395609
# Epoch [11/200], train Loss: 0.9247
# train head_auc 0.8573427796728768
# Epoch [21/200], train Loss: 0.8790
# train head_auc 0.9050118079244293
# Epoch [31/200], train Loss: 0.8551
# train head_auc 0.9258287413627221
# Epoch [41/200], train Loss: 0.8289
# train head_auc 0.9407417125863727
# Epoch [51/200], train Loss: 0.7827
# train head_auc 0.9531181667103998
# Epoch [61/200], train Loss: 0.7687
# train head_auc 0.9606839849558295
# Epoch [71/200], train Loss: 0.7191
# train head_auc 0.968555934575352
# Epoch [81/200], train Loss: 0.6962
# train head_auc 0.97485349427097
# Epoch [91/200], train Loss: 0.6623
# train head_auc 0.979226799615149
# Epoch [101/200], train Loss: 0.6517
# train head_auc 0.9825067786232834
# Epoch [111/200], train Loss: 0.6317
# train head_auc 0.9860491559520685
# Epoch [121/200], train Loss: 0.5874
# train head_auc 0.9881920755707164
# Epoch [131/200], train Loss: 0.5416
# train head_auc 0.9899413977083881
# Epoch [141/200], train Loss: 0.5177
# train head_auc 0.9909472579375492
# Epoch [151/200], train Loss: 0.5013
# train head_auc 0.9920843173270358
# Epoch [161/200], train Loss: 0.4580
# train head_auc 0.9926091139683374
# Epoch [171/200], train Loss: 0.4496
# train head_auc 0.9933525758768477
# Epoch [181/200], train Loss: 0.4528
# train head_auc 0.9938773725181492
# Epoch [191/200], train Loss: 0.4052
# train head_auc 0.9946208344266596
# KMM Adversary AUC: 0.5034
# Random Forest Adversary AUC: 0.5269
# End state train Losses: {'reconstruction': 1.6051552295684814, 'head': 0.08769101649522781, 'adversary': 0.3846214711666107}
# train head_auc 0.9953
# train adversary_auc 0.5875
# End state test Losses: {'reconstruction': 1.5860004425048828, 'head': 0.33042845129966736, 'adversary': 0.3768446147441864}
# test head_auc 0.8782
# test adversary_auc 0.5638
# Epoch [1/200], train Loss: 0.9948
# train head_auc 0.7006811689738519
# Epoch [11/200], train Loss: 0.9238
# train head_auc 0.8907492858712371
# Epoch [21/200], train Loss: 0.8915
# train head_auc 0.9173368490441661
# Epoch [31/200], train Loss: 0.8927
# train head_auc 0.9331575477916941
# Epoch [41/200], train Loss: 0.8156
# train head_auc 0.9471324983520105
# Epoch [51/200], train Loss: 0.7956
# train head_auc 0.9567567567567568
# Epoch [61/200], train Loss: 0.7606
# train head_auc 0.9668644254010108
# Epoch [71/200], train Loss: 0.7403
# train head_auc 0.9740716326082179
# Epoch [81/200], train Loss: 0.7072
# train head_auc 0.9795209843990331
# Epoch [91/200], train Loss: 0.6827
# train head_auc 0.9836519446275545
# Epoch [101/200], train Loss: 0.6582
# train head_auc 0.9891452428037794
# Epoch [111/200], train Loss: 0.6415
# train head_auc 0.9919138650845968
# Epoch [121/200], train Loss: 0.6280
# train head_auc 0.9939793451988573
# Epoch [131/200], train Loss: 0.5387
# train head_auc 0.9962206108547571
# Epoch [141/200], train Loss: 0.5289
# train head_auc 0.997363216875412
# Epoch [151/200], train Loss: 0.5014
# train head_auc 0.998461876510657
# Epoch [161/200], train Loss: 0.4755
# train head_auc 0.9989452867501647
# Epoch [171/200], train Loss: 0.4448
# train head_auc 0.9991650186772137
# Epoch [181/200], train Loss: 0.4269
# train head_auc 0.9996044825313117
# Epoch [191/200], train Loss: 0.4263
# train head_auc 0.9997363216875412
# KMM Adversary AUC: 0.5034
# Random Forest Adversary AUC: 0.5429
# End state train Losses: {'reconstruction': 1.25254487991333, 'head': 0.07710494101047516, 'adversary': 0.38871321082115173}
# train head_auc 0.9998
# train adversary_auc 0.5344
# End state test Losses: {'reconstruction': 1.1781120300292969, 'head': 0.3128149211406708, 'adversary': 0.34652045369148254}
# test head_auc 0.8984
# test adversary_auc 0.4823
# Epoch [1/200], train Loss: 1.0033
# train head_auc 0.47961672473867595
# Epoch [11/200], train Loss: 0.9085
# train head_auc 0.8710365853658537
# Epoch [21/200], train Loss: 0.8715
# train head_auc 0.9030487804878049
# Epoch [31/200], train Loss: 0.8330
# train head_auc 0.9222996515679441
# Epoch [41/200], train Loss: 0.8088
# train head_auc 0.938109756097561
# Epoch [51/200], train Loss: 0.8248
# train head_auc 0.9517857142857143
# Epoch [61/200], train Loss: 0.7529
# train head_auc 0.9620644599303135
# Epoch [71/200], train Loss: 0.7492
# train head_auc 0.9697735191637631
# Epoch [81/200], train Loss: 0.6979
# train head_auc 0.9755226480836238
# Epoch [91/200], train Loss: 0.6637
# train head_auc 0.9805313588850174
# Epoch [101/200], train Loss: 0.6608
# train head_auc 0.984102787456446
# Epoch [111/200], train Loss: 0.6102
# train head_auc 0.9873257839721254
# Epoch [121/200], train Loss: 0.5968
# train head_auc 0.9901132404181184
# Epoch [131/200], train Loss: 0.5769
# train head_auc 0.9920296167247387
# Epoch [141/200], train Loss: 0.5290
# train head_auc 0.9934668989547039
# Epoch [151/200], train Loss: 0.5200
# train head_auc 0.994425087108014
# Epoch [161/200], train Loss: 0.4780
# train head_auc 0.9952526132404181
# Epoch [171/200], train Loss: 0.4497
# train head_auc 0.9958188153310104
# Epoch [181/200], train Loss: 0.4229
# train head_auc 0.9962979094076654
# Epoch [191/200], train Loss: 0.4067
# train head_auc 0.9967334494773519
# KMM Adversary AUC: 0.5105
# Random Forest Adversary AUC: 0.5948
# End state train Losses: {'reconstruction': 5.261878490447998, 'head': 0.08398124575614929, 'adversary': 0.33425551652908325}
# train head_auc 0.9970
# train adversary_auc 0.4773
# End state test Losses: {'reconstruction': 5.090455055236816, 'head': 0.27367937564849854, 'adversary': 0.4084354043006897}
# test head_auc 0.9145
# test adversary_auc 0.5486
# Epoch [1/200], train Loss: 0.9904
# train head_auc 0.7828216566080645
# Epoch [11/200], train Loss: 0.9264
# train head_auc 0.8819207557071636
# Epoch [21/200], train Loss: 0.9022
# train head_auc 0.9125338931164174
# Epoch [31/200], train Loss: 0.8701
# train head_auc 0.9319513688445729
# Epoch [41/200], train Loss: 0.8318
# train head_auc 0.9472142044957579
# Epoch [51/200], train Loss: 0.8160
# train head_auc 0.9587597306043909
# Epoch [61/200], train Loss: 0.7597
# train head_auc 0.9666754132773551
# Epoch [71/200], train Loss: 0.7227
# train head_auc 0.9730604390798566
# Epoch [81/200], train Loss: 0.7051
# train head_auc 0.9772150791568268
# Epoch [91/200], train Loss: 0.6660
# train head_auc 0.9808449225924953
# Epoch [101/200], train Loss: 0.6496
# train head_auc 0.9825505116767252
# Epoch [111/200], train Loss: 0.6063
# train head_auc 0.985743024577976
# Epoch [121/200], train Loss: 0.5706
# train head_auc 0.9874923467156477
# Epoch [131/200], train Loss: 0.5314
# train head_auc 0.9896789993877373
# Epoch [141/200], train Loss: 0.5159
# train head_auc 0.9904224612962478
# Epoch [151/200], train Loss: 0.4885
# train head_auc 0.990990990990991
# Epoch [161/200], train Loss: 0.4544
# train head_auc 0.9916469867926179
# Epoch [171/200], train Loss: 0.4891
# train head_auc 0.9923467156476866
# Epoch [181/200], train Loss: 0.4339
# train head_auc 0.992477914808012
# Epoch [191/200], train Loss: 0.3963
# train head_auc 0.9932213767165223
# KMM Adversary AUC: 0.4777
# Random Forest Adversary AUC: 0.5070
# End state train Losses: {'reconstruction': 1.2597600221633911, 'head': 0.08092048764228821, 'adversary': 0.38049978017807007}
# train head_auc 0.9935
# train adversary_auc 0.4657
# End state test Losses: {'reconstruction': 1.2284839153289795, 'head': 0.3462376594543457, 'adversary': 0.34954833984375}
# test head_auc 0.8571
# test adversary_auc 0.5317
# Epoch [1/200], train Loss: 0.9993
# train head_auc 0.5992302982594244
# Epoch [11/200], train Loss: 0.9362
# train head_auc 0.8748797341030351
# Epoch [21/200], train Loss: 0.8953
# train head_auc 0.9064549986880085
# Epoch [31/200], train Loss: 0.8600
# train head_auc 0.9263972710574652
# Epoch [41/200], train Loss: 0.8434
# train head_auc 0.9392985218227937
# Epoch [51/200], train Loss: 0.8190
# train head_auc 0.9490947257937549
# Epoch [61/200], train Loss: 0.7830
# train head_auc 0.9573165398408117
# Epoch [71/200], train Loss: 0.7645
# train head_auc 0.963526633429546
# Epoch [81/200], train Loss: 0.7379
# train head_auc 0.9685996676287938
# Epoch [91/200], train Loss: 0.6874
# train head_auc 0.972360710224788
# Epoch [101/200], train Loss: 0.6848
# train head_auc 0.9761654858742239
# Epoch [111/200], train Loss: 0.6646
# train head_auc 0.9798390623633342
# Epoch [121/200], train Loss: 0.6504
# train head_auc 0.9825505116767252
# Epoch [131/200], train Loss: 0.6244
# train head_auc 0.9854368932038834
# Epoch [141/200], train Loss: 0.5749
# train head_auc 0.9878422111431819
# Epoch [151/200], train Loss: 0.5561
# train head_auc 0.9898101985480626
# Epoch [161/200], train Loss: 0.5541
# train head_auc 0.9917344528995016
# Epoch [171/200], train Loss: 0.5048
# train head_auc 0.993308842823406
# Epoch [181/200], train Loss: 0.4716
# train head_auc 0.9946208344266597
# Epoch [191/200], train Loss: 0.4592
# train head_auc 0.9958453599230298
# KMM Adversary AUC: 0.5395
# Random Forest Adversary AUC: 0.5914
# End state train Losses: {'reconstruction': 1.5749924182891846, 'head': 0.10147826373577118, 'adversary': 0.34290826320648193}
# train head_auc 0.9964
# train adversary_auc 0.4538
# End state test Losses: {'reconstruction': 1.5691982507705688, 'head': 0.27466651797294617, 'adversary': 0.3945034146308899}
# test head_auc 0.9146
# test adversary_auc 0.3918
# Epoch [1/200], train Loss: 0.9883
# train head_auc 0.7278492084317327
# Epoch [11/200], train Loss: 0.9269
# train head_auc 0.8794279716609814
# Epoch [21/200], train Loss: 0.8811
# train head_auc 0.9176943934225488
# Epoch [31/200], train Loss: 0.8768
# train head_auc 0.9357561444940086
# Epoch [41/200], train Loss: 0.8345
# train head_auc 0.9496195224350564
# Epoch [51/200], train Loss: 0.7763
# train head_auc 0.9602903874748535
# Epoch [61/200], train Loss: 0.7549
# train head_auc 0.966675413277355
# Epoch [71/200], train Loss: 0.7208
# train head_auc 0.973366570453949
# Epoch [81/200], train Loss: 0.7573
# train head_auc 0.9780897402256626
# Epoch [91/200], train Loss: 0.6680
# train head_auc 0.9821131811423073
# Epoch [101/200], train Loss: 0.6201
# train head_auc 0.9849558296160238
# Epoch [111/200], train Loss: 0.6084
# train head_auc 0.9871862153415552
# Epoch [121/200], train Loss: 0.5688
# train head_auc 0.9896789993877373
# Epoch [131/200], train Loss: 0.5513
# train head_auc 0.9909035248841074
# Epoch [141/200], train Loss: 0.5233
# train head_auc 0.9926091139683372
# Epoch [151/200], train Loss: 0.5047
# train head_auc 0.9938773725181493
# Epoch [161/200], train Loss: 0.4635
# train head_auc 0.9944459022128925
# Epoch [171/200], train Loss: 0.4814
# train head_auc 0.9950581649610777
# Epoch [181/200], train Loss: 0.4108
# train head_auc 0.9960640251902388
# Epoch [191/200], train Loss: 0.4013
# train head_auc 0.9966762879384239
# KMM Adversary AUC: 0.4934
# Random Forest Adversary AUC: 0.5036
# End state train Losses: {'reconstruction': 3.7263190746307373, 'head': 0.0775088295340538, 'adversary': 0.3702804148197174}
# train head_auc 0.9971
# train adversary_auc 0.4297
# End state test Losses: {'reconstruction': 3.3970069885253906, 'head': 0.2937881350517273, 'adversary': 0.35738202929496765}
# test head_auc 0.9118
# test adversary_auc 0.4714
# Epoch [1/200], train Loss: 1.0132
# train head_auc 0.7148319050758075
# Epoch [11/200], train Loss: 0.9163
# train head_auc 0.8818721160184575
# Epoch [21/200], train Loss: 0.8691
# train head_auc 0.9132937815864646
# Epoch [31/200], train Loss: 0.8539
# train head_auc 0.9339485827290704
# Epoch [41/200], train Loss: 0.8282
# train head_auc 0.9489782465392221
# Epoch [51/200], train Loss: 0.7514
# train head_auc 0.9596132718083938
# Epoch [61/200], train Loss: 0.7438
# train head_auc 0.967479674796748
# Epoch [71/200], train Loss: 0.7035
# train head_auc 0.9733245440562512
# Epoch [81/200], train Loss: 0.6855
# train head_auc 0.9788178422324764
# Epoch [91/200], train Loss: 0.6456
# train head_auc 0.9821138211382114
# Epoch [101/200], train Loss: 0.6123
# train head_auc 0.9853219072731267
# Epoch [111/200], train Loss: 0.5859
# train head_auc 0.9878268512414853
# Epoch [121/200], train Loss: 0.5780
# train head_auc 0.9906394199077125
# Epoch [131/200], train Loss: 0.5172
# train head_auc 0.9924851680949242
# Epoch [141/200], train Loss: 0.4944
# train head_auc 0.9941551307404966
# Epoch [151/200], train Loss: 0.4648
# train head_auc 0.9951219512195122
# Epoch [161/200], train Loss: 0.4394
# train head_auc 0.9959129861568886
# Epoch [171/200], train Loss: 0.4290
# train head_auc 0.9962645572401669
# Epoch [181/200], train Loss: 0.4251
# train head_auc 0.9965282355526258
# Epoch [191/200], train Loss: 0.3712
# train head_auc 0.9966600747088552
# KMM Adversary AUC: 0.4032
# Random Forest Adversary AUC: 0.3975
# End state train Losses: {'reconstruction': 2.6675689220428467, 'head': 0.06865545362234116, 'adversary': 0.35277464985847473}
# train head_auc 0.9971
# train adversary_auc 0.5511
# End state test Losses: {'reconstruction': 2.5654895305633545, 'head': 0.36331310868263245, 'adversary': 0.3598475456237793}
# test head_auc 0.8709
# test adversary_auc 0.4587
# Epoch [1/200], train Loss: 0.9870
# train head_auc 0.48344947735191635
# Epoch [11/200], train Loss: 0.9162
# train head_auc 0.8683797909407664
# Epoch [21/200], train Loss: 0.8645
# train head_auc 0.9026567944250872
# Epoch [31/200], train Loss: 0.8458
# train head_auc 0.9200348432055748
# Epoch [41/200], train Loss: 0.8513
# train head_auc 0.9358013937282229
# Epoch [51/200], train Loss: 0.8232
# train head_auc 0.9475609756097562
# Epoch [61/200], train Loss: 0.7748
# train head_auc 0.9576219512195122
# Epoch [71/200], train Loss: 0.7663
# train head_auc 0.9652439024390244
# Epoch [81/200], train Loss: 0.7190
# train head_auc 0.9714285714285714
# Epoch [91/200], train Loss: 0.7047
# train head_auc 0.9758275261324041
# Epoch [101/200], train Loss: 0.6563
# train head_auc 0.9800087108013937
# Epoch [111/200], train Loss: 0.6372
# train head_auc 0.9837543554006969
# Epoch [121/200], train Loss: 0.5862
# train head_auc 0.9865418118466899
# Epoch [131/200], train Loss: 0.5845
# train head_auc 0.9880662020905923
# Epoch [141/200], train Loss: 0.5521
# train head_auc 0.9902439024390245
# Epoch [151/200], train Loss: 0.5538
# train head_auc 0.9912891986062717
# Epoch [161/200], train Loss: 0.4871
# train head_auc 0.9924216027874565
# Epoch [171/200], train Loss: 0.4770
# train head_auc 0.9931184668989547
# Epoch [181/200], train Loss: 0.4533
# train head_auc 0.9943379790940767
# Epoch [191/200], train Loss: 0.4283
# train head_auc 0.9950348432055749
# KMM Adversary AUC: 0.4625
# Random Forest Adversary AUC: 0.5949
# End state train Losses: {'reconstruction': 1.5189486742019653, 'head': 0.0914282575249672, 'adversary': 0.34870216250419617}
# train head_auc 0.9953
# train adversary_auc 0.5562
# End state test Losses: {'reconstruction': 1.5532441139221191, 'head': 0.2214634120464325, 'adversary': 0.3620903789997101}
# test head_auc 0.9452
# test adversary_auc 0.5147
# Epoch [1/200], train Loss: 1.0000
# train head_auc 0.5294323449663256
# Epoch [11/200], train Loss: 0.9158
# train head_auc 0.8695880346365783
# Epoch [21/200], train Loss: 0.8912
# train head_auc 0.9062800664742412
# Epoch [31/200], train Loss: 0.8536
# train head_auc 0.92749059739351
# Epoch [41/200], train Loss: 0.8224
# train head_auc 0.94384675938074
# Epoch [51/200], train Loss: 0.8123
# train head_auc 0.956441878771976
# Epoch [61/200], train Loss: 0.7433
# train head_auc 0.9657132861016356
# Epoch [71/200], train Loss: 0.7471
# train head_auc 0.9734103035073909
# Epoch [81/200], train Loss: 0.7305
# train head_auc 0.9784833377066386
# Epoch [91/200], train Loss: 0.6629
# train head_auc 0.9836438380127701
# Epoch [101/200], train Loss: 0.6705
# train head_auc 0.987011283127788
# Epoch [111/200], train Loss: 0.6327
# train head_auc 0.990990990990991
# Epoch [121/200], train Loss: 0.5844
# train head_auc 0.9933525758768478
# Epoch [131/200], train Loss: 0.5635
# train head_auc 0.9950581649610777
# Epoch [141/200], train Loss: 0.5260
# train head_auc 0.996851220152191
# Epoch [151/200], train Loss: 0.5048
# train head_auc 0.9979445464882358
# Epoch [161/200], train Loss: 0.4672
# train head_auc 0.998731741450188
# Epoch [171/200], train Loss: 0.4521
# train head_auc 0.9992128050380478
# Epoch [181/200], train Loss: 0.4195
# train head_auc 0.9994752033586985
# Epoch [191/200], train Loss: 0.3977
# train head_auc 0.999562669465582
# KMM Adversary AUC: 0.4704
# Random Forest Adversary AUC: 0.5759
# End state train Losses: {'reconstruction': 1.4930486679077148, 'head': 0.08160538971424103, 'adversary': 0.3395482301712036}
# train head_auc 0.9998
# train adversary_auc 0.4796
# End state test Losses: {'reconstruction': 1.4364508390426636, 'head': 0.3648676872253418, 'adversary': 0.3724597096443176}
# test head_auc 0.8564
# test adversary_auc 0.4265
# Epoch [1/200], train Loss: 0.9840
# train head_auc 0.6852532143794279
# Epoch [11/200], train Loss: 0.9201
# train head_auc 0.8802151666229336
# Epoch [21/200], train Loss: 0.8925
# train head_auc 0.9087291174669816
# Epoch [31/200], train Loss: 0.8342
# train head_auc 0.9299396483862503
# Epoch [41/200], train Loss: 0.7986
# train head_auc 0.9456398145718535
# Epoch [51/200], train Loss: 0.8182
# train head_auc 0.9554797515962564
# Epoch [61/200], train Loss: 0.7520
# train head_auc 0.964794891979358
# Epoch [71/200], train Loss: 0.7226
# train head_auc 0.9715297822093939
# Epoch [81/200], train Loss: 0.6828
# train head_auc 0.9780460071722208
# Epoch [91/200], train Loss: 0.6455
# train head_auc 0.9818945158750984
# Epoch [101/200], train Loss: 0.6228
# train head_auc 0.9853494270969999
# Epoch [111/200], train Loss: 0.6237
# train head_auc 0.9873611475553223
# Epoch [121/200], train Loss: 0.5915
# train head_auc 0.9892416688533193
# Epoch [131/200], train Loss: 0.5366
# train head_auc 0.9912971223650835
# Epoch [141/200], train Loss: 0.5022
# train head_auc 0.992871512288988
# Epoch [151/200], train Loss: 0.5349
# train head_auc 0.9939648386250328
# Epoch [161/200], train Loss: 0.4465
# train head_auc 0.9951018980145193
# Epoch [171/200], train Loss: 0.4135
# train head_auc 0.9957141607627045
# Epoch [181/200], train Loss: 0.3926
# train head_auc 0.9962826904574478
# Epoch [191/200], train Loss: 0.3770
# train head_auc 0.9966325548849821
# KMM Adversary AUC: 0.5293
# Random Forest Adversary AUC: 0.5195
# End state train Losses: {'reconstruction': 1.3569140434265137, 'head': 0.07298741489648819, 'adversary': 0.3637447655200958}
# train head_auc 0.9970
# train adversary_auc 0.5399
# End state test Losses: {'reconstruction': 1.2614980936050415, 'head': 0.2963784337043762, 'adversary': 0.3526232838630676}
# test head_auc 0.9013
# test adversary_auc 0.5052
# Epoch [1/200], train Loss: 0.9858
# train head_auc 0.3805212979970261
# Epoch [11/200], train Loss: 0.9414
# train head_auc 0.82397445989679
# Epoch [21/200], train Loss: 0.9098
# train head_auc 0.8917606927315666
# Epoch [31/200], train Loss: 0.8565
# train head_auc 0.9165573340330622
# Epoch [41/200], train Loss: 0.8504
# train head_auc 0.9321263010583399
# Epoch [51/200], train Loss: 0.7983
# train head_auc 0.9425347677774862
# Epoch [61/200], train Loss: 0.7943
# train head_auc 0.9524621709087727
# Epoch [71/200], train Loss: 0.8284
# train head_auc 0.9596781247266685
# Epoch [81/200], train Loss: 0.7197
# train head_auc 0.9657570191550774
# Epoch [91/200], train Loss: 0.6791
# train head_auc 0.9716172483162774
# Epoch [101/200], train Loss: 0.6619
# train head_auc 0.9774774774774775
# Epoch [111/200], train Loss: 0.6578
# train head_auc 0.9810635878597044
# Epoch [121/200], train Loss: 0.6156
# train head_auc 0.9846934312953731
# Epoch [131/200], train Loss: 0.5901
# train head_auc 0.9860054228986268
# Epoch [141/200], train Loss: 0.5661
# train head_auc 0.9879734103035074
# Epoch [151/200], train Loss: 0.5505
# train head_auc 0.9898539316015045
# Epoch [161/200], train Loss: 0.5175
# train head_auc 0.9916469867926179
# Epoch [171/200], train Loss: 0.4994
# train head_auc 0.9931339106096387
# Epoch [181/200], train Loss: 0.4804
# train head_auc 0.9939211055715911
# Epoch [191/200], train Loss: 0.4477
# train head_auc 0.9946645674801015
# KMM Adversary AUC: 0.4822
# Random Forest Adversary AUC: 0.5790
# End state train Losses: {'reconstruction': 3.6364526748657227, 'head': 0.10723396390676498, 'adversary': 0.37876248359680176}
# train head_auc 0.9952
# train adversary_auc 0.5048
# End state test Losses: {'reconstruction': 3.2603516578674316, 'head': 0.23163533210754395, 'adversary': 0.3484562933444977}
# test head_auc 0.9405
# test adversary_auc 0.4897
# Epoch [1/200], train Loss: 1.0295
# train head_auc 0.7018237749945067
# Epoch [11/200], train Loss: 0.8935
# train head_auc 0.9411997363216875
# Epoch [21/200], train Loss: 0.8464
# train head_auc 0.9552625796528236
# Epoch [31/200], train Loss: 0.8174
# train head_auc 0.9609316633706878
# Epoch [41/200], train Loss: 0.8072
# train head_auc 0.9674357284113381
# Epoch [51/200], train Loss: 0.7769
# train head_auc 0.972313777191826
# Epoch [61/200], train Loss: 0.7171
# train head_auc 0.9767963085036258
# Epoch [71/200], train Loss: 0.7058
# train head_auc 0.979784662711492
# Epoch [81/200], train Loss: 0.6681
# train head_auc 0.9829048560755878
# Epoch [91/200], train Loss: 0.6367
# train head_auc 0.9847066578773895
# Epoch [101/200], train Loss: 0.6446
# train head_auc 0.985937156668864
# Epoch [111/200], train Loss: 0.5517
# train head_auc 0.9877389584706658
# Epoch [121/200], train Loss: 0.5344
# train head_auc 0.988573939793452
# Epoch [131/200], train Loss: 0.5597
# train head_auc 0.9899362777411557
# Epoch [141/200], train Loss: 0.4902
# train head_auc 0.9899362777411558
# Epoch [151/200], train Loss: 0.4668
# train head_auc 0.9903317952098439
# Epoch [161/200], train Loss: 0.4417
# train head_auc 0.9906833662931224
# Epoch [171/200], train Loss: 0.4209
# train head_auc 0.9910788837618105
# Epoch [181/200], train Loss: 0.4220
# train head_auc 0.9916941331575478
# Epoch [191/200], train Loss: 0.4818
# train head_auc 0.991650186772138
# KMM Adversary AUC: 0.5226
# Random Forest Adversary AUC: 0.5969
# End state train Losses: {'reconstruction': 1.3299412727355957, 'head': 0.07079722732305527, 'adversary': 0.36691007018089294}
# train head_auc 0.9922
# train adversary_auc 0.4533
# End state test Losses: {'reconstruction': 1.3233195543289185, 'head': 0.46616533398628235, 'adversary': 0.356027215719223}
# test head_auc 0.7885
# test adversary_auc 0.3990
# Epoch [1/200], train Loss: 0.9951
# train head_auc 0.6012195121951219
# Epoch [11/200], train Loss: 0.9342
# train head_auc 0.8641114982578397
# Epoch [21/200], train Loss: 0.9124
# train head_auc 0.9034843205574914
# Epoch [31/200], train Loss: 0.8592
# train head_auc 0.9231271777003485
# Epoch [41/200], train Loss: 0.8330
# train head_auc 0.9388066202090591
# Epoch [51/200], train Loss: 0.7948
# train head_auc 0.9516986062717769
# Epoch [61/200], train Loss: 0.7737
# train head_auc 0.9622386759581881
# Epoch [71/200], train Loss: 0.7182
# train head_auc 0.96955574912892
# Epoch [81/200], train Loss: 0.7308
# train head_auc 0.975
# Epoch [91/200], train Loss: 0.6670
# train head_auc 0.9787891986062719
# Epoch [101/200], train Loss: 0.6414
# train head_auc 0.982186411149826
# Epoch [111/200], train Loss: 0.6124
# train head_auc 0.984581881533101
# Epoch [121/200], train Loss: 0.5676
# train head_auc 0.9868902439024391
# Epoch [131/200], train Loss: 0.5543
# train head_auc 0.9881968641114983
# Epoch [141/200], train Loss: 0.5402
# train head_auc 0.9898954703832752
# Epoch [151/200], train Loss: 0.5227
# train head_auc 0.990897212543554
# Epoch [161/200], train Loss: 0.5470
# train head_auc 0.9914198606271776
# Epoch [171/200], train Loss: 0.4761
# train head_auc 0.9918989547038327
# Epoch [181/200], train Loss: 0.4307
# train head_auc 0.9925522648083623
# Epoch [191/200], train Loss: 0.4025
# train head_auc 0.9928571428571429
# KMM Adversary AUC: 0.5626
# Random Forest Adversary AUC: 0.4662
# End state train Losses: {'reconstruction': 1.4877049922943115, 'head': 0.08715860545635223, 'adversary': 0.37261679768562317}
# train head_auc 0.9932
# train adversary_auc 0.5399
# End state test Losses: {'reconstruction': 1.3802751302719116, 'head': 0.33573660254478455, 'adversary': 0.3529444634914398}
# test head_auc 0.8761
# test adversary_auc 0.5522
# Epoch [1/200], train Loss: 0.9492
# train head_auc 0.7409691244642701
# Epoch [11/200], train Loss: 0.9184
# train head_auc 0.8812647599055367
# Epoch [21/200], train Loss: 0.8901
# train head_auc 0.9073733928102861
# Epoch [31/200], train Loss: 0.8833
# train head_auc 0.9288463220502056
# Epoch [41/200], train Loss: 0.8650
# train head_auc 0.9436280941135311
# Epoch [51/200], train Loss: 0.8540
# train head_auc 0.9530307006035162
# Epoch [61/200], train Loss: 0.7977
# train head_auc 0.9628706376279192
# Epoch [71/200], train Loss: 0.7906
# train head_auc 0.9690369981632116
# Epoch [81/200], train Loss: 0.7394
# train head_auc 0.9754220239657133
# Epoch [91/200], train Loss: 0.6909
# train head_auc 0.9806699903787283
# Epoch [101/200], train Loss: 0.6721
# train head_auc 0.9847808974022566
# Epoch [111/200], train Loss: 0.6392
# train head_auc 0.9877547450362985
# Epoch [121/200], train Loss: 0.6187
# train head_auc 0.9898539316015044
# Epoch [131/200], train Loss: 0.5728
# train head_auc 0.9921280503804776
# Epoch [141/200], train Loss: 0.5668
# train head_auc 0.9937461733578239
# Epoch [151/200], train Loss: 0.5164
# train head_auc 0.9950144319076357
# Epoch [161/200], train Loss: 0.4823
# train head_auc 0.996020292136797
# Epoch [171/200], train Loss: 0.4656
# train head_auc 0.9971136184728417
# Epoch [181/200], train Loss: 0.4408
# train head_auc 0.9979008134347941
# Epoch [191/200], train Loss: 0.4122
# train head_auc 0.9986880083967462
# KMM Adversary AUC: 0.4669
# Random Forest Adversary AUC: 0.5800
# End state train Losses: {'reconstruction': 2.1147947311401367, 'head': 0.08674979954957962, 'adversary': 0.35514944791793823}
# train head_auc 0.9993
# train adversary_auc 0.4815
# End state test Losses: {'reconstruction': 2.0645639896392822, 'head': 0.2180679887533188, 'adversary': 0.3637075126171112}
# test head_auc 0.9426
# test adversary_auc 0.5365
# Epoch [1/200], train Loss: 0.9787
# train head_auc 0.6400769701740575
# Epoch [11/200], train Loss: 0.9363
# train head_auc 0.8668328522697456
# Epoch [21/200], train Loss: 0.8919
# train head_auc 0.8934225487623546
# Epoch [31/200], train Loss: 0.8526
# train head_auc 0.9124464270095338
# Epoch [41/200], train Loss: 0.8186
# train head_auc 0.9267908685384414
# Epoch [51/200], train Loss: 0.8318
# train head_auc 0.9396046531968862
# Epoch [61/200], train Loss: 0.7768
# train head_auc 0.949925653809149
# Epoch [71/200], train Loss: 0.7917
# train head_auc 0.9592845272456922
# Epoch [81/200], train Loss: 0.7563
# train head_auc 0.9658007522085192
# Epoch [91/200], train Loss: 0.7263
# train head_auc 0.9721420449575789
# Epoch [101/200], train Loss: 0.6989
# train head_auc 0.9763841511414326
# Epoch [111/200], train Loss: 0.6732
# train head_auc 0.9805387912184028
# Epoch [121/200], train Loss: 0.6269
# train head_auc 0.9841686346540716
# Epoch [131/200], train Loss: 0.6016
# train head_auc 0.9875798128225313
# Epoch [141/200], train Loss: 0.5856
# train head_auc 0.9898101985480626
# Epoch [151/200], train Loss: 0.5771
# train head_auc 0.9915157876322925
# Epoch [161/200], train Loss: 0.5477
# train head_auc 0.9928277792355462
# Epoch [171/200], train Loss: 0.5122
# train head_auc 0.9943584361060089
# Epoch [181/200], train Loss: 0.4822
# train head_auc 0.994970698854194
# Epoch [191/200], train Loss: 0.4494
# train head_auc 0.9958016268695881
# KMM Adversary AUC: 0.4475
# Random Forest Adversary AUC: 0.6109
# End state train Losses: {'reconstruction': 1.828377366065979, 'head': 0.10013493150472641, 'adversary': 0.36550062894821167}
# train head_auc 0.9968
# train adversary_auc 0.5393
# End state test Losses: {'reconstruction': 1.7556086778640747, 'head': 0.2017451822757721, 'adversary': 0.35566315054893494}
# test head_auc 0.9678
# test adversary_auc 0.5714
# Epoch [1/200], train Loss: 1.0265
# train head_auc 0.5095338056503105
# Epoch [11/200], train Loss: 0.9151
# train head_auc 0.8495582961602379
# Epoch [21/200], train Loss: 0.8812
# train head_auc 0.8902300358611038
# Epoch [31/200], train Loss: 0.8665
# train head_auc 0.9127088253301846
# Epoch [41/200], train Loss: 0.8378
# train head_auc 0.9271407329659757
# Epoch [51/200], train Loss: 0.8101
# train head_auc 0.9425347677774862
# Epoch [61/200], train Loss: 0.7934
# train head_auc 0.9537741625120266
# Epoch [71/200], train Loss: 0.7494
# train head_auc 0.9615149129712237
# Epoch [81/200], train Loss: 0.7335
# train head_auc 0.9682935362547014
# Epoch [91/200], train Loss: 0.7063
# train head_auc 0.9733665704539491
# Epoch [101/200], train Loss: 0.6729
# train head_auc 0.9784833377066386
# Epoch [111/200], train Loss: 0.6490
# train head_auc 0.9818507828216565
# Epoch [121/200], train Loss: 0.6712
# train head_auc 0.9852182279366746
# Epoch [131/200], train Loss: 0.5932
# train head_auc 0.9874048806087641
# Epoch [141/200], train Loss: 0.5821
# train head_auc 0.9895040671739701
# Epoch [151/200], train Loss: 0.5492
# train head_auc 0.9912533893116418
# Epoch [161/200], train Loss: 0.5358
# train head_auc 0.9922155164873612
# Epoch [171/200], train Loss: 0.4936
# train head_auc 0.9929152453424298
# Epoch [181/200], train Loss: 0.4548
# train head_auc 0.9935275080906149
# Epoch [191/200], train Loss: 0.4543
# train head_auc 0.9940960377853582
# KMM Adversary AUC: 0.4351
# Random Forest Adversary AUC: 0.4598
# End state train Losses: {'reconstruction': 3.4120402336120605, 'head': 0.09913426637649536, 'adversary': 0.36417895555496216}
# train head_auc 0.9946
# train adversary_auc 0.5448
# End state test Losses: {'reconstruction': 3.145019054412842, 'head': 0.19687479734420776, 'adversary': 0.39103972911834717}
# test head_auc 0.9566
# test adversary_auc 0.5660
# Epoch [1/200], train Loss: 1.0064
# train head_auc 0.7416831465611953
# Epoch [11/200], train Loss: 0.9292
# train head_auc 0.8809931883102615
# Epoch [21/200], train Loss: 0.9021
# train head_auc 0.9042847725774554
# Epoch [31/200], train Loss: 0.8781
# train head_auc 0.9238848604702262
# Epoch [41/200], train Loss: 0.8390
# train head_auc 0.9382113821138212
# Epoch [51/200], train Loss: 0.8323
# train head_auc 0.9488903537684026
# Epoch [61/200], train Loss: 0.8029
# train head_auc 0.9590859151834762
# Epoch [71/200], train Loss: 0.7627
# train head_auc 0.9671720500988794
# Epoch [81/200], train Loss: 0.7803
# train head_auc 0.9717424741814986
# Epoch [91/200], train Loss: 0.7007
# train head_auc 0.9775433970555922
# Epoch [101/200], train Loss: 0.6672
# train head_auc 0.9815425181278841
# Epoch [111/200], train Loss: 0.6297
# train head_auc 0.9849263898044386
# Epoch [121/200], train Loss: 0.6464
# train head_auc 0.9877389584706657
# Epoch [131/200], train Loss: 0.6053
# train head_auc 0.989452867501648
# Epoch [141/200], train Loss: 0.5682
# train head_auc 0.9909470446055811
# Epoch [151/200], train Loss: 0.5336
# train head_auc 0.9916062403867281
# Epoch [161/200], train Loss: 0.5687
# train head_auc 0.9924851680949242
# Epoch [171/200], train Loss: 0.4859
# train head_auc 0.9932322566468909
# Epoch [181/200], train Loss: 0.4647
# train head_auc 0.9935838277301692
# Epoch [191/200], train Loss: 0.4438
# train head_auc 0.9938914524280379
# KMM Adversary AUC: 0.5098
# Random Forest Adversary AUC: 0.5874
# End state train Losses: {'reconstruction': 1.4454114437103271, 'head': 0.09810967743396759, 'adversary': 0.3530145585536957}
# train head_auc 0.9940
# train adversary_auc 0.4541
# End state test Losses: {'reconstruction': 1.4390466213226318, 'head': 0.22026097774505615, 'adversary': 0.3620290458202362}
# test head_auc 0.9478
# test adversary_auc 0.5174
# Epoch [1/200], train Loss: 0.9906
# train head_auc 0.67948606271777
# Epoch [11/200], train Loss: 0.9172
# train head_auc 0.8651567944250871
# Epoch [21/200], train Loss: 0.9078
# train head_auc 0.9020905923344947
# Epoch [31/200], train Loss: 0.8284
# train head_auc 0.9248257839721254
# Epoch [41/200], train Loss: 0.8242
# train head_auc 0.939329268292683
# Epoch [51/200], train Loss: 0.8181
# train head_auc 0.9518728222996515
# Epoch [61/200], train Loss: 0.7889
# train head_auc 0.961890243902439
# Epoch [71/200], train Loss: 0.7370
# train head_auc 0.9699912891986062
# Epoch [81/200], train Loss: 0.6938
# train head_auc 0.9770470383275262
# Epoch [91/200], train Loss: 0.6691
# train head_auc 0.9817508710801394
# Epoch [101/200], train Loss: 0.6243
# train head_auc 0.9856271777003485
# Epoch [111/200], train Loss: 0.6014
# train head_auc 0.9887630662020905
# Epoch [121/200], train Loss: 0.5796
# train head_auc 0.9923344947735191
# Epoch [131/200], train Loss: 0.5571
# train head_auc 0.9947299651567945
# Epoch [141/200], train Loss: 0.5180
# train head_auc 0.9961236933797909
# Epoch [151/200], train Loss: 0.4804
# train head_auc 0.9976480836236934
# Epoch [161/200], train Loss: 0.4713
# train head_auc 0.9987369337979094
# Epoch [171/200], train Loss: 0.4338
# train head_auc 0.9992160278745644
# Epoch [181/200], train Loss: 0.4042
# train head_auc 0.9997386759581881
# Epoch [191/200], train Loss: 0.3784
# train head_auc 0.9999564459930314
# KMM Adversary AUC: 0.4720
# Random Forest Adversary AUC: 0.5609
# End state train Losses: {'reconstruction': 2.546602249145508, 'head': 0.07667764276266098, 'adversary': 0.3560055196285248}
# train head_auc 1.0000
# train adversary_auc 0.5611
# End state test Losses: {'reconstruction': 2.4292542934417725, 'head': 0.2724306285381317, 'adversary': 0.36620134115219116}
# test head_auc 0.9152
# test adversary_auc 0.4905
# Epoch [1/200], train Loss: 0.9962
# train head_auc 0.6541590133823143
# Epoch [11/200], train Loss: 0.9195
# train head_auc 0.8651272631855157
# Epoch [21/200], train Loss: 0.8700
# train head_auc 0.8982331846409516
# Epoch [31/200], train Loss: 0.8474
# train head_auc 0.9201434444152892
# Epoch [41/200], train Loss: 0.8072
# train head_auc 0.9372430683110294
# Epoch [51/200], train Loss: 0.7709
# train head_auc 0.9493571241144056
# Epoch [61/200], train Loss: 0.7420
# train head_auc 0.9603778535817371
# Epoch [71/200], train Loss: 0.7424
# train head_auc 0.9672876760255401
# Epoch [81/200], train Loss: 0.6706
# train head_auc 0.9738476340418087
# Epoch [91/200], train Loss: 0.6754
# train head_auc 0.9783958715997552
# Epoch [101/200], train Loss: 0.6356
# train head_auc 0.981151053966588
# Epoch [111/200], train Loss: 0.5942
# train head_auc 0.9852182279366746
# Epoch [121/200], train Loss: 0.5851
# train head_auc 0.9888480713723432
# Epoch [131/200], train Loss: 0.5379
# train head_auc 0.9911221901513163
# Epoch [141/200], train Loss: 0.5200
# train head_auc 0.9926965800752208
# Epoch [151/200], train Loss: 0.4820
# train head_auc 0.9938336394647074
# Epoch [161/200], train Loss: 0.4691
# train head_auc 0.9950144319076358
# Epoch [171/200], train Loss: 0.4394
# train head_auc 0.9954080293886118
# Epoch [181/200], train Loss: 0.4109
# train head_auc 0.9958453599230298
# Epoch [191/200], train Loss: 0.3958
# train head_auc 0.9961077582436805
# KMM Adversary AUC: 0.3977
# Random Forest Adversary AUC: 0.5061
# End state train Losses: {'reconstruction': 3.1014761924743652, 'head': 0.0754295364022255, 'adversary': 0.3626265525817871}
# train head_auc 0.9966
# train adversary_auc 0.5193
# End state test Losses: {'reconstruction': 3.0346262454986572, 'head': 0.2831713855266571, 'adversary': 0.36069124937057495}
# test head_auc 0.8957
# test adversary_auc 0.5337
# Epoch [1/200], train Loss: 1.0324
# train head_auc 0.38865564593719937
# Epoch [11/200], train Loss: 0.9045
# train head_auc 0.8792093063937725
# Epoch [21/200], train Loss: 0.8666
# train head_auc 0.9187877197585936
# Epoch [31/200], train Loss: 0.8436
# train head_auc 0.9362809411353101
# Epoch [41/200], train Loss: 0.8185
# train head_auc 0.9500131199160325
# Epoch [51/200], train Loss: 0.7960
# train head_auc 0.9597218577801103
# Epoch [61/200], train Loss: 0.7584
# train head_auc 0.9659756844222864
# Epoch [71/200], train Loss: 0.7331
# train head_auc 0.9720983119041371
# Epoch [81/200], train Loss: 0.7177
# train head_auc 0.9771276130499432
# Epoch [91/200], train Loss: 0.6759
# train head_auc 0.9815883845010058
# Epoch [101/200], train Loss: 0.6753
# train head_auc 0.9847808974022566
# Epoch [111/200], train Loss: 0.6326
# train head_auc 0.9876235458759731
# Epoch [121/200], train Loss: 0.6220
# train head_auc 0.9892854019067612
# Epoch [131/200], train Loss: 0.5903
# train head_auc 0.9910347240444328
# Epoch [141/200], train Loss: 0.5473
# train head_auc 0.9921280503804776
# Epoch [151/200], train Loss: 0.5341
# train head_auc 0.9928715122889881
# Epoch [161/200], train Loss: 0.5102
# train head_auc 0.993702440304382
# Epoch [171/200], train Loss: 0.4897
# train head_auc 0.9945333683197761
# Epoch [181/200], train Loss: 0.4543
# train head_auc 0.9952768302282866
# Epoch [191/200], train Loss: 0.4387
# train head_auc 0.9956266946558208
# KMM Adversary AUC: 0.4090
# Random Forest Adversary AUC: 0.5090
# End state train Losses: {'reconstruction': 3.0951929092407227, 'head': 0.09512411803007126, 'adversary': 0.3661101758480072}
# train head_auc 0.9960
# train adversary_auc 0.4792
# End state test Losses: {'reconstruction': 2.992833375930786, 'head': 0.394040584564209, 'adversary': 0.35670968890190125}
# test head_auc 0.8368
# test adversary_auc 0.4817
# Epoch [1/200], train Loss: 0.9924
# train head_auc 0.34640951631242894
# Epoch [11/200], train Loss: 0.9000
# train head_auc 0.8485961689845185
# Epoch [21/200], train Loss: 0.8391
# train head_auc 0.9019504941835039
# Epoch [31/200], train Loss: 0.8239
# train head_auc 0.9228986267821219
# Epoch [41/200], train Loss: 0.8075
# train head_auc 0.940260648998513
# Epoch [51/200], train Loss: 0.7615
# train head_auc 0.9538178955654684
# Epoch [61/200], train Loss: 0.7259
# train head_auc 0.9631330359485699
# Epoch [71/200], train Loss: 0.6892
# train head_auc 0.970261523659582
# Epoch [81/200], train Loss: 0.7081
# train head_auc 0.9748972273244118
# Epoch [91/200], train Loss: 0.6472
# train head_auc 0.9797515962564507
# Epoch [101/200], train Loss: 0.6470
# train head_auc 0.9828566430508177
# Epoch [111/200], train Loss: 0.5900
# train head_auc 0.9871862153415552
# Epoch [121/200], train Loss: 0.6375
# train head_auc 0.989547800227412
# Epoch [131/200], train Loss: 0.5363
# train head_auc 0.9916907198460596
# Epoch [141/200], train Loss: 0.4909
# train head_auc 0.992871512288988
# Epoch [151/200], train Loss: 0.4726
# train head_auc 0.9935712411440567
# Epoch [161/200], train Loss: 0.4628
# train head_auc 0.9938773725181492
# Epoch [171/200], train Loss: 0.4293
# train head_auc 0.9946208344266596
# Epoch [181/200], train Loss: 0.4008
# train head_auc 0.994970698854194
# Epoch [191/200], train Loss: 0.4361
# train head_auc 0.9951018980145194
# KMM Adversary AUC: 0.5518
# Random Forest Adversary AUC: 0.5797
# End state train Losses: {'reconstruction': 3.3601956367492676, 'head': 0.07808726280927658, 'adversary': 0.3688724935054779}
# train head_auc 0.9953
# train adversary_auc 0.5092
# End state test Losses: {'reconstruction': 3.097404718399048, 'head': 0.29007333517074585, 'adversary': 0.36892613768577576}
# test head_auc 0.9020
# test adversary_auc 0.4567
# Epoch [1/200], train Loss: 0.9934
# train head_auc 0.1992529114480334
# Epoch [11/200], train Loss: 0.9073
# train head_auc 0.8731707317073172
# Epoch [21/200], train Loss: 0.8562
# train head_auc 0.9002417051197539
# Epoch [31/200], train Loss: 0.8239
# train head_auc 0.9162381894089211
# Epoch [41/200], train Loss: 0.8081
# train head_auc 0.9306086574379258
# Epoch [51/200], train Loss: 0.7848
# train head_auc 0.9432652164359482
# Epoch [61/200], train Loss: 0.7450
# train head_auc 0.9533289386947923
# Epoch [71/200], train Loss: 0.7481
# train head_auc 0.9629092507141288
# Epoch [81/200], train Loss: 0.7157
# train head_auc 0.9688420127444517
# Epoch [91/200], train Loss: 0.6605
# train head_auc 0.9743792573060865
# Epoch [101/200], train Loss: 0.6385
# train head_auc 0.9792133597011645
# Epoch [111/200], train Loss: 0.6194
# train head_auc 0.9831685343880466
# Epoch [121/200], train Loss: 0.5905
# train head_auc 0.9863766205229619
# Epoch [131/200], train Loss: 0.5554
# train head_auc 0.988573939793452
# Epoch [141/200], train Loss: 0.5767
# train head_auc 0.9901999560536145
# Epoch [151/200], train Loss: 0.5099
# train head_auc 0.9915622940013183
# Epoch [161/200], train Loss: 0.4939
# train head_auc 0.9928806855636124
# Epoch [171/200], train Loss: 0.4637
# train head_auc 0.9938475060426281
# Epoch [181/200], train Loss: 0.4345
# train head_auc 0.9946385409800044
# Epoch [191/200], train Loss: 0.4225
# train head_auc 0.9954735223027906
# KMM Adversary AUC: 0.5680
# Random Forest Adversary AUC: 0.5844
# End state train Losses: {'reconstruction': 3.2429516315460205, 'head': 0.0900493860244751, 'adversary': 0.3522123396396637}
# train head_auc 0.9963
# train adversary_auc 0.5266
# End state test Losses: {'reconstruction': 3.1847352981567383, 'head': 0.2300862818956375, 'adversary': 0.3724137246608734}
# test head_auc 0.9396
# test adversary_auc 0.5029
# Epoch [1/200], train Loss: 0.9972
# train head_auc 0.2649390243902439
# Epoch [11/200], train Loss: 0.9247
# train head_auc 0.8164198606271778
# Epoch [21/200], train Loss: 0.8804
# train head_auc 0.8875
# Epoch [31/200], train Loss: 0.8229
# train head_auc 0.9130226480836235
# Epoch [41/200], train Loss: 0.8014
# train head_auc 0.928876306620209
# Epoch [51/200], train Loss: 0.7672
# train head_auc 0.943336236933798
# Epoch [61/200], train Loss: 0.7448
# train head_auc 0.9531358885017421
# Epoch [71/200], train Loss: 0.7466
# train head_auc 0.9608013937282229
# Epoch [81/200], train Loss: 0.7263
# train head_auc 0.9662456445993033
# Epoch [91/200], train Loss: 0.6973
# train head_auc 0.9718641114982578
# Epoch [101/200], train Loss: 0.6679
# train head_auc 0.9774390243902439
# Epoch [111/200], train Loss: 0.6470
# train head_auc 0.9809233449477351
# Epoch [121/200], train Loss: 0.6060
# train head_auc 0.9849303135888502
# Epoch [131/200], train Loss: 0.5851
# train head_auc 0.9875871080139372
# Epoch [141/200], train Loss: 0.5673
# train head_auc 0.9896777003484319
# Epoch [151/200], train Loss: 0.5445
# train head_auc 0.991506968641115
# Epoch [161/200], train Loss: 0.5220
# train head_auc 0.9928571428571429
# Epoch [171/200], train Loss: 0.5126
# train head_auc 0.9939024390243902
# Epoch [181/200], train Loss: 0.4596
# train head_auc 0.9953397212543553
# Epoch [191/200], train Loss: 0.4534
# train head_auc 0.9960801393728222
# KMM Adversary AUC: 0.4619
# Random Forest Adversary AUC: 0.5216
# End state train Losses: {'reconstruction': 2.1508948802948, 'head': 0.10199534893035889, 'adversary': 0.3788544535636902}
# train head_auc 0.9969
# train adversary_auc 0.4552
# End state test Losses: {'reconstruction': 2.0350053310394287, 'head': 0.26265016198158264, 'adversary': 0.36208438873291016}
# test head_auc 0.9167
# test adversary_auc 0.5117
# Epoch [1/200], train Loss: 0.9922
# train head_auc 0.41266509227674275
# Epoch [11/200], train Loss: 0.9325
# train head_auc 0.8767602554010321
# Epoch [21/200], train Loss: 0.9024
# train head_auc 0.9100411090702353
# Epoch [31/200], train Loss: 0.8727
# train head_auc 0.929808449225925
# Epoch [41/200], train Loss: 0.8440
# train head_auc 0.9406542464794893
# Epoch [51/200], train Loss: 0.8308
# train head_auc 0.9493571241144056
# Epoch [61/200], train Loss: 0.7961
# train head_auc 0.9561357473978832
# Epoch [71/200], train Loss: 0.7641
# train head_auc 0.9621709087728506
# Epoch [81/200], train Loss: 0.7393
# train head_auc 0.9669815446514475
# Epoch [91/200], train Loss: 0.7189
# train head_auc 0.971486049155952
# Epoch [101/200], train Loss: 0.6903
# train head_auc 0.9756406892329222
# Epoch [111/200], train Loss: 0.6879
# train head_auc 0.9786582699204058
# Epoch [121/200], train Loss: 0.6401
# train head_auc 0.9812385200734716
# Epoch [131/200], train Loss: 0.6229
# train head_auc 0.9842123677075134
# Epoch [141/200], train Loss: 0.6033
# train head_auc 0.9860928890055104
# Epoch [151/200], train Loss: 0.5646
# train head_auc 0.9888918044257851
# Epoch [161/200], train Loss: 0.5348
# train head_auc 0.9905536604565731
# Epoch [171/200], train Loss: 0.5126
# train head_auc 0.9919968512201521
# Epoch [181/200], train Loss: 0.4909
# train head_auc 0.9937899064112656
# Epoch [191/200], train Loss: 0.4834
# train head_auc 0.9943584361060089
# KMM Adversary AUC: 0.4406
# Random Forest Adversary AUC: 0.5814
# End state train Losses: {'reconstruction': 4.526698589324951, 'head': 0.11152314394712448, 'adversary': 0.36844465136528015}
# train head_auc 0.9952
# train adversary_auc 0.5572
# End state test Losses: {'reconstruction': 4.252694129943848, 'head': 0.2688511908054352, 'adversary': 0.34651830792427063}
# test head_auc 0.9244
# test adversary_auc 0.5544
# Epoch [1/200], train Loss: 1.0269
# train head_auc 0.6604565730779324
# Epoch [11/200], train Loss: 0.9088
# train head_auc 0.8741800052479664
# Epoch [21/200], train Loss: 0.8619
# train head_auc 0.9116154989941397
# Epoch [31/200], train Loss: 0.8730
# train head_auc 0.9329572290737339
# Epoch [41/200], train Loss: 0.8077
# train head_auc 0.9477390011370593
# Epoch [51/200], train Loss: 0.7831
# train head_auc 0.961033849383364
# Epoch [61/200], train Loss: 0.7568
# train head_auc 0.9709612525146506
# Epoch [71/200], train Loss: 0.7117
# train head_auc 0.9775212105309193
# Epoch [81/200], train Loss: 0.6890
# train head_auc 0.9826817108370507
# Epoch [91/200], train Loss: 0.6455
# train head_auc 0.9871862153415552
# Epoch [101/200], train Loss: 0.6212
# train head_auc 0.9904661943496895
# Epoch [111/200], train Loss: 0.5834
# train head_auc 0.9927840461821045
# Epoch [121/200], train Loss: 0.5484
# train head_auc 0.994577101373218
# Epoch [131/200], train Loss: 0.5239
# train head_auc 0.9959765590833551
# Epoch [141/200], train Loss: 0.4868
# train head_auc 0.9969386862590747
# Epoch [151/200], train Loss: 0.4570
# train head_auc 0.9979882795416777
# Epoch [161/200], train Loss: 0.4241
# train head_auc 0.9988192075570717
# Epoch [171/200], train Loss: 0.4011
# train head_auc 0.9992565380914895
# Epoch [181/200], train Loss: 0.3985
# train head_auc 0.9996064025190239
# Epoch [191/200], train Loss: 0.3604
# train head_auc 0.9998688008396747
# KMM Adversary AUC: 0.4975
# Random Forest Adversary AUC: 0.5631
# End state train Losses: {'reconstruction': 2.9836840629577637, 'head': 0.06299880892038345, 'adversary': 0.36124753952026367}
# train head_auc 0.9999
# train adversary_auc 0.5330
# End state test Losses: {'reconstruction': 2.7005252838134766, 'head': 0.28217974305152893, 'adversary': 0.3976832628250122}
# test head_auc 0.9006
# test adversary_auc 0.4769
# Epoch [1/200], train Loss: 0.9668
# train head_auc 0.6740575526983295
# Epoch [11/200], train Loss: 0.9320
# train head_auc 0.8932913496020293
# Epoch [21/200], train Loss: 0.8953
# train head_auc 0.925610076095513
# Epoch [31/200], train Loss: 0.8765
# train head_auc 0.9406105134260474
# Epoch [41/200], train Loss: 0.8243
# train head_auc 0.9503192512901252
# Epoch [51/200], train Loss: 0.8107
# train head_auc 0.959984256100761
# Epoch [61/200], train Loss: 0.7977
# train head_auc 0.9661943496894954
# Epoch [71/200], train Loss: 0.7598
# train head_auc 0.9717047144231611
# Epoch [81/200], train Loss: 0.7615
# train head_auc 0.9770401469430596
# Epoch [91/200], train Loss: 0.7353
# train head_auc 0.9809761217528208
# Epoch [101/200], train Loss: 0.7057
# train head_auc 0.9831627744249103
# Epoch [111/200], train Loss: 0.6548
# train head_auc 0.9862678212192776
# Epoch [121/200], train Loss: 0.6329
# train head_auc 0.987842211143182
# Epoch [131/200], train Loss: 0.6062
# train head_auc 0.9894166010670866
# Epoch [141/200], train Loss: 0.5712
# train head_auc 0.9903787282428058
# Epoch [151/200], train Loss: 0.5467
# train head_auc 0.9917781859529432
# Epoch [161/200], train Loss: 0.5225
# train head_auc 0.9927403131286626
# Epoch [171/200], train Loss: 0.5152
# train head_auc 0.9933088428234059
# Epoch [181/200], train Loss: 0.4738
# train head_auc 0.9934400419837313
# Epoch [191/200], train Loss: 0.4629
# train head_auc 0.9941397708388
# KMM Adversary AUC: 0.6236
# Random Forest Adversary AUC: 0.6499
# End state train Losses: {'reconstruction': 1.7064425945281982, 'head': 0.10361967980861664, 'adversary': 0.3927735686302185}
# train head_auc 0.9945
# train adversary_auc 0.4953
# End state test Losses: {'reconstruction': 1.665528416633606, 'head': 0.35768845677375793, 'adversary': 0.3841639757156372}
# test head_auc 0.8389
# test adversary_auc 0.5612

# %%
vals = []
for subset_num in range(0,30):
    model_subdir = f'{model_id}_{subset_num}'
    model_dir = os.path.join(output_dir, model_subdir)
    output_data = json.load(open(os.path.join(model_dir, 'output.json')))
    vals.append(output_data['end_state_eval']['test']['head_auc'])
    
print(np.mean(vals), np.std(vals))
# Out:
# 0.9018397814966441 0.04032743132443603
