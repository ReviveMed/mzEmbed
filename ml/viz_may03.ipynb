# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/jonaheaton/Desktop/RCC (2).csv',index_col=0)

# %%
df.T.sort_index().to_csv('/Users/jonaheaton/Desktop/RCC (2) tr.csv')

# %%
df = pd.read_csv('/Users/jonaheaton/Downloads/Z_embed_test2.csv',index_col=0)

# %%
df
# Out:
#                                                PCA1      PCA2      PCA3  \
# 0582_Marios_PD1_Inhib2_HP-EA003798-7.mzML -2.056199 -0.255898  0.137958
# 0293_Marios_PD1_Inhib2_HP-E9101785-7.mzML -0.431255  0.190101 -0.074942
# 0219_Marios_PD1_Inhib2_HP-EA003799-7.mzML  1.138934  0.582211 -0.766346
# 0962_Marios_PD1_Inhib2_HP-E9784758-7.mzML -1.441337 -0.047247  0.053386
# 0218_Marios_PD1_Inhib2_HP-E9123067-7.mzML  3.198435 -0.117491 -0.379169
# ...                                             ...       ...       ...
# 1110_Marios_PD1_Inhib2_HP-AD827407-7.mzML -2.363432 -1.435677 -0.168507
# 1105_Marios_PD1_Inhib2_HP-AE722161-7.mzML -2.419499 -0.141490  0.521248
# 0920_Marios_PD1_Inhib2_HP-AF003923-9.mzML -2.595805 -0.730994  0.133594
# 0793_Marios_PD1_Inhib2_HP-AE206901-7.mzML -1.024622 -1.102265 -0.287442
# 1152_Marios_PD1_Inhib2_HP-AD452686-7.mzML -1.240106  0.709740  0.587156
#
#                                                PCA4      PCA5      PCA6  \
# ...

# %%
sns.scatterplot(df[~df['IMDC BINARY'].isna()],x='UMAP1',y='UMAP2',hue='IMDC')
plt.title('Test Data')
# Out:
# Text(0.5, 1.0, 'Test Data')

# %%
df = pd.read_csv('/Users/jonaheaton/Downloads/Z_embed_test2 (1).csv',index_col=0)

# %%
sns.scatterplot(df,x='UMAP1',y='UMAP2',hue='OS',style='OS_Event')
plt.title('Test Data')
# place legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
