# %%
import os
import neptune
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read in the dataframes

# %%
file1 = '/Users/jonaheaton/Desktop/VAE April18 part1.csv'
file2 = '/Users/jonaheaton/Desktop/VAE April18 part2.csv'
file3 = '/Users/jonaheaton/Desktop/VAE April18 part3.csv'

df2 = pd.read_csv(file2, index_col=0)
df1 = pd.read_csv(file1, index_col=0)
df3 = pd.read_csv(file3, index_col=0)
df = df1.join(df2, how='outer', lsuffix='_1', rsuffix='_2')
df = df.join(df3, how='outer', rsuffix='_3')

# %%
df['pretrain/original_kwargs/study_info_dict/study_name']
# Out:
# Id
# RCC-3028    Multi Obj Apr15
# RCC-3027    Multi Obj Apr15
# RCC-3026    Multi Obj Apr15
# RCC-3025    Multi Obj Apr15
# RCC-3024    Multi Obj Apr15
#                  ...
# RCC-1797                NaN
# RCC-1147                NaN
# RCC-1145                NaN
# RCC-1144                NaN
# RCC-1136                NaN
# Name: pretrain/original_kwargs/study_info_dict/study_name, Length: 834, dtype: object

# %%
# get the important tages
from collections import defaultdict
important_tags = ['april17_best90','april17_pareto','april15_leila']
runs_with_tags_dict= defaultdict(list)

for tag in important_tags:
    for run_id in df.index:
        tags_in_run = eval(df.loc[run_id]['Tags_1'])
        if tag in tags_in_run:
            runs_with_tags_dict[tag].append(run_id)

# %% [markdown]
# ## Cleanup and Simplify the dataframe to the essential bits

# %%
pretrain_objectives = ['Reconstruction Loss (val)',' StudyID AUC (val)', 'CohortLabel AUC (val)','Gender AUC (val)','AgeGroup AUC (val)', 'Age MAE (val)']


finetune_objectives = ['MSKCC AUC (finetune, val)', 'MSKCC AUC (finetune, train)', 'MSKCC AUC (randinit, val)',\
                       'IMDC AUC (finetune, val)', 'IMDC AUC (finetune, train)', 'IMDC AUC (randinit, val)']

key_params = ['Latent dim', '# hidden layers','']#, 'Learning Rate', 'Num Epochs']


search_dct = {
    'Reconstruction Loss (val)': {
        'must_contain_all': ['recon','val'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'StudyID AUC (val)': {
        'must_contain_all': ['StudyID','AUROC','val'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'CohortLabel AUC (val)': {
        'must_contain_all': ['AUROC','val'],
        'must_contain_one': ['CohortLabel','Cohort Label'],
        'exact_matches': []
    },
    'Gender AUC (val)': {
        'must_contain_all': ['AUROC','val'],
        'must_contain_one': ['isFemale','Gender'],
        'exact_matches': []
    },
    'AgeGroup AUC (val)': {
        'must_contain_all': ['AUROC','val','isPediatric'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'Age MAE (val)': {
        'must_contain_all': ['MAE','val'],
        'must_contain_one': ['Age'],
        'exact_matches': []
    },
    'MSKCC AUC (finetune, val)': {
        'must_contain_all': ['MSKCC','finetune','val'],
        'must_contain_one': ['AUROC','AUC'],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'MSKCC AUC (finetune, train)': {
        'must_contain_all': ['MSKCC','finetune','train'],
        'must_contain_one': ['AUROC','AUC'],
        'must_not_contain': ['variance','std'],
        'exact_matches': []
    },
    'MSKCC AUC (randinit, val)': {
        'must_contain_all': ['MSKCC','randinit','val'],
        'must_contain_one': ['AUROC','AUC'],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'IMDC AUC (finetune, val)': {
        'must_contain_all': ['IMDC','finetune','val'],
        'must_contain_one': ['AUROC','AUC'],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'IMDC AUC (finetune, train)': {
        'must_contain_all': ['IMDC','finetune','train'],
        'must_contain_one': ['AUROC','AUC'],
        'exact_matches': [],
        'must_not_contain': ['variance','std'],
    },
    'IMDC AUC (randinit, val)': {
        'must_contain_all': ['IMDC','randinit','val'],
        'must_contain_one': ['AUROC','AUC'],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'Latent dim': {
        'must_contain_all': ['latent'],
        'must_contain_one': [],
        'exact_matches': []
    },
    '# hidden layers': {
        'must_contain_all': ['layers'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'encoder kind':{
        'must_contain_all': ['encoder','kind'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'study name':{
        'must_contain_all': ['original_kwargs','study_info_dict','study_name'],
        'must_contain_one': [],
        'exact_matches': []
    },
    'Both OS C-Index (finetune, val)': {
        'must_contain_all': ['both-OS','finetune','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'Both OS C-Index (finetune, train)': {
        'must_contain_all': ['both-OS','finetune','train','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std'],
        'exact_matches': []
    },
    'Both OS C-Index (randinit, val)': {
        'must_contain_all': ['both-OS','randinit','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'Both PFS C-Index (finetune, val)': {
        'must_contain_all': ['both-PFS','finetune','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'Both PFS C-Index (finetune, train)': {
        'must_contain_all': ['both-PFS','finetune','train','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std'],
        'exact_matches': []
    },
    'Both PFS C-Index (randinit, val)': {
        'must_contain_all': ['both-PFS','randinit','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'NIVO OS C-Index (finetune, val)': {
        'must_contain_all': ['NIVO-OS','finetune','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std','EVER','ever'],
        'exact_matches': []
    },
    'NIVO OS C-Index (finetune, train)': {
        'must_contain_all': ['NIVO-OS','finetune','train','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std','EVER','ever'],
        'exact_matches': []
    },
    'NIVO OS C-Index (randinit, val)': {
        'must_contain_all': ['NIVO-OS','randinit','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std','EVER','ever'],
        'exact_matches': []
    },
    'multitask NIVO OS C-Index (finetune, val)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','finetune','val','Concordance','Cox_NIVO OS'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'multitask NIVO OS C-Index (finetune, train)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','finetune','train','Concordance','Cox_NIVO OS'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std'],
        'exact_matches': []
    },
    'multitask NIVO OS C-Index (randinit, val)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','randinit','val','Concordance','Cox_NIVO OS'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'EVER OS C-Index (finetune, val)': {
        'must_contain_all': ['EVER-OS','finetune','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std','NIVO','nivo'],
        'exact_matches': []
    },
    'EVER OS C-Index (finetune, train)': {
        'must_contain_all': ['EVER-OS','finetune','train','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std','NIVO','nivo'],
        'exact_matches': []
    },
    'EVER OS C-Index (randinit, val)': {
        'must_contain_all': ['EVER-OS','randinit','val','Concordance'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std','NIVO','nivo'],
        'exact_matches': []
    },
    'multitask EVER OS C-Index (finetune, val)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','finetune','val','Concordance','Cox_EVER OS'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    },
    'multitask EVER OS C-Index (finetune, train)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','finetune','train','Concordance','Cox_EVER OS'],
        'must_contain_one': [],
        'must_not_contain': ['variance','std'],
        'exact_matches': []
    },
    'multitask EVER OS C-Index (randinit, val)': {
        'must_contain_all': ['NIVO-OS AND EVER-OS','randinit','val','Concordance','Cox_EVER OS'],
        'must_contain_one': [],
        'must_not_contain': ['train','variance','std'],
        'exact_matches': []
    }


}

# %%
# find the matches to the search dictionary for each important objective/parameter

input_cols = df.columns
selected_cols = []

for obj in search_dct.keys():

    print(obj)
    for col in df.columns:
        
        # first check of the column is already selected for an objective
        if col in selected_cols:
            continue

        # then check for exact matches
        if col in search_dct[obj]['exact_matches']:
            # print(obj, col)
            selected_cols.append(col)

        # then check if the column contains all of the must_contain_all words
        elif len(search_dct[obj]['must_contain_all'])==0 or all([x.lower() in col.lower() for x in search_dct[obj]['must_contain_all']]):
            if len(search_dct[obj]['must_contain_one'])==0 or any([x.lower() in col.lower() for x in search_dct[obj]['must_contain_one']]):
                if len(search_dct[obj].get('must_not_contain', []))==0 or all([x.lower() not in col.lower() for x in search_dct[obj].get('must_not_contain', [])]):

                    # print(obj, col)
                    selected_cols.append(col)
            
                    search_dct[obj]['exact_matches'].append(col)
# Out:
# Reconstruction Loss (val)
# StudyID AUC (val)
# CohortLabel AUC (val)
# Gender AUC (val)
# AgeGroup AUC (val)
# Age MAE (val)
# MSKCC AUC (finetune, val)
# MSKCC AUC (finetune, train)
# MSKCC AUC (randinit, val)
# IMDC AUC (finetune, val)
# IMDC AUC (finetune, train)
# IMDC AUC (randinit, val)
# Latent dim
# # hidden layers
# encoder kind
# study name
# Both OS C-Index (finetune, val)
# Both OS C-Index (finetune, train)
# Both OS C-Index (randinit, val)
# Both PFS C-Index (finetune, val)
# Both PFS C-Index (finetune, train)
# Both PFS C-Index (randinit, val)
# NIVO OS C-Index (finetune, val)
# NIVO OS C-Index (finetune, train)
# NIVO OS C-Index (randinit, val)
# multitask NIVO OS C-Index (finetune, val)
# multitask NIVO OS C-Index (finetune, train)
# multitask NIVO OS C-Index (randinit, val)
# EVER OS C-Index (finetune, val)
# EVER OS C-Index (finetune, train)
# EVER OS C-Index (randinit, val)
# multitask EVER OS C-Index (finetune, val)
# multitask EVER OS C-Index (finetune, train)
# multitask EVER OS C-Index (randinit, val)

# %%
# use the search_dct to create a new dataframe from the selected columns

df = df[selected_cols].copy()

for obj in search_dct.keys():
    if len(search_dct[obj]['exact_matches'])==0:
        print(obj, 'not found')
        continue

    if len(search_dct[obj]['exact_matches'])==1:
        # rename the column to the objective name
        df = df.rename(columns={search_dct[obj]['exact_matches'][0]: obj})
    
    else:
        print(obj, 'multiple matches', search_dct[obj]['exact_matches'])
        # merge the columns into a single column
        # if the columns are numeric then take the mean
        if all(df[search_dct[obj]['exact_matches']].dtypes != 'object'):
            df[obj] = df[search_dct[obj]['exact_matches']].mean(axis=1) # ignore nan
            
        else:
            # if the columns are not numeric then take the first one
            df[obj] = df[search_dct[obj]['exact_matches'][0]]
        df = df.drop(columns=search_dct[obj]['exact_matches'])
# Out:
# MSKCC AUC (finetune, val) multiple matches ['MSKCC_finetune/eval/val/Binary_MSKCC__AUROC (micro) (average)', 'MSKCC_finetune/eval/val2/Binary_MSKCC__AUROC (micro) (average)']
# MSKCC AUC (finetune, train) multiple matches ['MSKCC_finetune/eval/train/Binary_MSKCC__AUROC (micro) (average)', 'MSKCC_finetune/eval/train2/Binary_MSKCC__AUROC (micro) (average)']
# MSKCC AUC (randinit, val) multiple matches ['MSKCC_randinit/eval/val/Binary_MSKCC__AUROC (micro) (average)', 'MSKCC_randinit/eval/val2/Binary_MSKCC__AUROC (micro) (average)']
# IMDC AUC (finetune, val) multiple matches ['IMDC_finetune/eval/val/Binary_IMDC__AUROC (micro) (average)', 'IMDC_finetune/eval/val2/Binary_IMDC__AUROC (micro) (average)']
# IMDC AUC (finetune, train) multiple matches ['IMDC_finetune/eval/train/Binary_IMDC__AUROC (micro) (average)', 'IMDC_finetune/eval/train2/Binary_IMDC__AUROC (micro) (average)']
# IMDC AUC (randinit, val) multiple matches ['IMDC_randinit/eval/val/Binary_IMDC__AUROC (micro) (average)', 'IMDC_randinit/eval/val2/Binary_IMDC__AUROC (micro) (average)']
# Latent dim multiple matches ['pretrain/original_kwargs/encoder_kwargs/latent_size_1', 'pretrain/original_kwargs/encoder_kwargs/latent_size_2']
# # hidden layers multiple matches ['pretrain/original_kwargs/encoder_kwargs/num_hidden_layers_1', 'pretrain/original_kwargs/encoder_kwargs/num_hidden_layers_2']
# encoder kind multiple matches ['pretrain/original_kwargs/encoder_kind_1', 'pretrain/original_kwargs/encoder_kind_2']
# Both OS C-Index (finetune, train) not found
# Both PFS C-Index (finetune, train) not found
# NIVO OS C-Index (finetune, train) not found
# multitask NIVO OS C-Index (finetune, train) not found
# EVER OS C-Index (finetune, val) not found
# EVER OS C-Index (finetune, train) not found
# EVER OS C-Index (randinit, val) not found
# multitask EVER OS C-Index (finetune, train) not found

# %%
df
# Out:
#           Reconstruction Loss (val)  StudyID AUC (val)  CohortLabel AUC (val)  \
# Id
# RCC-3028                   0.603903           0.839010               0.935471
# RCC-3027                   0.948130           0.699162               0.670316
# RCC-3026                        NaN                NaN                    NaN
# RCC-3025                   0.535546           0.867888               0.887715
# RCC-3024                        NaN                NaN                    NaN
# ...                             ...                ...                    ...
# RCC-1797                        NaN                NaN                    NaN
# RCC-1147                        NaN                NaN                    NaN
# RCC-1145                        NaN                NaN                    NaN
# RCC-1144                        NaN                NaN                    NaN
# RCC-1136                        NaN                NaN                    NaN
#
#           Gender AUC (val)  AgeGroup AUC (val)  Age MAE (val)  \
# Id
# RCC-3028          0.840494            0.985297      10.237596
# RCC-3027          0.507654            0.748492      10.312777
# RCC-3026               NaN                 NaN            NaN
# RCC-3025          0.655882            0.978086       9.438339
# RCC-3024               NaN                 NaN            NaN
# ...                    ...                 ...            ...
# RCC-1797               NaN                 NaN            NaN
# RCC-1147               NaN                 NaN            NaN
# RCC-1145               NaN                 NaN            NaN
# RCC-1144               NaN                 NaN            NaN
# RCC-1136               NaN                 NaN            NaN
#
#                study name  Both OS C-Index (finetune, val)  \
# Id
# RCC-3028  Multi Obj Apr15                         0.687971
# RCC-3027  Multi Obj Apr15                         0.673678
# RCC-3026  Multi Obj Apr15                              NaN
# RCC-3025  Multi Obj Apr15                         0.601259
# RCC-3024  Multi Obj Apr15                              NaN
# ...                   ...                              ...
# RCC-1797              NaN                              NaN
# RCC-1147              NaN                              NaN
# RCC-1145              NaN                              NaN
# RCC-1144              NaN                              NaN
# RCC-1136              NaN                              NaN
#
#           Both OS C-Index (randinit, val)  Both PFS C-Index (finetune, val)  \
# Id
# RCC-3028                         0.687869                          0.600296
# RCC-3027                         0.538159                          0.530947
# RCC-3026                              NaN                               NaN
# RCC-3025                         0.500000                          0.491309
# RCC-3024                              NaN                               NaN
# ...                                   ...                               ...
# RCC-1797                              NaN                               NaN
# RCC-1147                              NaN                               NaN
# RCC-1145                              NaN                               NaN
# RCC-1144                              NaN                               NaN
# RCC-1136                              NaN                          0.542292
#
#           ...  multitask EVER OS C-Index (randinit, val)  \
# Id        ...
# RCC-3028  ...                                        NaN
# RCC-3027  ...                                        NaN
# RCC-3026  ...                                        NaN
# RCC-3025  ...                                        NaN
# RCC-3024  ...                                        NaN
# ...       ...                                        ...
# RCC-1797  ...                                        NaN
# RCC-1147  ...                                        NaN
# RCC-1145  ...                                        NaN
# RCC-1144  ...                                        NaN
# RCC-1136  ...                                        NaN
#
#           MSKCC AUC (finetune, val)  MSKCC AUC (finetune, train)  \
# Id
# RCC-3028                        NaN                          NaN
# RCC-3027                        NaN                          NaN
# RCC-3026                        NaN                          NaN
# RCC-3025                        NaN                          NaN
# RCC-3024                        NaN                          NaN
# ...                             ...                          ...
# RCC-1797                        NaN                          NaN
# RCC-1147                        NaN                          NaN
# RCC-1145                        NaN                          NaN
# RCC-1144                        NaN                          NaN
# RCC-1136                   0.871473                     0.992728
#
#           MSKCC AUC (randinit, val)  IMDC AUC (finetune, val)  \
# Id
# RCC-3028                        NaN                       NaN
# RCC-3027                        NaN                       NaN
# RCC-3026                        NaN                       NaN
# RCC-3025                        NaN                       NaN
# RCC-3024                        NaN                       NaN
# ...                             ...                       ...
# RCC-1797                        NaN                       NaN
# RCC-1147                        NaN                       NaN
# RCC-1145                        NaN                       NaN
# RCC-1144                        NaN                       NaN
# RCC-1136                   0.750772                  0.885936
#
#           IMDC AUC (finetune, train)  IMDC AUC (randinit, val)  Latent dim  \
# Id
# RCC-3028                         NaN                       NaN        25.0
# RCC-3027                         NaN                       NaN        75.0
# RCC-3026                         NaN                       NaN        81.0
# RCC-3025                         NaN                       NaN       126.0
# RCC-3024                         NaN                       NaN       101.0
# ...                              ...                       ...         ...
# RCC-1797                         NaN                       NaN        12.0
# RCC-1147                         NaN                       NaN        38.0
# RCC-1145                         NaN                       NaN        29.0
# RCC-1144                         NaN                       NaN        12.0
# RCC-1136                    0.992563                    0.8331        21.0
#
#           # hidden layers  encoder kind
# Id
# RCC-3028              3.0           VAE
# RCC-3027              4.0           VAE
# RCC-3026              1.0           VAE
# RCC-3025              2.0           VAE
# RCC-3024              2.0           VAE
# ...                   ...           ...
# RCC-1797              5.0           VAE
# RCC-1147              4.0           VAE
# RCC-1145              4.0           VAE
# RCC-1144              5.0           VAE
# RCC-1136              3.0           VAE
#
# [834 rows x 26 columns]

# %%
df['model complexity'] = df['Latent dim']*df['# hidden layers']
df['MSKCC AUC Diff (finetune-randinit)'] = df['MSKCC AUC (finetune, val)'] - df['MSKCC AUC (randinit, val)']
df['IMDC AUC Diff (finetune-randinit)'] = df['IMDC AUC (finetune, val)'] - df['IMDC AUC (randinit, val)']
df['Both OS C-Index Diff (finetune-randinit)'] = df['Both OS C-Index (finetune, val)'] - df['Both OS C-Index (randinit, val)']
df['Both PFS C-Index Diff (finetune-randinit)'] = df['Both PFS C-Index (finetune, val)'] - df['Both PFS C-Index (randinit, val)']

# %%
# add the import tags
for tag in important_tags:
    df['Has Tag '+tag] = df.index.isin(runs_with_tags_dict[tag])

# %%
df.dropna(subset=['Gender AUC (val)','Age MAE (val)'], inplace=True)

# drop outliers in the Age MAE
df = df[df['Age MAE (val)']<100].copy()

# %% [markdown]
# ## Now that it is clean we can do analysis

# %%
pretrain_objectives = ['Reconstruction Loss (val)','StudyID AUC (val)', 'CohortLabel AUC (val)','Gender AUC (val)','AgeGroup AUC (val)', 'Age MAE (val)']


finetune_objectives = ['MSKCC AUC (finetune, val)', 'MSKCC AUC (randinit, val)',\
                       'IMDC AUC (finetune, val)', 'IMDC AUC (randinit, val)',\
                        'Both OS C-Index (finetune, val)', 'Both OS C-Index (randinit, val)',
                        'Both PFS C-Index (finetune, val)', 'Both PFS C-Index (randinit, val)',
                        'NIVO OS C-Index (finetune, val)', 'NIVO OS C-Index (randinit, val)',
                        'EVER OS C-Index (finetune, val)', 'EVER OS C-Index (randinit, val)',
                        'multitask NIVO OS C-Index (finetune, val)', 'multitask NIVO OS C-Index (randinit, val)',
                        'multitask EVER OS C-Index (finetune, val)', 'multitask EVER OS C-Index (randinit, val)']

key_params = ['Latent dim', '# hidden layers','model complexity']#, 'Learning Rate', 'Num Epochs']

key_cols = pretrain_objectives+finetune_objectives+key_params

# %%
df['study name'].value_counts()
# Out:
# study name
# Multi Obj Apr12      337
# Multi Obj Apr15      149
# Multi Obj Apr11v2    134
# Multi Obj Apr10        2
# Multi Obj Apr11        1
# Name: count, dtype: int64

# %%
df['encoder kind'].value_counts()
# Out:
# encoder kind
# VAE    623
# Name: count, dtype: int64

# %%
ae_models = df[df['encoder kind']=='AE'].copy()
vae_models = df[df['encoder kind']=='VAE'].copy()

# %%
date_str = 'April18'
ae_models.sort_values('Age MAE (val)',ascending=True, inplace=True)
ae_models.sort_values('Gender AUC (val)', inplace=True, ascending=False)
ae_models.to_csv(f'/Users/jonaheaton/Desktop/ae_models {date_str}.csv')


vae_models.sort_values('Age MAE (val)',ascending=True, inplace=True)
vae_models.sort_values('Gender AUC (val)', inplace=True, ascending=False)
vae_models.to_csv(f'/Users/jonaheaton/Desktop/vae_models {date_str}.csv')

# %%
def update_directions_and_scales(df):

    df['neg log Reconstruction Loss (val)'] = -1* np.log(df['Reconstruction Loss (val)'])
    # remove the old column
    df = df.drop(columns=['Reconstruction Loss (val)'])

    df['neg Age MAE'] = -1*df['Age MAE (val)']
    df['neg Age MSE'] = -1*df['Age MAE (val)']
    df['neg StudyID AUC (val)'] = -1*df['StudyID AUC (val)']
    df.drop(columns=['Age MAE (val)','Age MAE (val)','StudyID AUC (val)'], inplace=True)


    df.drop(columns=['MSKCC AUC (finetune, train)', 'IMDC AUC (finetune, train)','neg Age MSE'], inplace=True)
    # drop the columns about tags
    df.drop(columns=[col for col in df.columns if 'Has Tag' in col], inplace=True)
    # drop any non-numeric columns
    df = df.select_dtypes(include=[np.number]).copy()

    

    return df

# %%
# ae_model_clean = update_directions_and_scales(ae_models.copy())

# %%
# Compute the correlation matrix

# corr_matrix = ae_model_clean.corr(method='spearman')

# # Plot the correlation matrix
# # make the plot bigger
# plt.figure(figsize=(20, 16))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# plt.title('Spearman Correlation Matrix (AE Model)')

# # rotate the x-axis labels
# plt.xticks(rotation=45, ha='right')

# plt.savefig('/Users/jonaheaton/Desktop/ae_correlation_matrix.png')

# %%
# sns.set_context('notebook')
# nonan_corr_matrix = corr_matrix.dropna(axis=1, how='all').dropna(axis=0, how='all')
# nonan_corr_matrix = nonan_corr_matrix.dropna(axis=0).dropna(axis=1).round(2)

# plt.figure(figsize=(26, 24))
# cax = sns.clustermap(nonan_corr_matrix, cmap='coolwarm', annot=True, annot_kws={"size": 7})
# plt.xticks(rotation=45, ha='right')

# # Set colorbar label size
# cax.cax.yaxis.set_tick_params(labelsize=8)

# # Set colorbar label size
# cax.cax.yaxis.set_tick_params(labelsize=8)

# # Set axis label size
# cax.ax_heatmap.tick_params(axis='both', which='both', labelsize=8)

# # add a title to the clustergird
# cax.ax_col_dendrogram.set_title('Spearman Correlation Matrix (AE Model)')

# plt.savefig('/Users/jonaheaton/Desktop/ae_clustered_correlation_matrix.png')

# %%
vae_model_clean = update_directions_and_scales(vae_models.copy())

# %%
# Compute the correlation matrix
top_model_clean = vae_model_clean.loc[vae_models[vae_models['Has Tag april17_best90']].index].copy()
corr_matrix = top_model_clean.corr(method='spearman')

# Plot the correlation matrix
# make the plot bigger
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Spearman Correlation Matrix (VAE top models)')

# rotate the x-axis labels
plt.xticks(rotation=45, ha='right')

plt.savefig('/Users/jonaheaton/Desktop/top_vae_correlation_matrix.png')

# %%
# sns.set_context('notebook')
nonan_corr_matrix = corr_matrix.dropna(axis=1, how='all').dropna(axis=0, how='all')
nonan_corr_matrix = nonan_corr_matrix.dropna(axis=0).dropna(axis=1).round(2)

plt.figure(figsize=(30, 27))
cax = sns.clustermap(nonan_corr_matrix, cmap='coolwarm', annot=True, annot_kws={"size": 6})

# Set colorbar label size
cax.cax.yaxis.set_tick_params(labelsize=8)

# Set colorbar label size
cax.cax.yaxis.set_tick_params(labelsize=8)

# Set axis label size
cax.ax_heatmap.tick_params(axis='both', which='both', labelsize=8)
# cax.ax_heatmap.tick_params(axis='x', rotation=45)
# cax.ax_heatmap.tick_params(axis='x', labelrotation=45)


# add a title to the clustergird
cax.ax_col_dendrogram.set_title('Spearman Correlation Matrix (VAE Top Models)')

plt.savefig('/Users/jonaheaton/Desktop/top_vae_clustered_correlation_matrix.png')

# %%
# Compute the correlation matrix

corr_matrix = vae_model_clean.corr(method='spearman')

# Plot the correlation matrix
# make the plot bigger
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Spearman Correlation Matrix (VAE)')

# rotate the x-axis labels
plt.xticks(rotation=45, ha='right')

plt.savefig('/Users/jonaheaton/Desktop/vae_correlation_matrix.png')

# %%
# sns.set_context('notebook')
nonan_corr_matrix = corr_matrix.dropna(axis=1, how='all').dropna(axis=0, how='all')
nonan_corr_matrix = nonan_corr_matrix.dropna(axis=0).dropna(axis=1).round(2)

plt.figure(figsize=(30, 27))
cax = sns.clustermap(nonan_corr_matrix, cmap='coolwarm', annot=True, annot_kws={"size": 6})

# Set colorbar label size
cax.cax.yaxis.set_tick_params(labelsize=8)

# Set colorbar label size
cax.cax.yaxis.set_tick_params(labelsize=8)

# Set axis label size
cax.ax_heatmap.tick_params(axis='both', which='both', labelsize=8)
# cax.ax_heatmap.tick_params(axis='x', rotation=45)
# cax.ax_heatmap.tick_params(axis='x', labelrotation=45)


# add a title to the clustergird
cax.ax_col_dendrogram.set_title('Spearman Correlation Matrix (VAE Model)')

plt.savefig('/Users/jonaheaton/Desktop/vae_clustered_correlation_matrix.png')

# %% [markdown]
# ## Choose the best runs using the pareto front

# %%
from paretoset import paretoset

# %%
def pareto_reduction(df, sense_list=None, current_set=None, desired_num=None, objective_cols=None):
    
    if desired_num is None:
        desired_num = np.floor(0.2*df.shape[0])
    if objective_cols is None:
        objective_cols = df.columns
    if sense_list is None:
        sense_list = ['max' for _ in objective_cols]

    if df.shape[0] < desired_num*1.5:
        return df

    mask = paretoset(df[objective_cols], sense=sense_list)
    current_set = pd.concat([current_set, df[mask]])
    if current_set.shape[0] < desired_num:
        return pareto_reduction(df[~mask], sense_list, current_set, desired_num, objective_cols)
    else:
        return current_set
    

def remove_outliers(df, column):
    Q1 = df[column].quantile(0.1)
    Q3 = df[column].quantile(0.9)
    IQR = Q3 - Q1

    df_out = df[~((df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR)))]
    
    return df_out

# %%
vae_model_clean.shape
# Out:
# (641, 21)

# %%
(~vae_model_clean['MSKCC AUC (finetune, val)'].isna()).sum()
# Out:
# 525

# %%
vae_model_clean
# Out:
#           Latent dim  # hidden layers  Both OS C-Index (finetune, val)  \
# Id
# RCC-3013        80.0              5.0                         0.687362
# RCC-2559        56.0              3.0                              NaN
# RCC-2987       119.0              4.0                              NaN
# RCC-2507        29.0              2.0                              NaN
# RCC-2549        61.0              2.0                              NaN
# ...              ...              ...                              ...
# RCC-2731        63.0              5.0                              NaN
# RCC-2828        42.0              5.0                         0.500000
# RCC-2657        45.0              3.0                              NaN
# RCC-2800        51.0              2.0                         0.612696
# RCC-2253        60.0              3.0                              NaN
#
#           Both OS C-Index (randinit, val)  Both PFS C-Index (finetune, val)  \
# Id
# RCC-3013                         0.520318                          0.545353
# RCC-2559                              NaN                               NaN
# RCC-2987                              NaN                          0.553891
# RCC-2507                              NaN                               NaN
# RCC-2549                              NaN                               NaN
# ...                                   ...                               ...
# RCC-2731                              NaN                               NaN
# RCC-2828                         0.634237                          0.500000
# RCC-2657                              NaN                               NaN
# RCC-2800                         0.625016                          0.500000
# RCC-2253                              NaN                               NaN
#
#           Both PFS C-Index (randinit, val)  CohortLabel AUC (val)  \
# Id
# RCC-3013                               0.5               0.990883
# RCC-2559                               NaN               0.827350
# RCC-2987                               0.5               0.989760
# RCC-2507                               NaN               0.979680
# RCC-2549                               NaN               0.823431
# ...                                    ...                    ...
# RCC-2731                               NaN               0.446569
# RCC-2828                               0.5               0.530451
# RCC-2657                               NaN               0.700982
# RCC-2800                               0.5               0.525452
# RCC-2253                               NaN               0.752743
#
#           Gender AUC (val)  AgeGroup AUC (val)  MSKCC AUC (finetune, val)  \
# Id
# RCC-3013          0.890305            0.998471                        NaN
# RCC-2559          0.889301            0.965923                   0.872840
# RCC-2987          0.887873            0.995976                        NaN
# RCC-2507          0.886695            0.995847                   0.829365
# RCC-2549          0.886217            0.970000                   0.869621
# ...                    ...                 ...                        ...
# RCC-2731          0.471697            0.502566                   0.510009
# RCC-2828          0.468668            0.382603                   0.510031
# RCC-2657          0.465275            0.794672                   0.829233
# RCC-2800          0.463991            0.497216                   0.503527
# RCC-2253          0.433537            0.942881                   0.834524
#
#           ...  IMDC AUC (finetune, val)  IMDC AUC (randinit, val)  \
# Id        ...
# RCC-3013  ...                       NaN                       NaN
# RCC-2559  ...                  0.888733                  0.775097
# RCC-2987  ...                       NaN                       NaN
# RCC-2507  ...                  0.879332                  0.806061
# RCC-2549  ...                  0.894872                  0.729060
# ...       ...                       ...                       ...
# RCC-2731  ...                  0.500000                  0.691064
# RCC-2828  ...                  0.500000                  0.827972
# RCC-2657  ...                  0.913287                  0.829371
# RCC-2800  ...                  0.729099                  0.777778
# RCC-2253  ...                  0.906449                  0.754468
#
#           model complexity  MSKCC AUC Diff (finetune-randinit)  \
# Id
# RCC-3013             400.0                                 NaN
# RCC-2559             168.0                            0.346869
# RCC-2987             476.0                                 NaN
# RCC-2507              58.0                            0.131834
# RCC-2549             122.0                            0.365873
# ...                    ...                                 ...
# RCC-2731             315.0                            0.009083
# RCC-2828             210.0                           -0.073942
# RCC-2657             135.0                            0.260847
# RCC-2800             102.0                            0.002910
# RCC-2253             180.0                            0.285317
#
#           IMDC AUC Diff (finetune-randinit)  \
# Id
# RCC-3013                                NaN
# RCC-2559                           0.113636
# RCC-2987                                NaN
# RCC-2507                           0.073271
# RCC-2549                           0.165812
# ...                                     ...
# RCC-2731                          -0.191064
# RCC-2828                          -0.327972
# RCC-2657                           0.083916
# RCC-2800                          -0.048679
# RCC-2253                           0.151981
#
#           Both OS C-Index Diff (finetune-randinit)  \
# Id
# RCC-3013                                  0.167044
# RCC-2559                                       NaN
# RCC-2987                                       NaN
# RCC-2507                                       NaN
# RCC-2549                                       NaN
# ...                                            ...
# RCC-2731                                       NaN
# RCC-2828                                 -0.134237
# RCC-2657                                       NaN
# RCC-2800                                 -0.012320
# RCC-2253                                       NaN
#
#           Both PFS C-Index Diff (finetune-randinit)  \
# Id
# RCC-3013                                   0.045353
# RCC-2559                                        NaN
# RCC-2987                                   0.053891
# RCC-2507                                        NaN
# RCC-2549                                        NaN
# ...                                             ...
# RCC-2731                                        NaN
# RCC-2828                                   0.000000
# RCC-2657                                        NaN
# RCC-2800                                   0.000000
# RCC-2253                                        NaN
#
#           neg log Reconstruction Loss (val)  neg Age MAE  \
# Id
# RCC-3013                           0.053260    -9.093743
# RCC-2559                           0.300080   -10.521715
# RCC-2987                           0.676420    -9.704203
# RCC-2507                           0.450439    -8.908306
# RCC-2549                           0.053255   -10.877678
# ...                                     ...          ...
# RCC-2731                           0.570014   -39.654396
# RCC-2828                           0.550870   -38.956985
# RCC-2657                           0.062284    -9.603444
# RCC-2800                           0.047948   -38.959576
# RCC-2253                           0.485751    -9.998194
#
#           neg StudyID AUC (val)
# Id
# RCC-3013              -0.541620
# RCC-2559              -0.777997
# RCC-2987              -0.504746
# RCC-2507              -0.881439
# RCC-2549              -0.766172
# ...                         ...
# RCC-2731              -0.588918
# RCC-2828              -0.604487
# RCC-2657              -0.702336
# RCC-2800              -0.686835
# RCC-2253              -0.801001
#
# [641 rows x 21 columns]

# %%
# pretrain_clean_objectives = ['Gender AUC (val)','AgeGroup AUC (val)','CohortLabel AUC (val)','neg Age MAE','neg StudyID AUC (val)','neg log Reconstruction Loss (val)']

pretrain_clean_objectives = ['Gender AUC (val)','AgeGroup AUC (val)','CohortLabel AUC (val)','neg Age MAE','neg log Reconstruction Loss (val)']
df_obj = vae_model_clean[pretrain_clean_objectives].copy()

# %%
df_obj.to_csv('/Users/jonaheaton/Desktop/vae_pretrain_objectives.csv')

# %%
df_obj = remove_outliers(df_obj,'neg Age MAE')
df_obj = remove_outliers(df_obj,'neg log Reconstruction Loss (val)')

# %%
df_obj.to_csv('/Users/jonaheaton/Desktop/vae_pretrain_objectives.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_obj.to_csv('/Users/jonaheaton/Desktop/vae_pretrain_objectives.csv')
#
# NameError: name 'df_obj' is not defined

# %%
df_obj.shape
# Out:
# (578, 5)

# %%
vae_model_subset = vae_model_clean.copy()
vae_model_subset = vae_model_subset.loc[df_obj.index].copy()

print('Finetune Statistics')
mkscc_finetune_count = (~vae_model_subset['MSKCC AUC (finetune, val)'].isna()).sum()
imdc_finetune_count = (~vae_model_subset['IMDC AUC (finetune, val)'].isna()).sum()
both_os_finetune_count = (~vae_model_subset['Both OS C-Index (finetune, val)'].isna()).sum()
both_pfs_finetune_count = (~vae_model_subset['Both PFS C-Index (finetune, val)'].isna()).sum()

print('MSKCC Finetune Count', mkscc_finetune_count)
print('IMDC Finetune Count', imdc_finetune_count)
print('Both OS Finetune Count', both_os_finetune_count)
print('Both PFS Finetune Count', both_pfs_finetune_count)
# Out:
# Finetune Statistics
# MSKCC Finetune Count 462
# IMDC Finetune Count 462
# Both OS Finetune Count 105
# Both PFS Finetune Count 110

# %%
pareto_df2 = pareto_reduction(df_obj.round(1))

# %%
pareto_df2.shape
# Out:
# (121, 5)

# %%
pareto_df = pareto_reduction(df_obj.round(5))

# %%
pareto_df.shape
# Out:
# (157, 5)

# %%
pareto_df
# Out:
#           Gender AUC (val)  AgeGroup AUC (val)  CohortLabel AUC (val)  \
# Id
# RCC-3013           0.89030             0.99847                0.99088
# RCC-2559           0.88930             0.96592                0.82735
# RCC-2987           0.88787             0.99598                0.98976
# RCC-2507           0.88669             0.99585                0.97968
# RCC-2658           0.88389             0.99531                0.89848
# ...                    ...                 ...                    ...
# RCC-2534           0.59572             0.99677                0.93390
# RCC-2188           0.59532             0.99104                0.98242
# RCC-2633           0.57152             0.99536                0.90196
# RCC-2651           0.57001             0.99587                0.89263
# RCC-2575           0.54773             0.98900                    NaN
#
#           neg Age MAE  neg log Reconstruction Loss (val)
# Id
# RCC-3013     -9.09374                            0.05326
# RCC-2559    -10.52172                            0.30008
# RCC-2987     -9.70420                            0.67642
# RCC-2507     -8.90831                            0.45044
# RCC-2658     -8.52497                            0.55652
# ...               ...                                ...
# RCC-2534     -9.65191                            0.44834
# RCC-2188    -10.10154                            0.67078
# RCC-2633     -9.19095                            0.58346
# RCC-2651     -9.58629                            0.52350
# RCC-2575     -8.88481                            0.05326
#
# [157 rows x 5 columns]

# %%
df_obj['pareto front'] = False
df_obj.loc[pareto_df.index, 'pareto front'] = True
sns.pairplot(df_obj, hue='pareto front')

# %%
NEPTUNE_API_TOKEN = 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGM5ZDhiMy1kOTlhLTRlMTAtOGFlYy1hOTQzMDE1YjZlNjcifQ=='

# %%
## Add tag to the top models


chosen_runs = pareto_df.index.tolist()

for run_id in chosen_runs:
    run = neptune.init_run(project='revivemed/RCC', api_token=NEPTUNE_API_TOKEN, with_id=run_id)
    run['sys/tags'].add('april17_pareto')
    run.stop()
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3013
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3013/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2559
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2559/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2987
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2987/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2507
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2507/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2658
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2658/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2390
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2390/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2370
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2370/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2425
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2425/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2956
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2956/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2488
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2488/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2925
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2925/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3011
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3011/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2402
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2402/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2802
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 4 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 4 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2802/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3023
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3023/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2277
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2277/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2140
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2140/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2331
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2331/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2938
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2938/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2223
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2223/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2227
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2227/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2851
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2851/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2977
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2977/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2786
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2786/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2445
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2445/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2549
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2549/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2881
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2881/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2676
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2676/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2876
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2876/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2848
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2848/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2964
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2964/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2224
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2224/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2502
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2502/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2486
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2486/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2050
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2050/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2221
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2221/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2721
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2721/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3018
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3018/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2950
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2950/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2621
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2621/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2314
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2314/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2992
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2992/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2162
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2162/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2978
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2978/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2595
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2595/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2548
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2548/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2378
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2378/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2392
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2392/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2949
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2949/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2504
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2504/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2153
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2153/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2455
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2455/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2372
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2372/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2321
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2321/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2983
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2983/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3007
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3007/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2201
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2201/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2976
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2976/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2368
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2368/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3021
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3021/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2296
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2296/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2254
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2254/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2312
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2312/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3002
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3002/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2855
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2855/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2951
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2951/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2991
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2991/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2257
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2257/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2389
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2389/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2187
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2187/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2169
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2169/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2052
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2052/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2220
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2220/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2344
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2344/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2995
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2995/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2206
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2206/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2149
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2149/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2243
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2243/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2993
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2993/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2024
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2024/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2496
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2496/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2647
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2647/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2596
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2596/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2568
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2568/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2830
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2830/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2734
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2734/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2276
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2276/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2588
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2588/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2225
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2225/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2584
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2584/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2922
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2922/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2165
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2165/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2302
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2302/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2787
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2787/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2520
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2520/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2231
# ...
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2248/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2453
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2453/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2233
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2233/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2401
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2401/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2267
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2267/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2960
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2960/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2036
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2036/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2492
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2492/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2959
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2959/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2672
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2672/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2759
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2759/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2364
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2364/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2228
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2228/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2035
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2035/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2914
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2914/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2896
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2896/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2967
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2967/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2342
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2342/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2597
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2597/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2581
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2581/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2377
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2377/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2515
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2515/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2376
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2376/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2752
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2752/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2932
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2932/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2192
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2192/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2680
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2680/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2534
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2534/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2188
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2188/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2633
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2633/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2651
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] All 0 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2651/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2575
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2575/metadata

# %%
vae_model_clean
# Out:
#           Latent dim  # hidden layers  CohortLabel AUC (val)  \
# Id
# RCC-2559        56.0              3.0               0.827350
# RCC-2507        29.0              2.0               0.979680
# RCC-2549        61.0              2.0               0.823431
# RCC-2676        42.0              1.0               0.978687
# RCC-2691        38.0              2.0               0.980738
# ...              ...              ...                    ...
# RCC-2805        42.0              5.0               0.512258
# RCC-2731        63.0              5.0               0.446569
# RCC-2657        45.0              3.0               0.700982
# RCC-2800        51.0              2.0               0.525452
# RCC-2253        60.0              3.0               0.752743
#
#           Gender AUC (val)  AgeGroup AUC (val)  MSKCC AUC (finetune, val)  \
# Id
# RCC-2559          0.889301            0.965923                   0.871098
# RCC-2507          0.886695            0.995847                   0.829960
# RCC-2549          0.886217            0.970000                   0.869775
# RCC-2676          0.884760            0.997477                   0.862500
# RCC-2691          0.884177            0.996623                   0.858399
# ...                    ...                 ...                        ...
# RCC-2805          0.472676            0.422462                        NaN
# RCC-2731          0.471697            0.502566                   0.522288
# RCC-2657          0.465275            0.794672                   0.828968
# RCC-2800          0.463991            0.497216                        NaN
# RCC-2253          0.433537            0.942881                   0.832870
#
#           MSKCC AUC (randinit, val)  IMDC AUC (finetune, val)  \
# Id
# RCC-2559                   0.501720                  0.887762
# RCC-2507                   0.722884                  0.881002
# RCC-2549                   0.500000                  0.895338
# RCC-2676                   0.870106                  0.889860
# RCC-2691                   0.654630                  0.896037
# ...                             ...                       ...
# RCC-2805                        NaN                       NaN
# RCC-2731                   0.501786                  0.500000
# RCC-2657                   0.563690                  0.912587
# RCC-2800                        NaN                       NaN
# RCC-2253                   0.573810                  0.906061
#
#           IMDC AUC (randinit, val)  model complexity  \
# Id
# RCC-2559                  0.798601             168.0
# RCC-2507                  0.842657              58.0
# RCC-2549                  0.767949             122.0
# RCC-2676                  0.893939              42.0
# RCC-2691                  0.845396              76.0
# ...                            ...               ...
# RCC-2805                       NaN             210.0
# RCC-2731                  0.728322             315.0
# RCC-2657                  0.804895             135.0
# RCC-2800                       NaN             102.0
# RCC-2253                  0.765618             180.0
#
#           MSKCC AUC Diff (finetune-randinit)  \
# Id
# RCC-2559                            0.369378
# RCC-2507                            0.107077
# RCC-2549                            0.369775
# RCC-2676                           -0.007606
# RCC-2691                            0.203770
# ...                                      ...
# RCC-2805                                 NaN
# RCC-2731                            0.020503
# RCC-2657                            0.265278
# RCC-2800                                 NaN
# RCC-2253                            0.259061
#
#           IMDC AUC Diff (finetune-randinit)  \
# Id
# RCC-2559                           0.089161
# RCC-2507                           0.038345
# RCC-2549                           0.127389
# RCC-2676                          -0.004079
# RCC-2691                           0.050641
# ...                                     ...
# RCC-2805                                NaN
# RCC-2731                          -0.228322
# RCC-2657                           0.107692
# RCC-2800                                NaN
# RCC-2253                           0.140443
#
#           neg log Reconstruction Loss (val)  neg Age MAE  \
# Id
# RCC-2559                           0.300080   -10.521715
# RCC-2507                           0.450439    -8.908306
# RCC-2549                           0.053255   -10.877678
# RCC-2676                           0.053262   -10.449822
# RCC-2691                          -2.432603    -9.323588
# ...                                     ...          ...
# RCC-2805                           0.561059   -39.789707
# RCC-2731                           0.570014   -39.654396
# RCC-2657                           0.062284    -9.603444
# RCC-2800                           0.047948   -38.959576
# RCC-2253                           0.485751    -9.998194
#
#           neg StudyID AUC (val)
# Id
# RCC-2559              -0.777997
# RCC-2507              -0.881439
# RCC-2549              -0.766172
# RCC-2676              -0.877224
# RCC-2691              -0.889493
# ...                         ...
# RCC-2805              -0.603648
# RCC-2731              -0.588918
# RCC-2657              -0.702336
# RCC-2800              -0.686835
# RCC-2253              -0.801001
#
# [486 rows x 15 columns]

# %% [markdown]
# ## Tag best models from list

# %%
NEPTUNE_API_TOKEN = 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGM5ZDhiMy1kOTlhLTRlMTAtOGFlYy1hOTQzMDE1YjZlNjcifQ=='

# %%
best_list_file = '/Users/jonaheaton/Desktop/april17 best.csv'
chosen_runs = pd.read_csv(best_list_file)['id'].tolist()

# %%
for run_id in chosen_runs:
    run = neptune.init_run(project='revivemed/RCC', api_token=NEPTUNE_API_TOKEN, with_id=run_id)
    run['sys/tags'].add('april17_best90')
    run.stop()
# Out:
# [neptune] [warning] NeptuneWarning: The following monitoring options are disabled by default in interactive sessions: 'capture_stdout', 'capture_stderr', 'capture_traceback', and 'capture_hardware_metrics'. To enable them, set each parameter to 'True' when initializing the run. The monitoring will continue until you call run.stop() or the kernel stops. Also note: Your source files can only be tracked if you pass the path(s) to the 'source_code' argument. For help, see the Neptune docs: https://docs.neptune.ai/logging/source_code/
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2704
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2704/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2964
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2964/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2584
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2584/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2154
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2154/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2438
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2438/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2317
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2317/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2325
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2325/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2976
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2976/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2992
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2992/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2384
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2384/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2588
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2588/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2282
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2282/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2560
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2560/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2544
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2544/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2911
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2911/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2312
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2312/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2866
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2866/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2050
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2050/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2933
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2933/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2225
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2225/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2240
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2240/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2551
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2551/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2392
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2392/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2922
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2922/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2494
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2494/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2180
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2180/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2304
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2304/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2502
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2502/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2983
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2983/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2879
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2879/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2467
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2467/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2980
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2980/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2450
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2450/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2183
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2183/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2199
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2199/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2458
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2458/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2476
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2476/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2232
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2232/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2972
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2972/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2488
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2488/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2231
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2231/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2221
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2221/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2489
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2489/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2164
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2164/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2340
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2340/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3007
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3007/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2254
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2254/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2375
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2375/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2165
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2165/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2168
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2168/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2314
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2314/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2961
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2961/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2368
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2368/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2378
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2378/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2195
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2195/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2787
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2787/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2159
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2159/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2306
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2306/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2296
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2296/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2520
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2520/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2372
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2372/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2504
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2504/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2321
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2321/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2658
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2658/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2277
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2277/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2516
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2516/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2033
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2033/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2224
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2224/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2302
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2302/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2987
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2987/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3021
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3021/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2276
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2276/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3018
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3018/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2370
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2370/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2201
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2201/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2402
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2402/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2153
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2153/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2621
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2621/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2956
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2956/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2162
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2162/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3023
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3023/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2425
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2425/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2925
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2925/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2978
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2978/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-3011
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-3011/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2548
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2548/metadata
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/revivemed/RCC/e/RCC-2390
# [neptune] [info   ] Shutting down background jobs, please wait a moment...
# [neptune] [info   ] Done!
# [neptune] [info   ] Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# [neptune] [info   ] All 1 operations synced, thanks for waiting!
# [neptune] [info   ] Explore the metadata in the Neptune app: https://app.neptune.ai/revivemed/RCC/e/RCC-2390/metadata
