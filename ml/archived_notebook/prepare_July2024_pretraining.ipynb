# %% [markdown]
# # Preparing new pretraining data
#
# We want to update our pretraining data, to add more data and improve the associated metadata. Here is a list of changes
# - we were to aggressive at removing outlier samples for some studies, so we want to make sure more samples are included
# - we want to add new studies to the pretraining data
# - some of the metadata was incomplete previously, we want to fix that
#
# other possible changes
# - include studies that were previously aligned, but excluded to not the best alignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load the features ids used in pretraining

# %%
x_rcc_test_file = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/April_30_Finetune_Data/X_finetune_test.csv'
x_rcc_test = pd.read_csv(x_rcc_test_file, index_col=0)
pretrain_feats = x_rcc_test.columns

save_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/July_05_Data'

# %%
def align_to_existing(input_intensity_matrix, pretrain_features, align_input,fill_na=False,std_scale=False):
    
    if 'FT' not in input_intensity_matrix.columns[0][:2]:
        input_intensity_matrix = input_intensity_matrix.T

    if isinstance(align_input,pd.DataFrame):
        align_input = align_input.iloc[:,0].copy()

    common_pretrained_features = list(set(pretrain_features).intersection(align_input.index))
    align_input = align_input[common_pretrained_features].copy()
    
    input_features_aligned = align_input.values.tolist()
    pretrain_features_aligned = align_input.index.tolist()
    if isinstance(pretrain_features, pd.Index):
        pretrain_features = pretrain_features.tolist()
    

    output_matrix = np.empty((input_intensity_matrix.shape[0], len(pretrain_features)), dtype=float)
    output_matrix = output_matrix * np.nan
    output_matrix[:, [pretrain_features.index(f) for f in pretrain_features_aligned]] = input_intensity_matrix[input_features_aligned].values

    intensity_df = pd.DataFrame(output_matrix, index=input_intensity_matrix.index, columns=pretrain_features)
    nan_df = intensity_df.isnull()

    if std_scale:
        scaler = StandardScaler()
        intensity_df = pd.DataFrame(scaler.fit_transform(intensity_df), index=intensity_df.index, columns=intensity_df.columns)
        
    if fill_na:
        # Fill partial missing values with the mean of the feature
        partial_missing = intensity_df.loc[:,pretrain_features_aligned].copy()
        full_missing = intensity_df.loc[:, [f for f in pretrain_features if f not in pretrain_features_aligned]].copy()
        partial_missing.fillna(partial_missing.mean(), inplace=True)

        # fill complete missing values rest with the mean of row
        full_missing = full_missing.T
        full_missing.fillna(intensity_df.mean(axis=1), inplace=True)
        full_missing = full_missing.T

        intensity_df = pd.concat([partial_missing, full_missing], axis=1)
        intensity_df = intensity_df[pretrain_features]


    return intensity_df, nan_df

# %%
def load_raw_data(main_dir, num, alignment_df):
    peaks_intensity_file = f'{main_dir}/{num}_final_peaks_intensity_max.csv'
    peak_info_file = f'{main_dir}/{num}_final_peaks_peak_info.csv'

    peaks_intensity = pd.read_csv(peaks_intensity_file, index_col=0)
    peak_info = pd.read_csv(peak_info_file, index_col=0)

    selected_peaks = alignment_df[f'{num}'].copy()
    selected_peaks.dropna(inplace=True)
    peak_info = peak_info.loc[selected_peaks.values].copy()
    peaks_intensity = peaks_intensity.loc[selected_peaks.values].copy()
    
    peak_info.index = selected_peaks.index.tolist()
    peaks_intensity.index = selected_peaks.index.tolist()

    peak_info['exists'] = 1
    return peaks_intensity, peak_info

# %%
import seaborn as sns
import umap
from sklearn.decomposition import PCA

def generate_pca_embedding(matrix, n_components=2):
    pca = PCA(n_components=n_components)
    embedding = pca.fit_transform(matrix.T)
    return embedding

def generate_umap_embedding(matrix, n_components=2):

    reducer = umap.UMAP(n_components=n_components)
    embedding = reducer.fit_transform(matrix.T)
    return embedding

def plot_pca(embedding,metadata,col_name,yes_umap=False):

    if yes_umap:
        xvar = 'UMAP1'
        yvar = 'UMAP2'
    else:
        xvar = 'PCA1'
        yvar = 'PCA2'
    if metadata[col_name].nunique() < 10:
        palette = sns.color_palette("tab10", metadata[col_name].nunique())
        sns.scatterplot(x=embedding[:,0], y=embedding[:,1], hue=metadata[col_name], palette=palette)
    else:
        sns.scatterplot(x=embedding[:,0], y=embedding[:,1], hue=metadata[col_name])
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title=col_name)
    plt.xlabel(xvar)
    plt.ylabel(yvar)

    # add counts to the legend
    handles, labels = plt.gca().get_legend_handles_labels()
    if metadata[col_name].nunique() < 15:
        labels = [f'{x} ({metadata[metadata[col_name]==x].shape[0]})' for x in labels]
        plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title=col_name,
            ncol=2)  # ncol=2 makes the legend have 2 columns

    # add the number of samples to the title
    plt.title(f'N samples = {metadata[~metadata[col_name].isna()].shape[0]}')

# %% [markdown]
# ## Add the Stanford BMI Data set

# %%
standford_data_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/stanford-hmp2'

new_alignment_df = pd.read_csv(f'{standford_data_dir}/alignment_df.csv', index_col=0)
# intensity_matrix = pd.read_csv(f'{main_dir}/combined_study.csv', index_col=0)
new_metadata = pd.read_csv(f'{standford_data_dir}/stanford-hmp2_metadata.tsv', index_col=0, sep='\t')

new_alignment_df.dropna(axis=0, how='all', inplace=True)

# %%
new_metadata['file name'] = new_metadata.index
new_metadata['mzml_file'] = new_metadata['file name'].apply(lambda x: x+'.mzML')
new_metadata.index = new_metadata['mzml_file']

# %%
sample_info = pd.read_csv(f'{standford_data_dir}/sample_info.csv', index_col=0)
new_metadata =new_metadata.join(sample_info)

# %%
new_metadata.head()
# Out:
#                                subject ID Study Race    Age    BMI   SSPG  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML    ZN3TBJM   HMP    C  67.47  30.18  133.5
# ZNED4XZ-4014_HILIC-pos-B1.mzML    ZNED4XZ   HMP    C  59.21  31.64    NaN
# ZLZNCLZ-2013_HILIC-pos-B1.mzML    ZLZNCLZ   HMP    C  54.74  27.33  130.0
# ZLZQMEV-07_HILIC-pos-B1.mzML      ZLZQMEV   HMP    H  61.00  29.99  221.0
# ZN0JE53-02_HILIC-pos-B1.mzML      ZN0JE53   HMP    B  66.81  33.32  148.0
#
#                                IR_IS_classification  CollectionDate  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML                   IS           623.0
# ZNED4XZ-4014_HILIC-pos-B1.mzML              Unknown           503.0
# ZLZNCLZ-2013_HILIC-pos-B1.mzML                   IS           622.0
# ZLZQMEV-07_HILIC-pos-B1.mzML                     IR           727.0
# ZN0JE53-02_HILIC-pos-B1.mzML                     IS           327.0
#
#                                       Event Event_Note1  Event_Note2  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML    Infection          D7          NaN
# ZNED4XZ-4014_HILIC-pos-B1.mzML        Ant_L         D21  amoxicillin
# ZLZNCLZ-2013_HILIC-pos-B1.mzML          Imz          D3          flu
# ZLZQMEV-07_HILIC-pos-B1.mzML        Healthy         NaN          NaN
# ZN0JE53-02_HILIC-pos-B1.mzML    Weight-gain         NaN          NaN
#
#                                        Event_Note3 SubStudy  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML      Infection_Late      HMP
# ZNED4XZ-4014_HILIC-pos-B1.mzML  Ant_Recovery_Early      HMP
# ZLZNCLZ-2013_HILIC-pos-B1.mzML          Imz_Middle      HMP
# ZLZQMEV-07_HILIC-pos-B1.mzML                   NaN      HMP
# ZN0JE53-02_HILIC-pos-B1.mzML                   NaN      HMP
#
#                                                 file name  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML  ZN3TBJM-1013_HILIC-pos-B1
# ZNED4XZ-4014_HILIC-pos-B1.mzML  ZNED4XZ-4014_HILIC-pos-B1
# ZLZNCLZ-2013_HILIC-pos-B1.mzML  ZLZNCLZ-2013_HILIC-pos-B1
# ZLZQMEV-07_HILIC-pos-B1.mzML      ZLZQMEV-07_HILIC-pos-B1
# ZN0JE53-02_HILIC-pos-B1.mzML      ZN0JE53-02_HILIC-pos-B1
#
#                                                      mzml_file  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML  ZN3TBJM-1013_HILIC-pos-B1.mzML
# ZNED4XZ-4014_HILIC-pos-B1.mzML  ZNED4XZ-4014_HILIC-pos-B1.mzML
# ZLZNCLZ-2013_HILIC-pos-B1.mzML  ZLZNCLZ-2013_HILIC-pos-B1.mzML
# ZLZQMEV-07_HILIC-pos-B1.mzML      ZLZQMEV-07_HILIC-pos-B1.mzML
# ZN0JE53-02_HILIC-pos-B1.mzML      ZN0JE53-02_HILIC-pos-B1.mzML
#
#                                           timestamp  Ref  runtime_hour  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML  2016-12-15 05:17:10    0      8.908333
# ZNED4XZ-4014_HILIC-pos-B1.mzML  2016-12-15 06:37:19    0     10.244167
# ZLZNCLZ-2013_HILIC-pos-B1.mzML  2016-12-15 07:04:03    0     10.689722
# ZLZQMEV-07_HILIC-pos-B1.mzML    2016-12-15 08:24:11    0     12.025278
# ZN0JE53-02_HILIC-pos-B1.mzML    2016-12-15 10:11:02    0     13.806111
#
#                                 batch_id  run_order
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML         0          9
# ZNED4XZ-4014_HILIC-pos-B1.mzML         0         10
# ZLZNCLZ-2013_HILIC-pos-B1.mzML         0         11
# ZLZQMEV-07_HILIC-pos-B1.mzML           0         12
# ZN0JE53-02_HILIC-pos-B1.mzML           0         15

# %%
poolmap_intensity = pd.read_csv(f'{standford_data_dir}/final_peaks_intensity_max_pool_map_norm.csv', index_col=0)

chosen_stanford_feats = new_alignment_df['627'].values
corresponding_rcc_feats = new_alignment_df.index
intensity_matrix = poolmap_intensity.loc[chosen_stanford_feats].copy()

intensity_matrix.index = corresponding_rcc_feats.to_list()
intensity_matrix =intensity_matrix.T

# %%
poolmap_intensity.T
# Out:
# feats                                          FT0  FT1        FT2        FT3  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN  NaN        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN  NaN        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN  NaN        NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN  NaN        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN  NaN  265213.47        NaN
# ...                                            ...  ...        ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      83245.190  NaN  294995.38  542592.75
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      77641.360  NaN  339772.56  539144.00
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      84801.125  NaN  313362.30  524650.30
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      80447.200  NaN  351742.88  512740.00
# Exercise_HILIC-pos_QC40.mzML             88612.670  NaN  265213.47  608087.00
#
# feats                                    FT4        FT5  FT6        FT7  FT8  \
# HILIC-pos-B1_MixAA_Mix.mzML              NaN        NaN  NaN        NaN  NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  NaN        NaN  NaN        NaN  NaN
# HILIC-pos-B1_Mix1.mzML                   NaN        NaN  NaN        NaN  NaN
# HILIC-pos-B1_Mix2.mzML                   NaN        NaN  NaN        NaN  NaN
# HILIC-pos-B1_QC_dln2.mzML                NaN  157939.95  NaN        NaN  NaN
# ...                                      ...        ...  ...        ...  ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      NaN  214767.56  NaN        NaN  NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      NaN  183612.05  NaN        NaN  NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      NaN        NaN  NaN  795.94965  NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      NaN  309821.66  NaN        NaN  NaN
# Exercise_HILIC-pos_QC40.mzML             NaN  150248.28  NaN        NaN  NaN
#
# feats                                          FT9  ...    FT18224    FT18225  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN  ...        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN  ...        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN  ...        NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN  ...        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                267056.44  ...  815534.56  6924039.0
# ...                                            ...  ...        ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN  ...  897814.90  7061255.5
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      355139.47  ...  812780.10  6496396.0
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      284121.16  ...  888073.20  6613621.0
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      293510.10  ...  806536.30  6954056.5
# Exercise_HILIC-pos_QC40.mzML                   NaN  ...  815534.56  6924039.0
#
# feats                                      FT18226    FT18227    FT18228  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN        NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                155024.44   643076.0  3194875.0
# ...                                            ...        ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN        NaN  1227360.6
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML            NaN  1136818.1  5260382.0
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      297330.56   893035.8  4144401.8
# Exercise_HILIC-pos_ZS78KHV-E17.mzML            NaN        NaN  2894244.8
# Exercise_HILIC-pos_QC40.mzML                   NaN   643076.0  3194875.0
#
# feats                                      FT18229     FT18230    FT18231  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN         NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN         NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN         NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN         NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                1934075.0   79294.734        NaN
# ...                                            ...         ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML       717451.7  182185.160        NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      3385265.2  150839.800        NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      2563439.5  157093.830        NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      1692902.9  178348.000  309694.28
# Exercise_HILIC-pos_QC40.mzML             1934075.0  177814.970        NaN
#
# feats                                      FT18232    FT18233
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN  336104.53
# ...                                            ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      107719.99  351409.60
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML            NaN  396408.00
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML            NaN  316532.22
# Exercise_HILIC-pos_ZS78KHV-E17.mzML            NaN  342552.38
# Exercise_HILIC-pos_QC40.mzML                   NaN  336104.53
#
# [977 rows x 17143 columns]

# %%
intensity_df, nan_df = align_to_existing(poolmap_intensity.T, pretrain_feats, new_alignment_df['627'], fill_na=False)

# %%
intensity_df
# Out:
#                                            FT10031  FT10035  FT10037  FT10039  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN      NaN      NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN      NaN      NaN
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN      NaN      NaN
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN      NaN      NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN      NaN      NaN
# ...                                            ...      ...      ...      ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      46977.230      NaN      NaN      NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      42768.723      NaN      NaN      NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      44817.953      NaN      NaN      NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      53393.055      NaN      NaN      NaN
# Exercise_HILIC-pos_QC40.mzML             44912.770      NaN      NaN      NaN
#
#                                            FT10041  FT10042  FT10044  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN      NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN      NaN
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN      NaN
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN      NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN      NaN
# ...                                            ...      ...      ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      227606.17      NaN      NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_QC40.mzML             127973.94      NaN      NaN
#
#                                             FT1006  FT10068  FT1007  ...  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN     NaN  ...
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN     NaN  ...
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN     NaN  ...
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN     NaN  ...
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN     NaN  ...
# ...                                            ...      ...     ...  ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN      NaN     NaN  ...
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      185689.52      NaN     NaN  ...
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML            NaN      NaN     NaN  ...
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      174924.83      NaN     NaN  ...
# Exercise_HILIC-pos_QC40.mzML             257175.40      NaN     NaN  ...
#
#                                          FT9951  FT9975     FT9978    FT9980  \
# HILIC-pos-B1_MixAA_Mix.mzML                 NaN     NaN        NaN       NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     NaN     NaN        NaN       NaN
# HILIC-pos-B1_Mix1.mzML                      NaN     NaN        NaN       NaN
# HILIC-pos-B1_Mix2.mzML                      NaN     NaN        NaN       NaN
# HILIC-pos-B1_QC_dln2.mzML                   NaN     NaN        NaN       NaN
# ...                                         ...     ...        ...       ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         NaN     NaN  174593.28       NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML         NaN     NaN  168597.44       NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML         NaN     NaN  131706.60       NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         NaN     NaN  205738.50       NaN
# Exercise_HILIC-pos_QC40.mzML                NaN     NaN        NaN  95612.94
#
#                                             FT9984     FT9985     FT9988  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN        NaN        NaN
# HILIC-pos-B1_Mix2.mzML                         NaN        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                2488019.0  53221.266  357680.66
# ...                                            ...        ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      1517349.5        NaN  187597.67
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      2315264.2  52879.312  307552.56
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      4097617.8        NaN        NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      2146370.2        NaN        NaN
# Exercise_HILIC-pos_QC40.mzML             2488019.0        NaN        NaN
#
#                                          FT9989     FT9997  FT9999
# HILIC-pos-B1_MixAA_Mix.mzML                 NaN        NaN     NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     NaN        NaN     NaN
# HILIC-pos-B1_Mix1.mzML                      NaN        NaN     NaN
# HILIC-pos-B1_Mix2.mzML                      NaN        NaN     NaN
# HILIC-pos-B1_QC_dln2.mzML                   NaN        NaN     NaN
# ...                                         ...        ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         NaN  455490.88     NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML         NaN  183693.88     NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML         NaN        NaN     NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         NaN        NaN     NaN
# Exercise_HILIC-pos_QC40.mzML                NaN  245367.19     NaN
#
# [977 rows x 2736 columns]

# %%
intensity_df, nan_df = align_to_existing(poolmap_intensity.T, pretrain_feats, new_alignment_df['627'], fill_na=True)

# %%
nan_df.shape
# Out:
# (977, 2736)

# %%
intensity_df
# Out:
#                                               FT10031       FT10035  \
# HILIC-pos-B1_MixAA_Mix.mzML              62629.939478  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  62629.939478  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   62629.939478  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   62629.939478  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                62629.939478  3.685749e+06
# ...                                               ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      46977.230000  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      42768.723000  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      44817.953000  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      53393.055000  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             44912.770000  3.658659e+06
#
#                                               FT10037       FT10039  \
# HILIC-pos-B1_MixAA_Mix.mzML              8.491808e+06  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  1.936779e+08  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   9.290769e+07  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   1.277360e+07  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                3.685749e+06  3.685749e+06
# ...                                               ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      3.869325e+06  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      4.343210e+06  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      3.771212e+06  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      3.655376e+06  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             3.658659e+06  3.658659e+06
#
#                                               FT10041       FT10042  \
# HILIC-pos-B1_MixAA_Mix.mzML              151222.22977  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  151222.22977  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   151222.22977  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   151222.22977  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                151222.22977  3.685749e+06
# ...                                               ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      151222.22977  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      151222.22977  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      227606.17000  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      151222.22977  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             127973.94000  3.658659e+06
#
#                                               FT10044         FT1006  \
# HILIC-pos-B1_MixAA_Mix.mzML              22270.821676  117388.810246
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  22270.821676  117388.810246
# HILIC-pos-B1_Mix1.mzML                   22270.821676  117388.810246
# HILIC-pos-B1_Mix2.mzML                   22270.821676  117388.810246
# HILIC-pos-B1_QC_dln2.mzML                22270.821676  117388.810246
# ...                                               ...            ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      22270.821676  117388.810246
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      22270.821676  185689.520000
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      22270.821676  117388.810246
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      22270.821676  174924.830000
# Exercise_HILIC-pos_QC40.mzML             22270.821676  257175.400000
#
#                                                FT10068        FT1007  ...  \
# HILIC-pos-B1_MixAA_Mix.mzML              121225.651486  8.491808e+06  ...
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  121225.651486  1.936779e+08  ...
# HILIC-pos-B1_Mix1.mzML                   121225.651486  9.290769e+07  ...
# HILIC-pos-B1_Mix2.mzML                   121225.651486  1.277360e+07  ...
# HILIC-pos-B1_QC_dln2.mzML                121225.651486  3.685749e+06  ...
# ...                                                ...           ...  ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      121225.651486  3.869325e+06  ...
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      121225.651486  4.343210e+06  ...
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      121225.651486  3.771212e+06  ...
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      121225.651486  3.655376e+06  ...
# Exercise_HILIC-pos_QC40.mzML             121225.651486  3.658659e+06  ...
#
#                                                FT9951        FT9975  \
# HILIC-pos-B1_MixAA_Mix.mzML              8.491808e+06  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  1.936779e+08  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   9.290769e+07  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   1.277360e+07  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                3.685749e+06  3.685749e+06
# ...                                               ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      3.869325e+06  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      4.343210e+06  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      3.771212e+06  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      3.655376e+06  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             3.658659e+06  3.658659e+06
#
#                                                 FT9978         FT9980  \
# HILIC-pos-B1_MixAA_Mix.mzML              331460.482471  167229.681133
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  331460.482471  167229.681133
# HILIC-pos-B1_Mix1.mzML                   331460.482471  167229.681133
# HILIC-pos-B1_Mix2.mzML                   331460.482471  167229.681133
# HILIC-pos-B1_QC_dln2.mzML                331460.482471  167229.681133
# ...                                                ...            ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      174593.280000  167229.681133
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      168597.440000  167229.681133
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      131706.600000  167229.681133
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      205738.500000  167229.681133
# Exercise_HILIC-pos_QC40.mzML             331460.482471   95612.940000
#
#                                                FT9984        FT9985  \
# HILIC-pos-B1_MixAA_Mix.mzML              3.567771e+06  48458.520951
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  3.567771e+06  48458.520951
# HILIC-pos-B1_Mix1.mzML                   3.567771e+06  48458.520951
# HILIC-pos-B1_Mix2.mzML                   3.567771e+06  48458.520951
# HILIC-pos-B1_QC_dln2.mzML                2.488019e+06  53221.266000
# ...                                               ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      1.517350e+06  48458.520951
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      2.315264e+06  52879.312000
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      4.097618e+06  48458.520951
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      2.146370e+06  48458.520951
# Exercise_HILIC-pos_QC40.mzML             2.488019e+06  48458.520951
#
#                                                 FT9988        FT9989  \
# HILIC-pos-B1_MixAA_Mix.mzML              406988.364588  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  406988.364588  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   406988.364588  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   406988.364588  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                357680.660000  3.685749e+06
# ...                                                ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      187597.670000  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      307552.560000  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      406988.364588  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      406988.364588  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             406988.364588  3.658659e+06
#
#                                                 FT9997        FT9999
# HILIC-pos-B1_MixAA_Mix.mzML              333734.387571  8.491808e+06
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  333734.387571  1.936779e+08
# HILIC-pos-B1_Mix1.mzML                   333734.387571  9.290769e+07
# HILIC-pos-B1_Mix2.mzML                   333734.387571  1.277360e+07
# HILIC-pos-B1_QC_dln2.mzML                333734.387571  3.685749e+06
# ...                                                ...           ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      455490.880000  3.869325e+06
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      183693.880000  4.343210e+06
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      333734.387571  3.771212e+06
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      333734.387571  3.655376e+06
# Exercise_HILIC-pos_QC40.mzML             245367.190000  3.658659e+06
#
# [977 rows x 2736 columns]

# %%
pretrain_feats
# Out:
# Index(['FT10031', 'FT10035', 'FT10037', 'FT10039', 'FT10041', 'FT10042',
#        'FT10044', 'FT1006', 'FT10068', 'FT1007',
#        ...
#        'FT9951', 'FT9975', 'FT9978', 'FT9980', 'FT9984', 'FT9985', 'FT9988',
#        'FT9989', 'FT9997', 'FT9999'],
#       dtype='object', length=2736)

# %%
intensity_df
# Out:
#                                            FT10031  FT10035  FT10037  FT10039  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN      NaN      NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN      NaN      NaN
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN      NaN      NaN
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN      NaN      NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN      NaN      NaN
# ...                                            ...      ...      ...      ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      46977.230      NaN      NaN      NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      42768.723      NaN      NaN      NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      44817.953      NaN      NaN      NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      53393.055      NaN      NaN      NaN
# Exercise_HILIC-pos_QC40.mzML             44912.770      NaN      NaN      NaN
#
#                                            FT10041  FT10042  FT10044  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN      NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN      NaN
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN      NaN
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN      NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN      NaN
# ...                                            ...      ...      ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML      227606.17      NaN      NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML            NaN      NaN      NaN
# Exercise_HILIC-pos_QC40.mzML             127973.94      NaN      NaN
#
#                                             FT1006  FT10068  FT1007  ...  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN      NaN     NaN  ...
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN      NaN     NaN  ...
# HILIC-pos-B1_Mix1.mzML                         NaN      NaN     NaN  ...
# HILIC-pos-B1_Mix2.mzML                         NaN      NaN     NaN  ...
# HILIC-pos-B1_QC_dln2.mzML                      NaN      NaN     NaN  ...
# ...                                            ...      ...     ...  ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML            NaN      NaN     NaN  ...
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML      185689.52      NaN     NaN  ...
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML            NaN      NaN     NaN  ...
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      174924.83      NaN     NaN  ...
# Exercise_HILIC-pos_QC40.mzML             257175.40      NaN     NaN  ...
#
#                                          FT4759     FT8646  FT6517  FT7280  \
# HILIC-pos-B1_MixAA_Mix.mzML                 NaN        NaN     NaN     NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     NaN        NaN     NaN     NaN
# HILIC-pos-B1_Mix1.mzML                      NaN        NaN     NaN     NaN
# HILIC-pos-B1_Mix2.mzML                      NaN        NaN     NaN     NaN
# HILIC-pos-B1_QC_dln2.mzML                   NaN  1280647.0     NaN     NaN
# ...                                         ...        ...     ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         NaN  1599719.5     NaN     NaN
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML         NaN        NaN     NaN     NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML         NaN        NaN     NaN     NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         NaN  1623645.2     NaN     NaN
# Exercise_HILIC-pos_QC40.mzML                NaN  1280647.0     NaN     NaN
#
#                                               FT356     FT8631     FT3831  \
# HILIC-pos-B1_MixAA_Mix.mzML              144651.810        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML         NaN        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                          NaN        NaN        NaN
# HILIC-pos-B1_Mix2.mzML                          NaN        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                       NaN  381455.90  3776721.5
# ...                                             ...        ...        ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML       93809.740  229536.55  2228232.5
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML             NaN  626872.30        NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML       96105.300        NaN  3289216.5
# Exercise_HILIC-pos_ZS78KHV-E17.mzML       89151.220  309453.22  3271470.0
# Exercise_HILIC-pos_QC40.mzML              83201.945  381455.90  3776721.5
#
#                                            FT10160     FT10948       FT2628
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN         NaN          NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN         NaN          NaN
# HILIC-pos-B1_Mix1.mzML                         NaN         NaN  4675676.500
# HILIC-pos-B1_Mix2.mzML                         NaN         NaN          NaN
# HILIC-pos-B1_QC_dln2.mzML                      NaN   76910.984          NaN
# ...                                            ...         ...          ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML      36177.050   98034.760   154725.700
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML            NaN  177716.480   134533.690
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML            NaN  139223.830    93415.555
# Exercise_HILIC-pos_ZS78KHV-E17.mzML      46878.645  153185.110   236896.390
# Exercise_HILIC-pos_QC40.mzML                   NaN   84085.170   138880.970
#
# [977 rows x 3157 columns]

# %%
len(pretrain_feats)
# Out:
# 2736

# %%
nan_df
# Out:
#                                          FT10031  FT10035  FT10037  FT10039  \
# HILIC-pos-B1_MixAA_Mix.mzML                 True     True     True     True
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     True     True     True     True
# HILIC-pos-B1_Mix1.mzML                      True     True     True     True
# HILIC-pos-B1_Mix2.mzML                      True     True     True     True
# HILIC-pos-B1_QC_dln2.mzML                   True     True     True     True
# ...                                          ...      ...      ...      ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML        False     True     True     True
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML        False     True     True     True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML        False     True     True     True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML        False     True     True     True
# Exercise_HILIC-pos_QC40.mzML               False     True     True     True
#
#                                          FT10041  FT10042  FT10044  FT1006  \
# HILIC-pos-B1_MixAA_Mix.mzML                 True     True     True    True
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     True     True     True    True
# HILIC-pos-B1_Mix1.mzML                      True     True     True    True
# HILIC-pos-B1_Mix2.mzML                      True     True     True    True
# HILIC-pos-B1_QC_dln2.mzML                   True     True     True    True
# ...                                          ...      ...      ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         True     True     True    True
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML         True     True     True   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML        False     True     True    True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         True     True     True   False
# Exercise_HILIC-pos_QC40.mzML               False     True     True   False
#
#                                          FT10068  FT1007  ...  FT4759  FT8646  \
# HILIC-pos-B1_MixAA_Mix.mzML                 True    True  ...    True    True
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML     True    True  ...    True    True
# HILIC-pos-B1_Mix1.mzML                      True    True  ...    True    True
# HILIC-pos-B1_Mix2.mzML                      True    True  ...    True    True
# HILIC-pos-B1_QC_dln2.mzML                   True    True  ...    True   False
# ...                                          ...     ...  ...     ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         True    True  ...    True   False
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML         True    True  ...    True    True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML         True    True  ...    True    True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         True    True  ...    True   False
# Exercise_HILIC-pos_QC40.mzML                True    True  ...    True   False
#
#                                          FT6517  FT7280  FT356  FT8631  \
# HILIC-pos-B1_MixAA_Mix.mzML                True    True  False    True
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML    True    True   True    True
# HILIC-pos-B1_Mix1.mzML                     True    True   True    True
# HILIC-pos-B1_Mix2.mzML                     True    True   True    True
# HILIC-pos-B1_QC_dln2.mzML                  True    True   True   False
# ...                                         ...     ...    ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML        True    True  False   False
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML        True    True   True   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML        True    True  False    True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML        True    True  False   False
# Exercise_HILIC-pos_QC40.mzML               True    True  False   False
#
#                                          FT3831  FT10160  FT10948  FT2628
# HILIC-pos-B1_MixAA_Mix.mzML                True     True     True    True
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML    True     True     True    True
# HILIC-pos-B1_Mix1.mzML                     True     True     True   False
# HILIC-pos-B1_Mix2.mzML                     True     True     True    True
# HILIC-pos-B1_QC_dln2.mzML                 False     True    False    True
# ...                                         ...      ...      ...     ...
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML       False    False    False   False
# Exercise_HILIC-pos_ZJBOZ2X-E13.mzML        True     True    False   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML       False     True    False   False
# Exercise_HILIC-pos_ZS78KHV-E17.mzML       False    False    False   False
# Exercise_HILIC-pos_QC40.mzML              False     True    False   False
#
# [977 rows x 3157 columns]

# %%
intensity_df.shape
# Out:
# (977, 3157)

# %%
intensity_matrix.head()
# Out:
#                                            FT1740    FT2429  FT9541  FT1566  \
# HILIC-pos-B1_MixAA_Mix.mzML                   NaN       NaN     NaN     NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML  401781.3       NaN     NaN     NaN
# HILIC-pos-B1_Mix1.mzML                        NaN       NaN     NaN     NaN
# HILIC-pos-B1_Mix2.mzML                        NaN       NaN     NaN     NaN
# HILIC-pos-B1_QC_dln2.mzML                     NaN  59037.68     NaN     NaN
#
#                                              FT2371    FT9470     FT9138  \
# HILIC-pos-B1_MixAA_Mix.mzML              1319073.60       NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML         NaN       NaN        NaN
# HILIC-pos-B1_Mix1.mzML                          NaN       NaN        NaN
# HILIC-pos-B1_Mix2.mzML                          NaN       NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                 285619.34  499922.2  58759.805
#
#                                            FT8652      FT1361     FT2830  ...  \
# HILIC-pos-B1_MixAA_Mix.mzML                   NaN         NaN  2093184.4  ...
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML       NaN         NaN        NaN  ...
# HILIC-pos-B1_Mix1.mzML                        NaN         NaN        NaN  ...
# HILIC-pos-B1_Mix2.mzML                        NaN         NaN        NaN  ...
# HILIC-pos-B1_QC_dln2.mzML                273990.6  10058815.0   754729.6  ...
#
#                                               FT3849  FT2243    FT10948  \
# HILIC-pos-B1_MixAA_Mix.mzML                      NaN     NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML          NaN     NaN        NaN
# HILIC-pos-B1_Mix1.mzML                           NaN     NaN        NaN
# HILIC-pos-B1_Mix2.mzML                      58591.74     NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                19375052.00     NaN  76910.984
#
#                                             FT9084     FT7192     FT2628  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN        NaN        NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN        NaN        NaN
# HILIC-pos-B1_Mix1.mzML                         NaN        NaN  4675676.5
# HILIC-pos-B1_Mix2.mzML                         NaN        NaN        NaN
# HILIC-pos-B1_QC_dln2.mzML                228600.45  2900373.5        NaN
#
#                                            FT10863    FT5060      FT8220  \
# HILIC-pos-B1_MixAA_Mix.mzML                    NaN       NaN         NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML        NaN       NaN         NaN
# HILIC-pos-B1_Mix1.mzML                         NaN       NaN         NaN
# HILIC-pos-B1_Mix2.mzML                         NaN       NaN         NaN
# HILIC-pos-B1_QC_dln2.mzML                542996.75  99886.93  109823.516
#
#                                              FT2068
# HILIC-pos-B1_MixAA_Mix.mzML                     NaN
# HILIC-pos-B1_MixOrgAcids_MixOthers.mzML   37797.523
# HILIC-pos-B1_Mix1.mzML                   268006.840
# HILIC-pos-B1_Mix2.mzML                    56092.990
# HILIC-pos-B1_QC_dln2.mzML                       NaN
#
# [5 rows x 2188 columns]

# %%
common_feats = [x for x in pretrain_feats if x in intensity_matrix.columns]
missing_feats = [x for x in pretrain_feats if x not in intensity_matrix.columns]
print(f'number of common features with the pretraining data: {len(common_feats)}')
# Out:
# number of common features with the pretraining data: 1767

# %%
new_matrix = intensity_matrix.loc[new_metadata.index][common_feats]
nan_matrix = new_matrix.isna()
new_matrix.fillna(new_matrix.mean(), inplace=True)
new_matrix = np.log2(new_matrix)

# %%
embedding0 = generate_pca_embedding(new_matrix)
# embedding1 = generate_umap_embedding(new_matrix)

# %%
plot_pca(embedding0,new_metadata,col_name='run_order',yes_umap=False)

# %%
# plot_pca(embedding0,new_metadata,col_name='batch_id',yes_umap=False)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
new_matrix_scaled = scaler.fit_transform(new_matrix)
new_matrix_scaled = pd.DataFrame(new_matrix_scaled, index=new_matrix.index, columns=new_matrix.columns)

# new_matrix_scaled = scaler.fit_transform(new_matrix.T)
# new_matrix_scaled = pd.DataFrame(new_matrix_scaled, index=new_matrix.columns, columns=new_matrix.index)

# %%
new_matrix_scaled
# Out:
#                                       FT10031   FT10041   FT10044    FT1006  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       0.186358  1.224664  0.036746  0.198595
# ZNED4XZ-4014_HILIC-pos-B1.mzML       0.186358 -0.950670  0.036746  0.198595
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       0.186358  0.192544  0.036746  0.198595
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.186358  0.692417  0.036746  0.198595
# ZN0JE53-02_HILIC-pos-B1.mzML         0.186358  2.388740  0.036746  0.198595
# ...                                       ...       ...       ...       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  0.740255  0.609584  0.036746  0.198595
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  0.777219  0.192544  0.036746  0.198595
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML -0.513134  0.192544  0.036746  0.198595
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML -0.629662  1.192032  0.036746  0.198595
# Exercise_HILIC-pos_ZS78KHV-E17.mzML -0.196105  0.192544  0.036746  0.807480
#
#                                       FT10068   FT10089   FT10091   FT10094  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       0.216847 -0.303664 -0.181738  0.088649
# ZNED4XZ-4014_HILIC-pos-B1.mzML       2.078724 -1.022031 -1.153912 -1.181512
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       0.216847 -0.509941 -0.664134  0.126904
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.216847  0.625282  0.670005 -0.492546
# ZN0JE53-02_HILIC-pos-B1.mzML         0.216847  1.433589  1.421506 -0.478667
# ...                                       ...       ...       ...       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  0.216847  0.121677  0.193401  0.281822
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  0.216847  0.912476  1.033984  0.281822
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  0.216847 -0.646292 -0.372152  0.281822
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  0.216847  1.191365  1.461875  0.281822
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  0.216847 -0.916941 -0.864122  0.281822
#
#                                       FT10095   FT10097  ...    FT9911  \
# mzml_file                                                ...
# ZN3TBJM-1013_HILIC-pos-B1.mzML      -0.285511 -0.706911  ... -0.984746
# ZNED4XZ-4014_HILIC-pos-B1.mzML      -1.496506 -0.974093  ...  0.460268
# ZLZNCLZ-2013_HILIC-pos-B1.mzML      -0.853287 -1.045700  ...  0.862829
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.135400 -0.136175  ...  0.643500
# ZN0JE53-02_HILIC-pos-B1.mzML         0.947961  1.295392  ...  1.091029
# ...                                       ...       ...  ...       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  0.197042  0.975368  ...  0.257986
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  0.375177  1.159251  ...  1.366577
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  0.841667 -0.409052  ...  0.848205
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  0.425635  1.292507  ...  0.877319
# Exercise_HILIC-pos_ZS78KHV-E17.mzML -1.290860 -1.862697  ...  0.419150
#
#                                        FT9913    FT9914    FT9923    FT9978  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML      -0.934928 -1.223796  0.182880  0.228850
# ZNED4XZ-4014_HILIC-pos-B1.mzML       0.320630 -0.979998  0.392554  0.228850
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       0.790333  0.263439 -1.374072  0.228850
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.575358  0.638497  1.597618  0.228850
# ZN0JE53-02_HILIC-pos-B1.mzML         0.864916  1.065733  0.280477  0.228850
# ...                                       ...       ...       ...       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML -1.118857 -1.551705  0.024371 -2.795734
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  0.858006  0.783471 -0.314504  0.371474
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML -0.152298 -0.314420  0.280477 -1.069834
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  0.821920  0.027216  1.603487 -1.627757
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  0.156117  0.212359 -0.126505 -0.744943
#
#                                        FT9980    FT9984    FT9985    FT9988  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       0.219794  0.325727  0.176770 -1.062739
# ZNED4XZ-4014_HILIC-pos-B1.mzML       0.219794  1.734269  0.176770  1.559238
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       0.219794  0.599078 -0.486266  0.210561
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.219794 -0.015797  0.176770  0.408649
# ZN0JE53-02_HILIC-pos-B1.mzML         0.219794  0.325727 -2.267601 -0.378784
# ...                                       ...       ...       ...       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  0.219794  1.233347  0.176770 -1.297809
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  0.219794 -0.341360  0.176770  0.135517
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  0.219794 -1.002503  0.176770 -0.985986
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  0.219794  0.414432  0.176770  0.282828
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  0.219794 -0.507847  0.176770  0.282828
#
#                                        FT9997
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       0.134830
# ZNED4XZ-4014_HILIC-pos-B1.mzML       0.134830
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       0.134830
# ZLZQMEV-07_HILIC-pos-B1.mzML         0.134830
# ZN0JE53-02_HILIC-pos-B1.mzML         0.134830
# ...                                       ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML -1.005392
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML -0.951888
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  1.040103
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  0.134830
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  0.134830
#
# [726 rows x 1767 columns]

# %%
new_metadata
# Out:
#                                     subject ID Study Race    Age    BMI  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML         ZN3TBJM   HMP    C  67.47  30.18
# ZNED4XZ-4014_HILIC-pos-B1.mzML         ZNED4XZ   HMP    C  59.21  31.64
# ZLZNCLZ-2013_HILIC-pos-B1.mzML         ZLZNCLZ   HMP    C  54.74  27.33
# ZLZQMEV-07_HILIC-pos-B1.mzML           ZLZQMEV   HMP    H  61.00  29.99
# ZN0JE53-02_HILIC-pos-B1.mzML           ZN0JE53   HMP    B  66.81  33.32
# ...                                        ...   ...  ...    ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML    ZN3TBJM   HMP    C  67.47  30.18
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML    ZPMBHPS   HMP    C  54.39  32.29
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML    ZPEL6L3   HMP    C  52.33  24.44
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML    ZWFDEY0   HMP    A  62.92  30.79
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    ZS78KHV   HMP    C  46.05  27.99
#
#                                       SSPG IR_IS_classification  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       133.5                   IS
# ZNED4XZ-4014_HILIC-pos-B1.mzML         NaN              Unknown
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       130.0                   IS
# ZLZQMEV-07_HILIC-pos-B1.mzML         221.0                   IR
# ZN0JE53-02_HILIC-pos-B1.mzML         148.0                   IS
# ...                                    ...                  ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  133.5                   IS
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  104.0                   IS
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML   57.0                   IS
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  257.5                   IR
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    NaN              Unknown
#
#                                      CollectionDate        Event Event_Note1  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML                623.0    Infection          D7
# ZNED4XZ-4014_HILIC-pos-B1.mzML                503.0        Ant_L         D21
# ZLZNCLZ-2013_HILIC-pos-B1.mzML                622.0          Imz          D3
# ZLZQMEV-07_HILIC-pos-B1.mzML                  727.0      Healthy         NaN
# ZN0JE53-02_HILIC-pos-B1.mzML                  327.0  Weight-gain         NaN
# ...                                             ...          ...         ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML          1266.0     Exercise     4 hours
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML          1446.0     Exercise     6 hours
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML          1264.0     Exercise     6 hours
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML          1161.0     Exercise     6 hours
# Exercise_HILIC-pos_ZS78KHV-E17.mzML          1151.0     Exercise     4 hours
#
#                                      Event_Note2         Event_Note3  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML               NaN      Infection_Late
# ZNED4XZ-4014_HILIC-pos-B1.mzML       amoxicillin  Ant_Recovery_Early
# ZLZNCLZ-2013_HILIC-pos-B1.mzML               flu          Imz_Middle
# ZLZQMEV-07_HILIC-pos-B1.mzML                 NaN                 NaN
# ZN0JE53-02_HILIC-pos-B1.mzML                 NaN                 NaN
# ...                                          ...                 ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML          NaN                 NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML          NaN                 NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML          NaN                 NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML          NaN                 NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML          NaN                 NaN
#
#                                      SubStudy                       file name  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML            HMP       ZN3TBJM-1013_HILIC-pos-B1
# ZNED4XZ-4014_HILIC-pos-B1.mzML            HMP       ZNED4XZ-4014_HILIC-pos-B1
# ZLZNCLZ-2013_HILIC-pos-B1.mzML            HMP       ZLZNCLZ-2013_HILIC-pos-B1
# ZLZQMEV-07_HILIC-pos-B1.mzML              HMP         ZLZQMEV-07_HILIC-pos-B1
# ZN0JE53-02_HILIC-pos-B1.mzML              HMP         ZN0JE53-02_HILIC-pos-B1
# ...                                       ...                             ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  Exercise  Exercise_HILIC-pos_ZN3TBJM-E17
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  Exercise  Exercise_HILIC-pos_ZPMBHPS-E18
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  Exercise  Exercise_HILIC-pos_ZPEL6L3-E18
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  Exercise  Exercise_HILIC-pos_ZWFDEY0-E18
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  Exercise  Exercise_HILIC-pos_ZS78KHV-E17
#
#                                                                mzml_file  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML            ZN3TBJM-1013_HILIC-pos-B1.mzML
# ZNED4XZ-4014_HILIC-pos-B1.mzML            ZNED4XZ-4014_HILIC-pos-B1.mzML
# ZLZNCLZ-2013_HILIC-pos-B1.mzML            ZLZNCLZ-2013_HILIC-pos-B1.mzML
# ZLZQMEV-07_HILIC-pos-B1.mzML                ZLZQMEV-07_HILIC-pos-B1.mzML
# ZN0JE53-02_HILIC-pos-B1.mzML                ZN0JE53-02_HILIC-pos-B1.mzML
# ...                                                                  ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  Exercise_HILIC-pos_ZN3TBJM-E17.mzML
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  Exercise_HILIC-pos_ZPMBHPS-E18.mzML
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  Exercise_HILIC-pos_ZPEL6L3-E18.mzML
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  Exercise_HILIC-pos_ZWFDEY0-E18.mzML
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  Exercise_HILIC-pos_ZS78KHV-E17.mzML
#
#                                                timestamp  Ref  runtime_hour  \
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML       2016-12-15 05:17:10    0      8.908333
# ZNED4XZ-4014_HILIC-pos-B1.mzML       2016-12-15 06:37:19    0     10.244167
# ZLZNCLZ-2013_HILIC-pos-B1.mzML       2016-12-15 07:04:03    0     10.689722
# ZLZQMEV-07_HILIC-pos-B1.mzML         2016-12-15 08:24:11    0     12.025278
# ZN0JE53-02_HILIC-pos-B1.mzML         2016-12-15 10:11:02    0     13.806111
# ...                                                  ...  ...           ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  2017-08-10 23:05:36    0   5738.715556
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  2017-08-10 23:32:16    0   5739.160000
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  2017-08-10 23:58:56    0   5739.604444
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  2017-08-11 00:52:19    0   5740.494167
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  2017-08-11 01:19:03    0   5740.939722
#
#                                      batch_id  run_order
# mzml_file
# ZN3TBJM-1013_HILIC-pos-B1.mzML              0          9
# ZNED4XZ-4014_HILIC-pos-B1.mzML              0         10
# ZLZNCLZ-2013_HILIC-pos-B1.mzML              0         11
# ZLZQMEV-07_HILIC-pos-B1.mzML                0         12
# ZN0JE53-02_HILIC-pos-B1.mzML                0         15
# ...                                       ...        ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML         2        970
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML         2        971
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML         2        972
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML         2        974
# Exercise_HILIC-pos_ZS78KHV-E17.mzML         2        975
#
# [726 rows x 20 columns]

# %%
# save the data 
new_matrix_scaled.to_csv(f'{save_dir}/stanford_hmp2_scaled_intensity_matrix.csv')
nan_matrix.to_csv(f'{save_dir}/stanford_hmp2_nan_matrix.csv')
new_metadata.to_csv(f'{save_dir}/stanford_hmp2_metadata.csv')

# %% [markdown]
# ## Add the Shanghai Lung Cancer Data
#
# Already combined the data using `shanghai_lungcancer_May30.ipynb`

# %%
data_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/MS_Data/ST002773_Shanghai_LungCancer'

# alignment_df = pd.read_csv(f'{data_dir}/alignment_df.csv', index_col=0)

# intensity_matrix = pd.read_csv(f'{data_dir}/combined_alignment_46_grid_0/final_peaks/intensity_max_synthetic_norm.csv', index_col=0)
# intensity_matrix = pd.read_csv(f'{data_dir}/combined_alignment_46_grid_0/final_peaks/intensity_max_pool.csv', index_col=0)
intensity_matrix = pd.read_csv(f'{data_dir}/combined/final_peaks/intensity_max_pool.csv', index_col=0)
peak_info = pd.read_csv(f'{data_dir}/combined/final_peaks/peak_info.csv', index_col=0)
# nan_matrix = intensity_matrix.isna()

# %%
metadata = pd.read_csv(f'{data_dir}/metadata_complete.csv', index_col=0)
metadata = metadata.loc[intensity_matrix.columns].copy()
metadata['Ref'] = metadata['Pool'].astype(int)
metadata['batch_id'] = metadata['Batch'].astype(int)

# %%
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler



# # Apply log2 transformation
# combined_norm_int_log2 = np.log2(intensity_matrix).T
# combined_norm_int_log2 = combined_norm_int_log2[peak_info[peak_info['freq'] > 0.6].index.tolist()].copy()
# # Apply standard scaler transformation
# scaler = StandardScaler()
# combined_norm_int_scaled = scaler.fit_transform(combined_norm_int_log2)
# combined_norm_int_scaled = pd.DataFrame(combined_norm_int_scaled, index=combined_norm_int_log2.index)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler



# Apply log2 transformation
combined_norm_int_log2 = np.log2(intensity_matrix).T
combined_norm_int_log2 = combined_norm_int_log2[peak_info[peak_info['freq'] > 0.6].index.tolist()].copy()
# Apply standard scaler transformation
scaler = StandardScaler()
combined_norm_int_scaled = scaler.fit_transform(combined_norm_int_log2)
combined_norm_int_scaled = pd.DataFrame(combined_norm_int_scaled, index=combined_norm_int_log2.index)



print(combined_norm_int_scaled.shape)
# Perform PCA
pca = PCA(n_components=2)
combined_norm_int_scaled.fillna(0, inplace=True)
pca_result = pca.fit_transform(combined_norm_int_scaled)

run_order = metadata.loc[combined_norm_int_scaled.index,'run_order'].values
ref_samples = metadata.loc[combined_norm_int_scaled.index,'Ref'].values
color_norm = plt.Normalize(vmin=0, vmax=metadata['run_order'].max())

# Create PCA plot
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=run_order, cmap='viridis', s=1, norm=color_norm)

plt.scatter(pca_result[:, 0][ref_samples.astype(bool)], 
            pca_result[:, 1][ref_samples.astype(bool)], 
            c=run_order[ref_samples.astype(bool)], cmap='viridis', 
            s=20, norm=color_norm, edgecolors='black', linewidths=0.1)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Plot of Combined Norm Intensity')
plt.show()
# Out:
# (3455, 563)

# %%
intensity_matrix.shape
# Out:
# (1526, 3455)

# %%
intensity_matrix
# Out:
#          F076_200714_M331_001.mzML  F076_200714_M331_009.mzML  \
# FT10040                  14941.562                        NaN
# FT10041                  42115.580                   3471.440
# FT10068                        NaN                        NaN
# FT10089                  95444.836                  95444.836
# FT10091                 234721.600                 229389.700
# ...                            ...                        ...
# FT9914                   95790.200                  95790.200
# FT9916                   40932.880                  40932.880
# FT9972                   56451.280                  56451.280
# FT9975                         NaN                 165785.200
# FT9980                   41290.633                        NaN
#
#          F076_200714_M331_017.mzML  F076_200714_M331_025.mzML  \
# FT10040                 11787.7930                  16726.055
# FT10041                  4959.5464                   7887.721
# FT10068                        NaN                        NaN
# FT10089                 20452.5490                  28792.367
# FT10091                 87425.1500                  86333.055
# ...                            ...                        ...
# FT9914                 169501.7000                 290774.400
# FT9916                  14050.0370                  15618.584
# FT9972                  36462.4500                 175308.670
# FT9975                  54662.9920                  20574.310
# FT9980                  14194.5950                  32366.703
#
#          F076_200714_M331_033.mzML  F076_200714_M331_041.mzML  \
# FT10040                        NaN                   8010.011
# FT10041                  5743.2837                   6464.715
# FT10068                        NaN                        NaN
# FT10089                 56541.4380                  19264.451
# FT10091                202900.8600                 112891.770
# ...                            ...                        ...
# FT9914                  32019.7100                 224171.830
# FT9916                         NaN                  17966.280
# FT9972                 150154.9500                  41028.723
# FT9975                  63192.1760                  96971.664
# FT9980                   5939.4126                  31828.428
#
#          F076_200714_M331_049.mzML  F076_200714_M331_057.mzML  \
# FT10040                  10173.402                  14102.483
# FT10041                   9258.850                   9289.512
# FT10068                        NaN                        NaN
# FT10089                  30673.290                  40674.957
# FT10091                  91865.016                 116852.310
# ...                            ...                        ...
# FT9914                  942178.300                 104008.450
# FT9916                   33984.110                  40137.387
# FT9972                  185485.620                  94401.340
# FT9975                         NaN                        NaN
# FT9980                   62955.560                  15473.339
#
#          F076_200714_M331_065.mzML  F076_200714_M331_073.mzML  ...  \
# FT10040                  6746.3450                        NaN  ...
# FT10041                        NaN                  17430.416  ...
# FT10068                        NaN                        NaN  ...
# FT10089                 17685.5490                  30323.695  ...
# FT10091                        NaN                  74337.195  ...
# ...                            ...                        ...  ...
# FT9914                 190065.1900                 711946.800  ...
# FT9916                   8672.5625                  17928.371  ...
# FT9972                  64429.6300                 112881.170  ...
# FT9975                         NaN                  15344.409  ...
# FT9980                  21783.1430                  60898.715  ...
#
#          F076_201011_M331_209.mzML  F076_201011_M331_217.mzML  \
# FT10040                  3795.2415                  3092.9617
# FT10041                        NaN                        NaN
# FT10068                        NaN                        NaN
# FT10089                 40049.3440                 27835.9280
# FT10091                106568.5000                 68787.7600
# ...                            ...                        ...
# FT9914                  51834.3870                199757.9500
# FT9916                   8415.4590                 17660.6520
# FT9972                  56485.9960                 39669.1000
# FT9975                  39545.0230                 43593.0100
# FT9980                   8865.5480                  7588.6080
#
#          F076_201011_M331_225.mzML  F076_201011_M331_233.mzML  \
# FT10040                  4329.3354                  7676.4480
# FT10041                        NaN                        NaN
# FT10068                        NaN                        NaN
# FT10089                 21277.1170                 41143.0940
# FT10091                 82136.5400                 94622.2600
# ...                            ...                        ...
# FT9914                 153986.3600                 75307.7100
# FT9916                  18670.2130                 12561.8790
# FT9972                  33073.5200                 26273.0980
# FT9975                  77548.1100                 67056.7900
# FT9980                  11346.4040                  6620.9214
#
#          F076_201011_M331_241.mzML  F076_201011_M331_249.mzML  \
# FT10040                   5448.082                  5902.2285
# FT10041                        NaN                        NaN
# FT10068                        NaN                        NaN
# FT10089                  63106.516                 38014.3480
# FT10091                 206190.800                 99149.3360
# ...                            ...                        ...
# FT9914                   65818.240                170065.1200
# FT9916                   10214.681                 14213.7030
# FT9972                   88469.040                 49576.1370
# FT9975                   61482.850                 57295.6370
# FT9980                    6363.258                 10902.9070
#
#          F076_201011_M331_257.mzML  F076_201011_M331_265.mzML  \
# FT10040                  6469.2770                  14941.562
# FT10041                        NaN                        NaN
# FT10068                        NaN                        NaN
# FT10089                 37516.1560                  95444.836
# FT10091                 94807.0860                 198889.900
# ...                            ...                        ...
# FT9914                  68443.1300                  95790.200
# FT9916                  12889.7440                  40932.880
# FT9972                  35604.9340                  56451.280
# FT9975                  73491.4300                 165785.200
# FT9980                   6952.1943                   9464.755
#
#          F076_201011_M331_273.mzML  F076_201011_M331_281.mzML
# FT10040                        NaN                        NaN
# FT10041                        NaN                        NaN
# FT10068                        NaN                        NaN
# FT10089                  95444.836                        NaN
# FT10091                 247623.610                        NaN
# ...                            ...                        ...
# FT9914                   95790.200                        NaN
# FT9916                   40932.880                        NaN
# FT9972                   56451.280                        NaN
# FT9975                  165785.200                        NaN
# FT9980                         NaN                        NaN
#
# [1526 rows x 3455 columns]

# %%
new_matrix = intensity_matrix.T.copy()
nan_matrix = new_matrix.isna()
new_matrix.fillna(new_matrix.mean(), inplace=True)

scaler = StandardScaler()
intensity_matrix_scaled = scaler.fit_transform(new_matrix)
intensity_matrix_scaled = pd.DataFrame(intensity_matrix_scaled, index=new_matrix.index, columns=new_matrix.columns)
# Out:
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
intensity_matrix_scaled
# Out:
#                                 FT10040   FT10041       FT10068   FT10089  \
# F076_200714_M331_001.mzML -1.578331e-01  0.748433 -1.051442e-15  1.071053
# F076_200714_M331_009.mzML  1.268925e-16 -2.303442 -1.051442e-15  1.071053
# F076_200714_M331_017.mzML -2.678364e-01 -2.185920 -1.051442e-15 -1.681753
# F076_200714_M331_025.mzML -9.559012e-02 -1.954671 -1.051442e-15 -1.375616
# F076_200714_M331_033.mzML  1.268925e-16 -2.124026 -1.051442e-15 -0.357007
# ...                                 ...       ...           ...       ...
# F076_201011_M331_249.mzML -4.731245e-01  0.000000 -1.051442e-15 -1.037097
# F076_201011_M331_257.mzML -4.533459e-01  0.000000 -1.051442e-15 -1.055384
# F076_201011_M331_265.mzML -1.578331e-01  0.000000 -1.051442e-15  1.071053
# F076_201011_M331_273.mzML  1.268925e-16  0.000000 -1.051442e-15  1.071053
# F076_201011_M331_281.mzML  1.268925e-16  0.000000 -1.051442e-15  0.000000
#
#                             FT10091       FT10097       FT10098       FT10100  \
# F076_200714_M331_001.mzML  1.596435  9.652436e-01  2.137347e-16  3.372423e-16
# F076_200714_M331_009.mzML  1.496027  3.249452e-16  2.137347e-16  3.372423e-16
# F076_200714_M331_017.mzML -1.177382  3.249452e-16  2.137347e-16  3.372423e-16
# F076_200714_M331_025.mzML -1.197948  3.645618e+00  2.137347e-16  3.372423e-16
# F076_200714_M331_033.mzML  0.997202  2.401776e-01  2.137347e-16  3.372423e-16
# ...                             ...           ...           ...           ...
# F076_201011_M331_249.mzML -0.956598  3.249452e-16  2.137347e-16  3.372423e-16
# F076_201011_M331_257.mzML -1.038369  3.249452e-16 -6.578219e-01 -1.026292e+00
# F076_201011_M331_265.mzML  0.921669  9.163257e-01 -4.058256e-01 -6.343507e-02
# F076_201011_M331_273.mzML  1.839399  1.004240e+00  1.571071e-01  1.061044e+00
# F076_201011_M331_281.mzML  0.000000  3.249452e-16  2.137347e-16  2.427545e+01
#
#                                 FT10101       FT10104  ...        FT9903  \
# F076_200714_M331_001.mzML  2.963685e-01 -4.660346e-01  ... -1.169489e-15
# F076_200714_M331_009.mzML  1.140839e+00  1.607501e-16  ... -1.169489e-15
# F076_200714_M331_017.mzML -7.786468e-01 -7.929551e-01  ... -1.169489e-15
# F076_200714_M331_025.mzML -8.699466e-01  1.607501e-16  ... -1.169489e-15
# F076_200714_M331_033.mzML -7.026889e-01 -7.311092e-01  ... -1.169489e-15
# ...                                 ...           ...  ...           ...
# F076_201011_M331_249.mzML -2.597086e-16 -9.076992e-01  ...  2.294659e+00
# F076_201011_M331_257.mzML -1.052137e+00 -7.133846e-01  ... -4.770479e-01
# F076_201011_M331_265.mzML  3.115905e+00 -2.375814e-01  ...  3.957618e+00
# F076_201011_M331_273.mzML  9.978108e-01  3.761506e-01  ...  3.588025e+00
# F076_201011_M331_281.mzML -2.597086e-16  1.201821e+01  ... -1.169489e-15
#
#                              FT9905    FT9911        FT9912    FT9913  \
# F076_200714_M331_001.mzML -0.469282  0.387517  6.080635e-01  0.407106
# F076_200714_M331_009.mzML -0.469282  0.387517  6.080635e-01  0.407106
# F076_200714_M331_017.mzML -0.785316 -1.019334 -8.949591e-01 -0.005361
# F076_200714_M331_025.mzML -0.986018  0.303809 -7.928754e-01  1.950753
# F076_200714_M331_033.mzML -0.055277  0.000000 -2.768820e-16 -0.874005
# ...                             ...       ...           ...       ...
# F076_201011_M331_249.mzML -0.896825  0.678476 -9.091621e-01  0.748755
# F076_201011_M331_257.mzML -0.999307 -0.871242 -8.775750e-01 -0.365536
# F076_201011_M331_265.mzML -0.469282  0.387517  6.080635e-01  0.407106
# F076_201011_M331_273.mzML -0.469282  0.387517  6.080635e-01  0.407106
# F076_201011_M331_281.mzML  0.000000  0.000000 -2.768820e-16  0.000000
#
#                                  FT9914        FT9916    FT9972        FT9975  \
# F076_200714_M331_001.mzML -3.415218e-01  4.966359e-01 -0.332103  3.110396e-16
# F076_200714_M331_009.mzML -3.415218e-01  4.966359e-01 -0.332103  1.779246e+00
# F076_200714_M331_017.mzML  3.760312e-01 -9.240686e-01 -0.794643 -5.959335e-01
# F076_200714_M331_025.mzML  1.556574e+00 -8.411740e-01  2.418245 -1.324561e+00
# F076_200714_M331_033.mzML -9.623029e-01 -1.922599e-16  1.836191 -4.136266e-01
# ...                                 ...           ...       ...           ...
# F076_201011_M331_249.mzML  3.815159e-01 -9.154191e-01 -0.491194 -5.396621e-01
# F076_201011_M331_257.mzML -6.077350e-01 -9.853877e-01 -0.814486 -1.934854e-01
# F076_201011_M331_265.mzML -3.415218e-01  4.966359e-01 -0.332103  1.779246e+00
# F076_201011_M331_273.mzML -3.415218e-01  4.966359e-01 -0.332103  1.779246e+00
# F076_201011_M331_281.mzML -1.416573e-16 -1.922599e-16  0.000000  3.110396e-16
#
#                              FT9980
# F076_200714_M331_001.mzML  0.436605
# F076_200714_M331_009.mzML  0.000000
# F076_200714_M331_017.mzML -0.726396
# F076_200714_M331_025.mzML  0.053577
# F076_200714_M331_033.mzML -1.080720
# ...                             ...
# F076_201011_M331_249.mzML -0.867680
# F076_201011_M331_257.mzML -1.037250
# F076_201011_M331_265.mzML -0.929407
# F076_201011_M331_273.mzML  0.000000
# F076_201011_M331_281.mzML  0.000000
#
# [3455 rows x 1526 columns]

# %%
nan_matrix
# Out:
#                            FT10040  FT10041  FT10068  FT10089  FT10091  \
# F076_200714_M331_001.mzML    False    False     True    False    False
# F076_200714_M331_009.mzML     True    False     True    False    False
# F076_200714_M331_017.mzML    False    False     True    False    False
# F076_200714_M331_025.mzML    False    False     True    False    False
# F076_200714_M331_033.mzML     True    False     True    False    False
# ...                            ...      ...      ...      ...      ...
# F076_201011_M331_249.mzML    False     True     True    False    False
# F076_201011_M331_257.mzML    False     True     True    False    False
# F076_201011_M331_265.mzML    False     True     True    False    False
# F076_201011_M331_273.mzML     True     True     True    False    False
# F076_201011_M331_281.mzML     True     True     True     True     True
#
#                            FT10097  FT10098  FT10100  FT10101  FT10104  ...  \
# F076_200714_M331_001.mzML    False     True     True    False    False  ...
# F076_200714_M331_009.mzML     True     True     True    False     True  ...
# F076_200714_M331_017.mzML     True     True     True    False    False  ...
# F076_200714_M331_025.mzML    False     True     True    False     True  ...
# F076_200714_M331_033.mzML    False     True     True    False    False  ...
# ...                            ...      ...      ...      ...      ...  ...
# F076_201011_M331_249.mzML     True     True     True     True    False  ...
# F076_201011_M331_257.mzML     True    False    False    False    False  ...
# F076_201011_M331_265.mzML    False    False    False    False    False  ...
# F076_201011_M331_273.mzML    False    False    False    False    False  ...
# F076_201011_M331_281.mzML     True     True    False     True    False  ...
#
#                            FT9903  FT9905  FT9911  FT9912  FT9913  FT9914  \
# F076_200714_M331_001.mzML    True   False   False   False   False   False
# F076_200714_M331_009.mzML    True   False   False   False   False   False
# F076_200714_M331_017.mzML    True   False   False   False   False   False
# F076_200714_M331_025.mzML    True   False   False   False   False   False
# F076_200714_M331_033.mzML    True   False    True    True   False   False
# ...                           ...     ...     ...     ...     ...     ...
# F076_201011_M331_249.mzML   False   False   False   False   False   False
# F076_201011_M331_257.mzML   False   False   False   False   False   False
# F076_201011_M331_265.mzML   False   False   False   False   False   False
# F076_201011_M331_273.mzML   False   False   False   False   False   False
# F076_201011_M331_281.mzML    True    True    True    True    True    True
#
#                            FT9916  FT9972  FT9975  FT9980
# F076_200714_M331_001.mzML   False   False    True   False
# F076_200714_M331_009.mzML   False   False   False    True
# F076_200714_M331_017.mzML   False   False   False   False
# F076_200714_M331_025.mzML   False   False   False   False
# F076_200714_M331_033.mzML    True   False   False   False
# ...                           ...     ...     ...     ...
# F076_201011_M331_249.mzML   False   False   False   False
# F076_201011_M331_257.mzML   False   False   False   False
# F076_201011_M331_265.mzML   False   False   False   False
# F076_201011_M331_273.mzML   False   False   False    True
# F076_201011_M331_281.mzML    True    True    True    True
#
# [3455 rows x 1526 columns]

# %%
# save the data 
intensity_matrix_scaled.to_csv(f'{save_dir}/shanghai_lung_cancer_scaled_intensity_matrix.csv')
nan_matrix.to_csv(f'{save_dir}/shanghai_lung_cancer_nan_matrix.csv')
metadata.to_csv(f'{save_dir}/shanghai_lung_cancer_metadata.csv')

# %% [markdown]
# # Add back Studies previously aligned

# %%
org_alignment_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/alignment_id_36/grid_search_index_1/'

alignment_df = pd.read_csv(f'{org_alignment_dir}/alignment_df.csv', index_col=0)

# %% [markdown]
# ## Add ST000601
#
# Untargeted LC-MS metabolomics analysis of human COPD plasma
# correspond to cohort id 547

# %%
data_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/MS_Data/ST000601/job_id_547'
cohort_id = 547

cohort_align = alignment_df[f'{cohort_id}'].dropna()

# %%
cleaned_metadata_file = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/mzLearn_preTraining/source_metadata/metadata_2025_july_05/metadata_ST000601.csv'

# %%
sample_info = pd.read_csv(f'{data_dir}/sample_info/sample_info.csv', index_col=0)

metadata = pd.read_csv(cleaned_metadata_file, index_col=0)

# %%
sample_info = sample_info.join(metadata)
sample_info.loc[sample_info['Sex'].isna(),'Ref'] = 1

# %%
norm_intensity = pd.read_csv(f'{data_dir}/final_peaks/intensity_max_synthetic_map_norm.csv', index_col=0)
intensity_matrix = norm_intensity.loc[cohort_align].copy()
intensity_matrix.index = cohort_align.index
intensity_matrix.index.name = 'feats'
intensity_matrix = intensity_matrix.T

nan_matrix = intensity_matrix.isna()

# %%
# Fill missing values with the mean of the feature
intensity_matrix.fillna(intensity_matrix.mean(), inplace=True)

# log scale the data
intensity_matrix = np.log2(intensity_matrix)


scaler = StandardScaler()
intensity_matrix_scaled = scaler.fit_transform(intensity_matrix)
intensity_matrix_scaled = pd.DataFrame(intensity_matrix_scaled, index=intensity_matrix.index, columns=intensity_matrix.columns)

# %%
# save the data 
intensity_matrix_scaled.to_csv(f'{save_dir}/ST000601_scaled_intensity_matrix.csv')
nan_matrix.to_csv(f'{save_dir}/ST000601_nan_matrix.csv')

# %%
pca = PCA(n_components=2)
# intensity_matrix_scaled.fillna(0, inplace=True)
pca_result = pca.fit_transform(intensity_matrix_scaled)

run_order = sample_info.loc[intensity_matrix_scaled.index,'run_order'].values
ref_samples = sample_info.loc[intensity_matrix_scaled.index,'Ref'].values
color_norm = plt.Normalize(vmin=0, vmax=sample_info['run_order'].max())

# Create PCA plot
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=run_order, cmap='viridis', s=1, norm=color_norm)

plt.scatter(pca_result[:, 0][ref_samples.astype(bool)], 
            pca_result[:, 1][ref_samples.astype(bool)], 
            c=run_order[ref_samples.astype(bool)], cmap='viridis', 
            s=20, norm=color_norm, edgecolors='black', linewidths=0.1)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Plot of Combined Norm Intensity')
plt.show()

# %% [markdown]
# ## Add ST001422, ST001423
#
# Previously I think I was too quick to remove outliers from this dataset.
# between these two studies, there are another 94 samples that have Sex
# with 48 of those having Age, BMI and cancer information. So we will add these samples back in.
#
# ST001423 corresponds to job ids: 526,  619
#
# ST001422 corresponds to job ids: 502, 618

# %% [markdown]
# #### ST001423

# %%
data_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/MS_Data/ST001423/job_id_526'
cohort_id = 526

cohort_align = alignment_df[f'{cohort_id}'].dropna()

# %%
sample_info = pd.read_csv(f'{data_dir}/sample_info/sample_info.csv', index_col=0)

# %%
norm_intensity = pd.read_csv(f'{data_dir}/final_peaks/intensity_max_synthetic_norm.csv', index_col=0)
intensity_matrix = norm_intensity.loc[cohort_align].copy()
intensity_matrix.index = cohort_align.index
intensity_matrix.index.name = 'feats'
intensity_matrix = intensity_matrix.T

nan_matrix = intensity_matrix.isna()

# %%
intensity_matrix
# Out:
# feats                         FT10041        FT10042       FT10044  \
# VT_160716_M198_001.mzML  8.587461e+05  875294.633297  2.105062e+06
# VT_160716_M198_003.mzML  9.124619e+05  788112.049087  2.043122e+06
# VT_160716_M198_005.mzML  1.085484e+06  727272.263688  2.280466e+06
# VT_160716_M198_007.mzML  1.759386e+06  885801.383355  2.070463e+06
# VT_160716_M198_009.mzML  1.955679e+06  714989.789715  1.955239e+06
# ...                               ...            ...           ...
# VT_160803_M198_129.mzML  7.369636e+05  765809.278064  1.377937e+06
# VT_160803_M198_131.mzML  6.228640e+05  672043.033123  1.541022e+06
# VT_160804_M198_001.mzML  8.243157e+05  583415.370612  1.472584e+06
# VT_160804_M198_003.mzML  6.877563e+05  686028.512447  1.484827e+06
# VT_160804_M198_005.mzML  8.456112e+05  681591.544601  1.313187e+06
#
# feats                           FT1006        FT1007        FT10089  \
# VT_160716_M198_001.mzML  207404.771345  4.405317e+06  526410.528579
# VT_160716_M198_003.mzML            NaN  4.102777e+06  401145.816077
# VT_160716_M198_005.mzML            NaN  3.411883e+06  485499.889783
# VT_160716_M198_007.mzML  388335.218992  5.980412e+06  439659.763452
# VT_160716_M198_009.mzML  409881.363080  6.470084e+06  405398.762880
# ...                                ...           ...            ...
# VT_160803_M198_129.mzML            NaN  5.286394e+06            NaN
# VT_160803_M198_131.mzML            NaN  4.251493e+06  296980.226173
# VT_160804_M198_001.mzML            NaN           NaN  298806.839294
# VT_160804_M198_003.mzML            NaN  5.017244e+06            NaN
# VT_160804_M198_005.mzML            NaN  5.470233e+06  311488.032039
#
# feats                          FT10090        FT10094       FT10097  \
# VT_160716_M198_001.mzML  419229.123493  487331.050081  1.109945e+06
# VT_160716_M198_003.mzML  383430.438921            NaN  1.124473e+06
# VT_160716_M198_005.mzML  457777.059491  438174.099965  1.010791e+06
# VT_160716_M198_007.mzML            NaN  609100.143197  1.278627e+06
# VT_160716_M198_009.mzML  121787.017724  735675.070458  1.103545e+06
# ...                                ...            ...           ...
# VT_160803_M198_129.mzML  271429.105664  642022.660155  7.782616e+05
# VT_160803_M198_131.mzML  288077.407170  405407.454500  6.623390e+05
# VT_160804_M198_001.mzML            NaN            NaN  6.737382e+05
# VT_160804_M198_003.mzML  195493.253984            NaN  7.771110e+05
# VT_160804_M198_005.mzML            NaN            NaN  7.107672e+05
#
# feats                           FT1011  ...         FT9934        FT9935  \
# VT_160716_M198_001.mzML            NaN  ...            NaN  8.381529e+06
# VT_160716_M198_003.mzML            NaN  ...            NaN  8.184426e+06
# VT_160716_M198_005.mzML            NaN  ...            NaN  8.601969e+06
# VT_160716_M198_007.mzML  162901.814139  ...  371806.499478  3.686614e+06
# VT_160716_M198_009.mzML  135628.723005  ...  358228.392718  3.660749e+06
# ...                                ...  ...            ...           ...
# VT_160803_M198_129.mzML            NaN  ...            NaN  7.225843e+06
# VT_160803_M198_131.mzML            NaN  ...            NaN  5.499010e+06
# VT_160804_M198_001.mzML            NaN  ...            NaN  5.056838e+06
# VT_160804_M198_003.mzML            NaN  ...            NaN  5.228611e+06
# VT_160804_M198_005.mzML            NaN  ...            NaN  6.073413e+06
#
# feats                           FT994        FT9951         FT9968  \
# VT_160716_M198_001.mzML  3.743550e+06  2.211643e+06  465997.035612
# VT_160716_M198_003.mzML  3.628291e+06  1.928441e+06  471357.607034
# VT_160716_M198_005.mzML  3.884411e+06  2.004410e+06  587174.359912
# VT_160716_M198_007.mzML  4.181504e+06  2.244477e+06            NaN
# VT_160716_M198_009.mzML           NaN  2.006932e+06            NaN
# ...                               ...           ...            ...
# VT_160803_M198_129.mzML  2.272651e+06  1.949130e+06            NaN
# VT_160803_M198_131.mzML           NaN  2.030582e+06  411079.782712
# VT_160804_M198_001.mzML  2.391190e+06  1.659074e+06  400267.265615
# VT_160804_M198_003.mzML  2.089237e+06  1.782010e+06            NaN
# VT_160804_M198_005.mzML  2.063779e+06  1.828870e+06  334504.756677
#
# feats                          FT9975         FT9980         FT9984  \
# VT_160716_M198_001.mzML  1.214327e+06  520103.844073            NaN
# VT_160716_M198_003.mzML  1.109147e+06            NaN            NaN
# VT_160716_M198_005.mzML  1.313723e+06  616412.861182            NaN
# VT_160716_M198_007.mzML  2.918046e+05  286348.556513  267641.843561
# VT_160716_M198_009.mzML  3.498907e+05  198505.969933            NaN
# ...                               ...            ...            ...
# VT_160803_M198_129.mzML  1.108616e+06  427601.061766  337810.531480
# VT_160803_M198_131.mzML  9.743436e+05            NaN  293335.140024
# VT_160804_M198_001.mzML  8.515235e+05  662945.381070  477828.143833
# VT_160804_M198_003.mzML  8.674068e+05  518173.788841  348378.022315
# VT_160804_M198_005.mzML  8.946421e+05  681181.709967  464037.915187
#
# feats                           FT9989        FT9999
# VT_160716_M198_001.mzML  277010.506008  2.479358e+06
# VT_160716_M198_003.mzML  344385.839425  2.441805e+06
# VT_160716_M198_005.mzML  315028.869924  2.665575e+06
# VT_160716_M198_007.mzML  907209.992047  1.005016e+06
# VT_160716_M198_009.mzML  921778.310944  1.184717e+06
# ...                                ...           ...
# VT_160803_M198_129.mzML            NaN  1.937405e+06
# VT_160803_M198_131.mzML            NaN  1.810755e+06
# VT_160804_M198_001.mzML            NaN  1.607529e+06
# VT_160804_M198_003.mzML            NaN  1.638070e+06
# VT_160804_M198_005.mzML            NaN  1.739838e+06
#
# [1197 rows x 1751 columns]

# %%
cohort_align
# Out:
# feats
# FT10041    FT8647
# FT10042    FT8658
# FT10044    FT8660
# FT1006      FT680
# FT1007      FT702
#             ...
# FT9975     FT8697
# FT9980     FT8650
# FT9984     FT8651
# FT9989     FT8678
# FT9999     FT8644
# Name: 526, Length: 1751, dtype: object

# %%
intensity_matrix.shape
# Out:
# (1197, 1751)

# %%
intensity_matrix.shape
# Out:
# (1197, 1751)

# %%
# Fill missing values with the mean of the feature
intensity_matrix.fillna(intensity_matrix.mean(), inplace=True)

# log scale the data
intensity_matrix = np.log2(intensity_matrix)


scaler = StandardScaler()
intensity_matrix_scaled = scaler.fit_transform(intensity_matrix)
intensity_matrix_scaled = pd.DataFrame(intensity_matrix_scaled, index=intensity_matrix.index, columns=intensity_matrix.columns)

# %%
intensity_matrix_scaled.head()
# Out:
# feats                     FT10041   FT10042   FT10044    FT1006    FT1007  \
# VT_160716_M198_001.mzML -1.734509  1.066084  1.075903 -0.483385 -0.134335
# VT_160716_M198_003.mzML -1.572475  0.499922  0.901769  0.319938 -0.311860
# VT_160716_M198_005.mzML -1.108762  0.066401  1.542551  0.319938 -0.771964
# VT_160716_M198_007.mzML  0.180984  1.130472  0.979275  1.497050  0.628375
# VT_160716_M198_009.mzML  0.463462 -0.025510  0.645419  1.667556  0.824743
#
# feats                     FT10089   FT10090   FT10094   FT10097    FT1011  \
# VT_160716_M198_001.mzML  1.749743  0.835509 -1.624392  1.102296  0.151047
# VT_160716_M198_003.mzML  0.066454  0.581839  0.157168  1.174984  0.151047
# VT_160716_M198_005.mzML  1.248625  1.085500 -1.971178  0.579215  0.151047
# VT_160716_M198_007.mzML  0.634306  0.169244 -0.896951  1.893120 -0.402405
# VT_160716_M198_009.mzML  0.131778 -2.677548 -0.281161  1.069968 -0.978809
#
# feats                    ...    FT9934    FT9935     FT994    FT9951  \
# VT_160716_M198_001.mzML  ...  0.077245  1.730425  0.114955  0.748196
# VT_160716_M198_003.mzML  ...  0.077245  1.648457 -0.012808  0.025352
# VT_160716_M198_005.mzML  ...  0.077245  1.819844  0.265858  0.229180
# VT_160716_M198_007.mzML  ...  1.469492 -1.098542  0.566952  0.825939
# VT_160716_M198_009.mzML  ...  1.235936 -1.122793  0.130693  0.235813
#
# feats                      FT9968    FT9975    FT9980    FT9984    FT9989  \
# VT_160716_M198_001.mzML  1.413115  1.384066 -0.497282  0.240603 -2.558381
# VT_160716_M198_003.mzML  1.486195  1.154030  0.202865  0.240603 -1.977348
# VT_160716_M198_005.mzML  2.889974  1.583825 -0.080389  0.240603 -2.215141
# VT_160716_M198_007.mzML  0.075536 -2.236259 -1.961830 -2.033822  0.607752
# VT_160716_M198_009.mzML  0.075536 -1.775330 -2.860926  0.240603  0.650270
#
# feats                      FT9999
# VT_160716_M198_001.mzML  1.702526
# VT_160716_M198_003.mzML  1.647915
# VT_160716_M198_005.mzML  1.961662
# VT_160716_M198_007.mzML -1.528606
# VT_160716_M198_009.mzML -0.939985
#
# [5 rows x 1751 columns]

# %%
# save the data
intensity_matrix_scaled.to_csv(f'{save_dir}/ST001423_scaled_intensity_matrix.csv')
nan_matrix.to_csv(f'{save_dir}/ST001423_nan_matrix.csv')

# %% [markdown]
# #### ST001422

# %%
data_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/MS_Data/ST001422/job_id_502'
cohort_id = 502

cohort_align = alignment_df[f'{cohort_id}'].dropna()

sample_info = pd.read_csv(f'{data_dir}/sample_info/sample_info.csv', index_col=0)

# %%
sample_info.shape
# Out:
# (2075, 5)

# %%
norm_intensity = pd.read_csv(f'{data_dir}/final_peaks/intensity_max_synthetic_map_norm.csv', index_col=0)
intensity_matrix = norm_intensity.loc[cohort_align].copy()
intensity_matrix.index = cohort_align.index
intensity_matrix.index.name = 'feats'
intensity_matrix = intensity_matrix.T

nan_matrix = intensity_matrix.isna()

# %%
nan_matrix
# Out:
# feats               FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML     True     True     True    False     True     True
# VT_160120_003.mzML     True     True    False    False     True     True
# VT_160120_005.mzML     True     True    False    False     True     True
# VT_160120_007.mzML     True     True    False    False     True     True
# VT_160120_009.mzML     True     True    False    False     True     True
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML     True     True     True     True    False     True
# VT_160226_137.mzML     True     True     True     True    False     True
# VT_160226_139.mzML     True     True     True     True     True     True
# VT_160226_141.mzML     True     True     True     True     True     True
# VT_160226_143.mzML     True     True     True     True     True     True
#
# feats               FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML   False    True    False    False  ...    True   False
# VT_160120_003.mzML   False    True    False    False  ...    True   False
# VT_160120_005.mzML   False    True    False    False  ...   False    True
# VT_160120_007.mzML   False    True    False     True  ...    True   False
# VT_160120_009.mzML   False    True    False     True  ...    True   False
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML    True    True     True     True  ...    True   False
# VT_160226_137.mzML   False    True     True     True  ...    True   False
# VT_160226_139.mzML   False    True     True     True  ...    True   False
# VT_160226_141.mzML   False    True    False     True  ...    True   False
# VT_160226_143.mzML    True    True    False     True  ...    True   False
#
# feats               FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML   False   False   False   False   False    True   False
# VT_160120_003.mzML   False   False   False   False   False   False   False
# VT_160120_005.mzML   False   False   False   False   False    True   False
# VT_160120_007.mzML   False   False   False   False   False   False   False
# VT_160120_009.mzML   False   False   False   False   False   False   False
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML   False   False   False   False   False    True   False
# VT_160226_137.mzML   False   False   False   False   False    True   False
# VT_160226_139.mzML   False   False   False   False   False    True   False
# VT_160226_141.mzML   False   False   False   False   False    True   False
# VT_160226_143.mzML   False   False   False   False   False    True   False
#
# feats               FT9980
# VT_160120_001.mzML    True
# VT_160120_003.mzML    True
# VT_160120_005.mzML    True
# VT_160120_007.mzML    True
# VT_160120_009.mzML    True
# ...                    ...
# VT_160226_135.mzML    True
# VT_160226_137.mzML   False
# VT_160226_139.mzML    True
# VT_160226_141.mzML    True
# VT_160226_143.mzML    True
#
# [2075 rows x 1744 columns]

# %%
intensity_matrix.head()
# Out:
# feats               FT10037  FT10039        FT10041        FT10042  FT10044  \
# VT_160120_001.mzML      NaN      NaN            NaN  187957.421165      NaN
# VT_160120_003.mzML      NaN      NaN  107629.208539  226058.151545      NaN
# VT_160120_005.mzML      NaN      NaN   83969.093770  209951.620417      NaN
# VT_160120_007.mzML      NaN      NaN  129365.258391  189683.402467      NaN
# VT_160120_009.mzML      NaN      NaN  157274.588145  184159.487516      NaN
#
# feats               FT10046         FT1006  FT1007       FT10071  \
# VT_160120_001.mzML      NaN  359245.564998     NaN  1.608179e+05
# VT_160120_003.mzML      NaN  332971.187200     NaN  2.366542e+05
# VT_160120_005.mzML      NaN  472001.902783     NaN  2.820595e+05
# VT_160120_007.mzML      NaN  351268.757686     NaN  1.254452e+06
# VT_160120_009.mzML      NaN  550567.780525     NaN  9.053601e+05
#
# feats                     FT10089  ...         FT9905        FT9907  \
# VT_160120_001.mzML  495586.049898  ...            NaN  3.166531e+06
# VT_160120_003.mzML  503008.988032  ...            NaN  3.543374e+06
# VT_160120_005.mzML  481761.549322  ...  126451.930639           NaN
# VT_160120_007.mzML            NaN  ...            NaN  4.300528e+05
# VT_160120_009.mzML            NaN  ...            NaN  4.486081e+05
#
# feats                     FT9917        FT9928        FT9931        FT9935  \
# VT_160120_001.mzML  9.877261e+06  4.192194e+06  6.561607e+06  1.845750e+07
# VT_160120_003.mzML  1.129879e+07  4.050346e+06  7.434181e+06  1.591167e+07
# VT_160120_005.mzML  1.016082e+07  4.060169e+06  6.921081e+06  1.573615e+07
# VT_160120_007.mzML  1.776446e+06  3.793492e+06  8.722534e+05  4.117061e+06
# VT_160120_009.mzML  8.895423e+05  3.960613e+06  4.134301e+05  2.839923e+06
#
# feats                     FT9951         FT9972        FT9975  FT9980
# VT_160120_001.mzML  4.064930e+06            NaN  1.570743e+06     NaN
# VT_160120_003.mzML  4.353654e+06  100437.682846  1.343764e+06     NaN
# VT_160120_005.mzML  4.114010e+06            NaN  1.340387e+06     NaN
# VT_160120_007.mzML  3.659367e+06  290382.034718  1.015652e+06     NaN
# VT_160120_009.mzML  3.377906e+06  526432.411112  9.503878e+05     NaN
#
# [5 rows x 1744 columns]

# %%
intensity_matrix.shape
# Out:
# (2075, 1744)

# %%
# Fill missing values with the mean of the feature
intensity_matrix.fillna(intensity_matrix.mean(), inplace=True)

# log scale the data
intensity_matrix = np.log2(intensity_matrix)


scaler = StandardScaler()
intensity_matrix_scaled = scaler.fit_transform(intensity_matrix)
intensity_matrix_scaled = pd.DataFrame(intensity_matrix_scaled, index=intensity_matrix.index, columns=intensity_matrix.columns)

# %%
print(intensity_matrix_scaled.shape)
# Out:
# (2075, 1744)

# %%
intensity_matrix_scaled.head()
# Out:
# feats                FT10037   FT10039   FT10041   FT10042   FT10044  \
# VT_160120_001.mzML  0.093245  0.087186  0.146938 -0.113207  0.193099
# VT_160120_003.mzML  0.093245  0.087186 -0.755285  0.668846  0.193099
# VT_160120_005.mzML  0.093245  0.087186 -1.552251  0.355667  0.193099
# VT_160120_007.mzML  0.093245  0.087186 -0.164735 -0.074477  0.193099
# VT_160120_009.mzML  0.093245  0.087186  0.462431 -0.199698  0.193099
#
# feats                FT10046    FT1006    FT1007   FT10071   FT10089  ...  \
# VT_160120_001.mzML  0.045698  0.220885  0.162623 -7.049922  2.928353  ...
# VT_160120_003.mzML  0.045698 -0.068341  0.162623 -5.403614  3.017734  ...
# VT_160120_005.mzML  0.045698  1.260408  0.162623 -4.655655  2.758262  ...
# VT_160120_007.mzML  0.045698  0.135376  0.162623  1.703833  0.072271  ...
# VT_160120_009.mzML  0.045698  1.846729  0.162623  0.314088  0.072271  ...
#
# feats                 FT9905    FT9907    FT9917    FT9928    FT9931  \
# VT_160120_001.mzML  0.123150  5.830387  7.862187  2.201605  6.725855
# VT_160120_003.mzML  0.123150  6.130938  8.362752  1.892175  7.114798
# VT_160120_005.mzML -1.851469  0.189385  7.967557  1.913950  6.892009
# VT_160120_007.mzML  0.123150  0.493929  1.475314  1.303236  0.439633
# VT_160120_009.mzML  0.123150  0.606838 -1.099593  1.690783 -1.886159
#
# feats                 FT9935    FT9951    FT9972    FT9975    FT9980
# VT_160120_001.mzML  8.319380  2.192188  0.256119  1.037220  0.331534
# VT_160120_003.mzML  7.778943  2.756604 -2.357894  0.727733  0.331534
# VT_160120_005.mzML  7.738552  2.290906  0.256119  0.722744  0.331534
# VT_160120_007.mzML  2.856194  1.327647 -0.207083  0.172619  0.331534
# VT_160120_009.mzML  1.503944  0.669335  0.998173  0.040919  0.331534
#
# [5 rows x 1744 columns]

# %%
# save the data
intensity_matrix_scaled.to_csv(f'{save_dir}/ST001422_scaled_intensity_matrix.csv')
nan_matrix.to_csv(f'{save_dir}/ST001422_nan_matrix.csv')

# %%
save_dir
# Out:
# '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/July_05_Data'

# %% [markdown]
# ## Combine all of the metadata and matrixes

# %%
import os

# %%
all_metadata_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/mzLearn_preTraining/source_metadata/metadata_2025_july_05'

all_metadata_files = os.listdir(all_metadata_dir)

# %%
all_metadata_list = []
for file in all_metadata_files:
    study_metadata = pd.read_csv(f'{all_metadata_dir}/{file}', index_col=0)
    if 'mzml path' in study_metadata.columns:
        study_metadata.index = study_metadata['mzml path'].to_list()
    all_metadata_list.append(study_metadata)

# %%
# for i, md in enumerate(all_metadata_list):
#     print(all_metadata_files[i])
#     print(md.columns)
#     print(md.shape)
#     print('')

# %%
all_metadata = pd.concat(all_metadata_list)
all_metadata['is Female']  = all_metadata['Sex'].map({'F':1, 'M':0})

# %%
all_metadata.shape
# Out:
# (25689, 39)

# %%
all_metadata.columns
# Out:
# Index(['Study ID', 'Cohort Label v0', 'Job ID', 'is Pediatric', 'Cancer Risk',
#        'Column', 'Polarity', 'Sex', 'Subject ID', 'Sample_Class', 'Batch',
#        'BMI', 'Benzene_Exposure_Category', 'Smoking Status', 'Age',
#        'Ethnicity', 'Race', 'Treatment', 'Diagnosis', 'Diagnosis Type',
#        'is Female', 'OS', 'OS_Event', 'Timepoint', 'Region', 'IMDC', 'MSKCC',
#        'Dose (mg/kg)', 'PFS', 'PFS_Event', 'ORR', 'Benefit', 'Prior_2',
#        'Clinical Trial Phase', 'Type', 'mzml path', 'Diagnosis Details',
#        'Emphysema/COPD', 'SARS-CoV-2 Positive'],
#       dtype='object')

# %%
all_metadata.to_csv(f'{save_dir}/all_metadata.csv')

# %%
hilic_pos = all_metadata[(all_metadata['Column'] == 'Hilic') & (all_metadata['Polarity'] == 'Positive')].copy()

# %%
hilic_pos[(hilic_pos['Study ID'] == 'ST001422')].shape
# Out:
# (2076, 39)

# %%
hilic_pos[(hilic_pos['Study ID'] == 'ST001423')].shape
# Out:
# (1455, 39)

# %%
hilic_pos
# Out:
#                                  Study ID Cohort Label v0  Job ID  \
# 10jan12_26-r001.mzML             ST000422     adult_other   550.0
# 10jan12_56-r001.mzML             ST000422     adult_other   550.0
# 10jan12_13-r002.mzML             ST000422     adult_other   550.0
# 10jan12_81-r002.mzML             ST000422     adult_other   550.0
# 10jan12_55-r002.mzML             ST000422     adult_other   550.0
# ...                                   ...             ...     ...
# B9_WU350-376_d7_polar_pos.mzML   ST001849     adult_other   504.0
# B9_WU350-377_d7_polar_pos.mzML   ST001849     adult_other   504.0
# B9_WU350-393_d7_polar_pos.mzML   ST001849     adult_other   504.0
# B9_WU350-398_d7_polar_pos.mzML   ST001849     adult_other   504.0
# B9_WU350-229_d84_polar_pos.mzML  ST001849     adult_other   504.0
#
#                                 is Pediatric Cancer Risk Column  Polarity  \
# 10jan12_26-r001.mzML                   False       False  Hilic  Positive
# 10jan12_56-r001.mzML                   False       False  Hilic  Positive
# 10jan12_13-r002.mzML                   False       False  Hilic  Positive
# 10jan12_81-r002.mzML                   False       False  Hilic  Positive
# 10jan12_55-r002.mzML                   False       False  Hilic  Positive
# ...                                      ...         ...    ...       ...
# B9_WU350-376_d7_polar_pos.mzML         False       False  Hilic  Positive
# B9_WU350-377_d7_polar_pos.mzML         False       False  Hilic  Positive
# B9_WU350-393_d7_polar_pos.mzML         False       False  Hilic  Positive
# B9_WU350-398_d7_polar_pos.mzML         False       False  Hilic  Positive
# B9_WU350-229_d84_polar_pos.mzML        False       False  Hilic  Positive
#
#                                  Sex Subject ID Sample_Class  ... PFS_Event  \
# 10jan12_26-r001.mzML             NaN        NaN          NaN  ...       NaN
# 10jan12_56-r001.mzML             NaN        NaN          NaN  ...       NaN
# 10jan12_13-r002.mzML             NaN        NaN          NaN  ...       NaN
# 10jan12_81-r002.mzML             NaN        NaN          NaN  ...       NaN
# 10jan12_55-r002.mzML             NaN        NaN          NaN  ...       NaN
# ...                              ...        ...          ...  ...       ...
# B9_WU350-376_d7_polar_pos.mzML     M  WU350-376          NaN  ...       NaN
# B9_WU350-377_d7_polar_pos.mzML     M  WU350-377          NaN  ...       NaN
# B9_WU350-393_d7_polar_pos.mzML     F  WU350-393          NaN  ...       NaN
# B9_WU350-398_d7_polar_pos.mzML     M  WU350-398          NaN  ...       NaN
# B9_WU350-229_d84_polar_pos.mzML    F  WU350-229          NaN  ...       NaN
#
#                                  ORR Benefit Prior_2  Clinical Trial Phase  \
# 10jan12_26-r001.mzML             NaN     NaN     NaN                   NaN
# 10jan12_56-r001.mzML             NaN     NaN     NaN                   NaN
# 10jan12_13-r002.mzML             NaN     NaN     NaN                   NaN
# 10jan12_81-r002.mzML             NaN     NaN     NaN                   NaN
# 10jan12_55-r002.mzML             NaN     NaN     NaN                   NaN
# ...                              ...     ...     ...                   ...
# B9_WU350-376_d7_polar_pos.mzML   NaN     NaN     NaN                   NaN
# B9_WU350-377_d7_polar_pos.mzML   NaN     NaN     NaN                   NaN
# B9_WU350-393_d7_polar_pos.mzML   NaN     NaN     NaN                   NaN
# B9_WU350-398_d7_polar_pos.mzML   NaN     NaN     NaN                   NaN
# B9_WU350-229_d84_polar_pos.mzML  NaN     NaN     NaN                   NaN
#
#                                 Type mzml path Diagnosis Details  \
# 10jan12_26-r001.mzML             NaN       NaN               NaN
# 10jan12_56-r001.mzML             NaN       NaN               NaN
# 10jan12_13-r002.mzML             NaN       NaN               NaN
# 10jan12_81-r002.mzML             NaN       NaN               NaN
# 10jan12_55-r002.mzML             NaN       NaN               NaN
# ...                              ...       ...               ...
# B9_WU350-376_d7_polar_pos.mzML   NaN       NaN               NaN
# B9_WU350-377_d7_polar_pos.mzML   NaN       NaN               NaN
# B9_WU350-393_d7_polar_pos.mzML   NaN       NaN               NaN
# B9_WU350-398_d7_polar_pos.mzML   NaN       NaN               NaN
# B9_WU350-229_d84_polar_pos.mzML  NaN       NaN               NaN
#
#                                 Emphysema/COPD SARS-CoV-2 Positive
# 10jan12_26-r001.mzML                       NaN                 NaN
# 10jan12_56-r001.mzML                       NaN                 NaN
# 10jan12_13-r002.mzML                       NaN                 NaN
# 10jan12_81-r002.mzML                       NaN                 NaN
# 10jan12_55-r002.mzML                       NaN                 NaN
# ...                                        ...                 ...
# B9_WU350-376_d7_polar_pos.mzML             NaN                 Yes
# B9_WU350-377_d7_polar_pos.mzML             NaN                 Yes
# B9_WU350-393_d7_polar_pos.mzML             NaN                 Yes
# B9_WU350-398_d7_polar_pos.mzML             NaN                 Yes
# B9_WU350-229_d84_polar_pos.mzML            NaN                  No
#
# [22567 rows x 39 columns]

# %%
hilic_pos.columns
# Out:
# Index(['Study ID', 'Cohort Label v0', 'Job ID', 'is Pediatric', 'Cancer Risk',
#        'Column', 'Polarity', 'Sex', 'Subject ID', 'Sample_Class', 'Batch',
#        'BMI', 'Benzene_Exposure_Category', 'Smoking Status', 'Age',
#        'Ethnicity', 'Race', 'Treatment', 'Diagnosis', 'Diagnosis Type',
#        'is Female', 'OS', 'OS_Event', 'Timepoint', 'Region', 'IMDC', 'MSKCC',
#        'Dose (mg/kg)', 'PFS', 'PFS_Event', 'ORR', 'Benefit', 'Prior_2',
#        'Clinical Trial Phase', 'Type', 'mzml path', 'Diagnosis Details',
#        'Emphysema/COPD', 'SARS-CoV-2 Positive'],
#       dtype='object')

# %%
print('Number of samples')
print(hilic_pos.shape[0])

print('Sex counts:')
print(hilic_pos.shape[0] - hilic_pos['Sex'].isna().sum())

print('BMI counts:')
print(hilic_pos.shape[0] - hilic_pos['BMI'].isna().sum())

print('Age counts:')
print(hilic_pos.shape[0] - hilic_pos['Age'].isna().sum())

print('Study Ids')
print(hilic_pos['Study ID'].nunique())
# Out:
# Number of samples
# 22567
# Sex counts:
# 11637
# BMI counts:
# 4104
# Age counts:
# 8841
# Study Ids
# 22

# %%
hilic_pos.hist(column='Age')
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
sns.histplot(y='Study ID', hue='Cohort Label v0', data=hilic_pos)
# Out:
# <Axes: xlabel='Count', ylabel='Study ID'>

# %%
sns.barplot(hilic_pos['Cohort Label v0'].value_counts())
# Out:
# <Axes: xlabel='Cohort Label v0', ylabel='count'>

# %%
hilic_pos['Study ID'].value_counts()
# missing some of the ST001423, ST001422
# Out:
# Study ID
# ST001932       4482
# ST002773       3455
# ST001422       2076
# ST001931       2044
# ST001428       1522
# ST001423       1455
# ST001237       1379
# ST002331       1315
# ST000909        742
# stanfordbmi     726
# ST001849        700
# ST000601        384
# ST002027        356
# ST001408        349
# ST002112        335
# ST001918        273
# ST001236        271
# ST002251        269
# ST001519        158
# ST002244        122
# ST000388         94
# ST000422         60
# Name: count, dtype: int64

# %%
previous_intensity_file = "/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/alignment_id_36/grid_search_index_1/subset_robust_Freq, Cohort Log Size Weighted_0.2_rem_['549', '551', '547']_recompute/X.csv"
previous_nans_file = "/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/alignment_id_36/grid_search_index_1/subset_robust_Freq, Cohort Log Size Weighted_0.2_rem_['549', '551', '547']_recompute/nans.csv"
previous_metadata_file = "/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/development_CohortCombination/alignment_RCC_2024_Feb_27/alignment_id_36/grid_search_index_1/subset_robust_Freq, Cohort Log Size Weighted_0.2_rem_['549', '551', '547']_recompute/y.csv"
previous_intensity = pd.read_csv(previous_intensity_file, index_col=0)
previous_metadata = pd.read_csv(previous_metadata_file, index_col=0)

# %%
previous_metadata.columns
# Out:
# Index(['cohort_id', 'Study ID', 'Cohort Label', 'Cohort ID Expanded',
#        'Study ID Expanded', 'Cohort ID', 'OS', 'OS_Event', 'Age', 'subject ID',
#        'study_week', 'Region', 'Sex', 'Race', 'Dose (mg/kg)', 'phase',
#        'Treatment', 'Prior_2', 'batch_id', 'runtime_hour', 'run_order',
#        'MSKCC', 'ORR', 'Benefit', 'ExtremeResponder', 'PFS', 'PFS_Event', 'MV',
#        'Age_Group', 'Benefit BINARY', 'Benefit ORDINAL', 'Nivo Benefit BINARY',
#        'MSKCC BINARY', 'MSKCC ORDINAL', 'Matt Set', 'Set'],
#       dtype='object')

# %%
previous_metadata.shape
# Out:
# (17685, 36)

# %%
previous_metadata['Study ID Expanded'].value_counts()
# Out:
# Study ID Expanded
# ST001932    4482
# ST001422    2051
# ST001931    2044
# ST001428    1522
# ST001237    1379
# ST002331    1315
# ST001423    1192
# ST000909     742
# ST001849     691
# ST002027     356
# ST001408     349
# ST002112     335
# ST001236     271
# ST001918     271
# ST002251     242
# ST001519     166
# ST002244     122
# ST000388      95
# ST000422      60
# Name: count, dtype: int64

# %%
# drop the 

kept_previous = previous_metadata[~previous_metadata['Study ID Expanded'].isin(['ST000601','ST001422','ST001423'])].copy()

# %%
kept_previous_files = kept_previous.index.to_list()

# %%
previous_intensity.shape
# Out:
# (17685, 2736)

# %%
saved_files = os.listdir(save_dir)
all_intensity = previous_intensity.loc[kept_previous_files].copy()
for file in saved_files:
    if 'scaled_intensity_matrix' in file:
        print(file)
        new_intensity = pd.read_csv(f'{save_dir}/{file}', index_col=0)
        print(new_intensity.shape)
        missing_cols = [x for x in all_intensity.columns if x not in new_intensity.columns]

        missing_mat = np.repeat(new_intensity.mean(axis=1).values, len(missing_cols)).reshape(new_intensity.shape[0], len(missing_cols))
        missing_mat = pd.DataFrame(missing_mat, index=new_intensity.index, columns=missing_cols)
        new_intensity = pd.concat([new_intensity, missing_mat], axis=1)

        all_intensity = pd.concat([all_intensity, new_intensity])

        print(all_intensity.shape)
# Out:
# ST001423_scaled_intensity_matrix.csv
# ST001422_scaled_intensity_matrix.csv
# ST000601_scaled_intensity_matrix.csv
# stanford_hmp2_scaled_intensity_matrix.csv
# shanghai_lung_cancer_scaled_intensity_matrix.csv

# %%
all_intensity.shape
# Out:
# (22288, 3226)

# %%
all_intensity.to_csv(f'{save_dir}/all_intensity_matrix.csv')

# %%
previous_nans = pd.read_csv(previous_nans_file, index_col=0)
saved_files = os.listdir(save_dir)
all_nans = previous_nans.loc[kept_previous_files].copy()

# %%
all_nans = all_nans.astype(int)

# %%
all_nans
# Out:
#                                          FT10031  FT10035  FT10037  FT10039  \
# VT_171028_M314_167.mzML                        1        1        1        1
# VT_170729_M021_175.mzML                        1        1        1        1
# YW_200307_M431_189.mzML                        1        1        1        1
# VT_181116_M338_047.mzML                        1        1        1        1
# VT_170729_M021_179.mzML                        1        1        1        1
# ...                                          ...      ...      ...      ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0        0        0        0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0        0        0        0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0        0        0        0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0        0        0        0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0        0        0        0
#
#                                          FT10041  FT10042  FT10044  FT1006  \
# VT_171028_M314_167.mzML                        1        1        1       1
# VT_170729_M021_175.mzML                        1        1        1       1
# YW_200307_M431_189.mzML                        1        1        1       1
# VT_181116_M338_047.mzML                        1        1        0       1
# VT_170729_M021_179.mzML                        1        1        1       1
# ...                                          ...      ...      ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0        0        0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0        0        0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0        0        1       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0        0        1       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0        0        0       0
#
#                                          FT10068  FT1007  ...  FT9951  FT9975  \
# VT_171028_M314_167.mzML                        1       0  ...       1       1
# VT_170729_M021_175.mzML                        1       0  ...       1       1
# YW_200307_M431_189.mzML                        1       1  ...       1       1
# VT_181116_M338_047.mzML                        1       1  ...       1       1
# VT_170729_M021_179.mzML                        1       0  ...       1       1
# ...                                          ...     ...  ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0       0  ...       0       1
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0       0  ...       0       1
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0       0  ...       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0       0  ...       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0       0  ...       0       0
#
#                                          FT9978  FT9980  FT9984  FT9985  \
# VT_171028_M314_167.mzML                       1       1       1       1
# VT_170729_M021_175.mzML                       1       1       1       1
# YW_200307_M431_189.mzML                       1       1       1       1
# VT_181116_M338_047.mzML                       0       1       1       1
# VT_170729_M021_179.mzML                       1       1       1       1
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML       0       0       0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML       0       0       0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML       0       0       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML       0       0       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML       0       0       0       0
#
#                                          FT9988  FT9989  FT9997  FT9999
# VT_171028_M314_167.mzML                       1       1       1       1
# VT_170729_M021_175.mzML                       1       1       1       1
# YW_200307_M431_189.mzML                       1       1       1       1
# VT_181116_M338_047.mzML                       1       1       1       1
# VT_170729_M021_179.mzML                       1       1       1       1
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML       0       0       0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML       0       0       0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML       0       0       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML       0       0       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML       0       0       0       0
#
# [14442 rows x 2736 columns]

# %%
all_nans = all_nans.astype(int)

for file in saved_files:
    if 'nan_matrix' in file:
        print(file)
        new_nans = pd.read_csv(f'{save_dir}/{file}', index_col=0)
        new_int = pd.read_csv(f'{save_dir}/{file.replace("nan_matrix","scaled_intensity_matrix")}', index_col=0)

        # if 'FT' not in new_nans.columns[0][:2]:
        #     new_nans = new_nans.T

        # missing_cols = [x for x in all_nans.columns if x not in new_nans.columns]

        # missing_mat = np.repeat(new_nans.mean(axis=1).values, len(missing_cols)).reshape(new_nans.shape[0], len(missing_cols))
        # missing_mat[:,:] = False
        # missing_mat = pd.DataFrame(missing_mat, index=new_nans.index, columns=missing_cols)
        # new_nans = pd.concat([new_nans, missing_mat], axis=1)
        # break
        new_nans = new_nans.astype(int)
        

        print(new_nans.shape)
        all_nans = pd.concat([all_nans, new_nans],axis=0)
        print(all_nans.shape)

        break
# Out:
# ST001422_nan_matrix.csv
# (2075, 1744)
# (4811, 16186)

# %%
previous_intensity2 = previous_intensity.loc[kept_previous_files].copy()

# %%
temp = pd.concat([all_nans, new_nans],axis=0)

# %%
[x for x in new_int.columns if x not in previous_intensity2.columns]
# Out:
# ['FT10046',
#  'FT10071',
#  'FT10098',
#  'FT10186',
#  'FT10286',
#  'FT10309',
#  'FT10422',
#  'FT10467',
#  'FT10642',
#  'FT10779',
#  'FT10885',
#  'FT10933',
#  'FT11027',
#  'FT11066',
#  'FT11110',
#  'FT11141',
#  'FT11149',
#  'FT11184',
#  'FT11212',
#  'FT11287',
#  'FT11300',
#  'FT11303',
#  'FT11338',
#  'FT11345',
#  'FT11359',
#  'FT11394',
#  'FT11511',
#  'FT11522',
#  'FT11542',
#  'FT11557',
#  'FT11583',
#  'FT11624',
#  'FT11631',
#  'FT11719',
#  'FT11723',
#  'FT11753',
#  'FT11778',
#  'FT1189',
#  'FT1668',
#  'FT1809',
#  'FT1870',
#  'FT1991',
#  'FT2011',
#  'FT2240',
#  'FT2259',
#  'FT2507',
#  'FT2515',
#  'FT2628',
#  'FT2703',
#  'FT2800',
#  'FT2841',
#  'FT3011',
#  'FT3078',
#  'FT3121',
#  'FT313',
#  'FT327',
#  'FT3299',
#  'FT3357',
#  'FT3366',
#  'FT338',
#  'FT3497',
#  'FT3557',
#  'FT357',
#  'FT3592',
#  'FT3709',
#  'FT3767',
#  'FT3875',
#  'FT3880',
#  'FT3892',
#  'FT3950',
#  'FT4084',
#  'FT4195',
#  'FT4262',
#  'FT4297',
#  'FT4347',
#  'FT4373',
#  'FT4401',
#  'FT4406',
#  'FT4414',
#  'FT442',
#  'FT4575',
#  'FT4586',
#  'FT4642',
#  'FT4845',
#  'FT4859',
#  'FT4869',
#  'FT4876',
#  'FT4912',
#  'FT4930',
#  'FT4931',
#  'FT494',
#  'FT4992',
#  'FT4999',
#  'FT5024',
#  'FT5219',
#  'FT5292',
#  'FT5303',
#  'FT5306',
#  'FT5437',
#  'FT5529',
#  'FT5623',
#  'FT572',
#  'FT5990',
#  'FT6040',
#  'FT618',
#  'FT6223',
#  'FT6646',
#  'FT6726',
#  'FT6805',
#  'FT6857',
#  'FT7270',
#  'FT7308',
#  'FT7476',
#  'FT7540',
#  'FT7752',
#  'FT7813',
#  'FT7830',
#  'FT8016',
#  'FT8226',
#  'FT8317',
#  'FT8406',
#  'FT8610',
#  'FT8661',
#  'FT8855',
#  'FT8895',
#  'FT8899',
#  'FT8904',
#  'FT9036',
#  'FT9078',
#  'FT922',
#  'FT9246',
#  'FT9334',
#  'FT951',
#  'FT9516',
#  'FT9671',
#  'FT969',
#  'FT9707',
#  'FT9972']

# %%
[x for x in new_nans.columns if x not in all_nans.columns]

# %%
[x for x in new_nans.columns if x not in all_nans.columns]
# Out:
# ['FT10046',
#  'FT10071',
#  'FT10098',
#  'FT10186',
#  'FT10286',
#  'FT10309',
#  'FT10422',
#  'FT10467',
#  'FT10642',
#  'FT10779',
#  'FT10885',
#  'FT10933',
#  'FT11027',
#  'FT11066',
#  'FT11110',
#  'FT11141',
#  'FT11149',
#  'FT11184',
#  'FT11212',
#  'FT11287',
#  'FT11300',
#  'FT11303',
#  'FT11338',
#  'FT11345',
#  'FT11359',
#  'FT11394',
#  'FT11511',
#  'FT11522',
#  'FT11542',
#  'FT11557',
#  'FT11583',
#  'FT11624',
#  'FT11631',
#  'FT11719',
#  'FT11723',
#  'FT11753',
#  'FT11778',
#  'FT1189',
#  'FT1668',
#  'FT1809',
#  'FT1870',
#  'FT1991',
#  'FT2011',
#  'FT2240',
#  'FT2259',
#  'FT2507',
#  'FT2515',
#  'FT2628',
#  'FT2703',
#  'FT2800',
#  'FT2841',
#  'FT3011',
#  'FT3078',
#  'FT3121',
#  'FT313',
#  'FT327',
#  'FT3299',
#  'FT3357',
#  'FT3366',
#  'FT338',
#  'FT3497',
#  'FT3557',
#  'FT357',
#  'FT3592',
#  'FT3709',
#  'FT3767',
#  'FT3875',
#  'FT3880',
#  'FT3892',
#  'FT3950',
#  'FT4084',
#  'FT4195',
#  'FT4262',
#  'FT4297',
#  'FT4347',
#  'FT4373',
#  'FT4401',
#  'FT4406',
#  'FT4414',
#  'FT442',
#  'FT4575',
#  'FT4586',
#  'FT4642',
#  'FT4845',
#  'FT4859',
#  'FT4869',
#  'FT4876',
#  'FT4912',
#  'FT4930',
#  'FT4931',
#  'FT494',
#  'FT4992',
#  'FT4999',
#  'FT5024',
#  'FT5219',
#  'FT5292',
#  'FT5303',
#  'FT5306',
#  'FT5437',
#  'FT5529',
#  'FT5623',
#  'FT572',
#  'FT5990',
#  'FT6040',
#  'FT618',
#  'FT6223',
#  'FT6646',
#  'FT6726',
#  'FT6805',
#  'FT6857',
#  'FT7270',
#  'FT7308',
#  'FT7476',
#  'FT7540',
#  'FT7752',
#  'FT7813',
#  'FT7830',
#  'FT8016',
#  'FT8226',
#  'FT8317',
#  'FT8406',
#  'FT8610',
#  'FT8661',
#  'FT8855',
#  'FT8895',
#  'FT8899',
#  'FT8904',
#  'FT9036',
#  'FT9078',
#  'FT922',
#  'FT9246',
#  'FT9334',
#  'FT951',
#  'FT9516',
#  'FT9671',
#  'FT969',
#  'FT9707',
#  'FT9972']

# %%
all_nans
# Out:
#                                          FT10031  FT10035  FT10037  FT10039  \
# VT_171028_M314_167.mzML                        1        1        1        1
# VT_170729_M021_175.mzML                        1        1        1        1
# YW_200307_M431_189.mzML                        1        1        1        1
# VT_181116_M338_047.mzML                        1        1        1        1
# VT_170729_M021_179.mzML                        1        1        1        1
# ...                                          ...      ...      ...      ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0        0        0        0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0        0        0        0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0        0        0        0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0        0        0        0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0        0        0        0
#
#                                          FT10041  FT10042  FT10044  FT1006  \
# VT_171028_M314_167.mzML                        1        1        1       1
# VT_170729_M021_175.mzML                        1        1        1       1
# YW_200307_M431_189.mzML                        1        1        1       1
# VT_181116_M338_047.mzML                        1        1        0       1
# VT_170729_M021_179.mzML                        1        1        1       1
# ...                                          ...      ...      ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0        0        0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0        0        0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0        0        1       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0        0        1       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0        0        0       0
#
#                                          FT10068  FT1007  ...  FT9951  FT9975  \
# VT_171028_M314_167.mzML                        1       0  ...       1       1
# VT_170729_M021_175.mzML                        1       0  ...       1       1
# YW_200307_M431_189.mzML                        1       1  ...       1       1
# VT_181116_M338_047.mzML                        1       1  ...       1       1
# VT_170729_M021_179.mzML                        1       0  ...       1       1
# ...                                          ...     ...  ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML        0       0  ...       0       1
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML        0       0  ...       0       1
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML        0       0  ...       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML        0       0  ...       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML        0       0  ...       0       0
#
#                                          FT9978  FT9980  FT9984  FT9985  \
# VT_171028_M314_167.mzML                       1       1       1       1
# VT_170729_M021_175.mzML                       1       1       1       1
# YW_200307_M431_189.mzML                       1       1       1       1
# VT_181116_M338_047.mzML                       0       1       1       1
# VT_170729_M021_179.mzML                       1       1       1       1
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML       0       0       0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML       0       0       0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML       0       0       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML       0       0       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML       0       0       0       0
#
#                                          FT9988  FT9989  FT9997  FT9999
# VT_171028_M314_167.mzML                       1       1       1       1
# VT_170729_M021_175.mzML                       1       1       1       1
# YW_200307_M431_189.mzML                       1       1       1       1
# VT_181116_M338_047.mzML                       1       1       1       1
# VT_170729_M021_179.mzML                       1       1       1       1
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML       0       0       0       0
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML       0       0       0       0
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML       0       0       0       0
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML       0       0       0       0
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML       0       0       0       0
#
# [14442 rows x 2736 columns]

# %%
len(temp.columns.unique())
# Out:
# 2874

# %%
new_nans
# Out:
#                     FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML        1        1        1        0        1        1
# VT_160120_003.mzML        1        1        0        0        1        1
# VT_160120_005.mzML        1        1        0        0        1        1
# VT_160120_007.mzML        1        1        0        0        1        1
# VT_160120_009.mzML        1        1        0        0        1        1
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML        1        1        1        1        0        1
# VT_160226_137.mzML        1        1        1        1        0        1
# VT_160226_139.mzML        1        1        1        1        1        1
# VT_160226_141.mzML        1        1        1        1        1        1
# VT_160226_143.mzML        1        1        1        1        1        1
#
#                     FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML       0       1        0        0  ...       1       0
# VT_160120_003.mzML       0       1        0        0  ...       1       0
# VT_160120_005.mzML       0       1        0        0  ...       0       1
# VT_160120_007.mzML       0       1        0        1  ...       1       0
# VT_160120_009.mzML       0       1        0        1  ...       1       0
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML       1       1        1        1  ...       1       0
# VT_160226_137.mzML       0       1        1        1  ...       1       0
# VT_160226_139.mzML       0       1        1        1  ...       1       0
# VT_160226_141.mzML       0       1        0        1  ...       1       0
# VT_160226_143.mzML       1       1        0        1  ...       1       0
#
#                     FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML       0       0       0       0       0       1       0
# VT_160120_003.mzML       0       0       0       0       0       0       0
# VT_160120_005.mzML       0       0       0       0       0       1       0
# VT_160120_007.mzML       0       0       0       0       0       0       0
# VT_160120_009.mzML       0       0       0       0       0       0       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML       0       0       0       0       0       1       0
# VT_160226_137.mzML       0       0       0       0       0       1       0
# VT_160226_139.mzML       0       0       0       0       0       1       0
# VT_160226_141.mzML       0       0       0       0       0       1       0
# VT_160226_143.mzML       0       0       0       0       0       1       0
#
#                     FT9980
# VT_160120_001.mzML       1
# VT_160120_003.mzML       1
# VT_160120_005.mzML       1
# VT_160120_007.mzML       1
# VT_160120_009.mzML       1
# ...                    ...
# VT_160226_135.mzML       1
# VT_160226_137.mzML       0
# VT_160226_139.mzML       1
# VT_160226_141.mzML       1
# VT_160226_143.mzML       1
#
# [2075 rows x 1744 columns]

# %%
new_nans.shape
# Out:
# (2075, 1744)

# %%
all_nans.shape
# Out:
# (16186, 4811)

# %%
new_nans
# Out:
#                     FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML        1        1        1        0        1        1
# VT_160120_003.mzML        1        1        0        0        1        1
# VT_160120_005.mzML        1        1        0        0        1        1
# VT_160120_007.mzML        1        1        0        0        1        1
# VT_160120_009.mzML        1        1        0        0        1        1
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML        1        1        1        1        0        1
# VT_160226_137.mzML        1        1        1        1        0        1
# VT_160226_139.mzML        1        1        1        1        1        1
# VT_160226_141.mzML        1        1        1        1        1        1
# VT_160226_143.mzML        1        1        1        1        1        1
#
#                     FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML       0       1        0        0  ...       1       0
# VT_160120_003.mzML       0       1        0        0  ...       1       0
# VT_160120_005.mzML       0       1        0        0  ...       0       1
# VT_160120_007.mzML       0       1        0        1  ...       1       0
# VT_160120_009.mzML       0       1        0        1  ...       1       0
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML       1       1        1        1  ...       1       0
# VT_160226_137.mzML       0       1        1        1  ...       1       0
# VT_160226_139.mzML       0       1        1        1  ...       1       0
# VT_160226_141.mzML       0       1        0        1  ...       1       0
# VT_160226_143.mzML       1       1        0        1  ...       1       0
#
#                     FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML       0       0       0       0       0       1       0
# VT_160120_003.mzML       0       0       0       0       0       0       0
# VT_160120_005.mzML       0       0       0       0       0       1       0
# VT_160120_007.mzML       0       0       0       0       0       0       0
# VT_160120_009.mzML       0       0       0       0       0       0       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML       0       0       0       0       0       1       0
# VT_160226_137.mzML       0       0       0       0       0       1       0
# VT_160226_139.mzML       0       0       0       0       0       1       0
# VT_160226_141.mzML       0       0       0       0       0       1       0
# VT_160226_143.mzML       0       0       0       0       0       1       0
#
#                     FT9980
# VT_160120_001.mzML       1
# VT_160120_003.mzML       1
# VT_160120_005.mzML       1
# VT_160120_007.mzML       1
# VT_160120_009.mzML       1
# ...                    ...
# VT_160226_135.mzML       1
# VT_160226_137.mzML       0
# VT_160226_139.mzML       1
# VT_160226_141.mzML       1
# VT_160226_143.mzML       1
#
# [2075 rows x 1744 columns]

# %%
all_nans
# Out:
#                         FT10031 FT10035 FT10037 FT10039 FT10041 FT10042  \
# VT_171028_M314_167.mzML    True    True    True    True    True    True
# VT_170729_M021_175.mzML    True    True    True    True    True    True
# YW_200307_M431_189.mzML    True    True    True    True    True    True
# VT_181116_M338_047.mzML    True    True    True    True    True    True
# VT_170729_M021_179.mzML    True    True    True    True    True    True
# ...                         ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML          NaN     NaN     NaN     NaN     NaN     NaN
# VT_160226_137.mzML          NaN     NaN     NaN     NaN     NaN     NaN
# VT_160226_139.mzML          NaN     NaN     NaN     NaN     NaN     NaN
# VT_160226_141.mzML          NaN     NaN     NaN     NaN     NaN     NaN
# VT_160226_143.mzML          NaN     NaN     NaN     NaN     NaN     NaN
#
#                         FT10044 FT1006 FT10068 FT1007  ... FT9905 FT9907  \
# VT_171028_M314_167.mzML    True   True    True  False  ...    NaN    NaN
# VT_170729_M021_175.mzML    True   True    True  False  ...    NaN    NaN
# YW_200307_M431_189.mzML    True   True    True   True  ...    NaN    NaN
# VT_181116_M338_047.mzML   False   True    True   True  ...    NaN    NaN
# VT_170729_M021_179.mzML    True   True    True  False  ...    NaN    NaN
# ...                         ...    ...     ...    ...  ...    ...    ...
# VT_160226_135.mzML          NaN    NaN     NaN    NaN  ...   True  False
# VT_160226_137.mzML          NaN    NaN     NaN    NaN  ...   True  False
# VT_160226_139.mzML          NaN    NaN     NaN    NaN  ...   True  False
# VT_160226_141.mzML          NaN    NaN     NaN    NaN  ...   True  False
# VT_160226_143.mzML          NaN    NaN     NaN    NaN  ...   True  False
#
#                         FT9917 FT9928 FT9931 FT9935 FT9951 FT9972 FT9975  \
# VT_171028_M314_167.mzML    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_175.mzML    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# YW_200307_M431_189.mzML    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# VT_181116_M338_047.mzML    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_179.mzML    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                        ...    ...    ...    ...    ...    ...    ...
# VT_160226_135.mzML       False  False  False  False  False   True  False
# VT_160226_137.mzML       False  False  False  False  False   True  False
# VT_160226_139.mzML       False  False  False  False  False   True  False
# VT_160226_141.mzML       False  False  False  False  False   True  False
# VT_160226_143.mzML       False  False  False  False  False   True  False
#
#                         FT9980
# VT_171028_M314_167.mzML    NaN
# VT_170729_M021_175.mzML    NaN
# YW_200307_M431_189.mzML    NaN
# VT_181116_M338_047.mzML    NaN
# VT_170729_M021_179.mzML    NaN
# ...                        ...
# VT_160226_135.mzML        True
# VT_160226_137.mzML       False
# VT_160226_139.mzML        True
# VT_160226_141.mzML        True
# VT_160226_143.mzML        True
#
# [16517 rows x 4480 columns]

# %%
new_nans
# Out:
#                     FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML     True     True     True    False     True     True
# VT_160120_003.mzML     True     True    False    False     True     True
# VT_160120_005.mzML     True     True    False    False     True     True
# VT_160120_007.mzML     True     True    False    False     True     True
# VT_160120_009.mzML     True     True    False    False     True     True
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML     True     True     True     True    False     True
# VT_160226_137.mzML     True     True     True     True    False     True
# VT_160226_139.mzML     True     True     True     True     True     True
# VT_160226_141.mzML     True     True     True     True     True     True
# VT_160226_143.mzML     True     True     True     True     True     True
#
#                     FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML   False    True    False    False  ...    True   False
# VT_160120_003.mzML   False    True    False    False  ...    True   False
# VT_160120_005.mzML   False    True    False    False  ...   False    True
# VT_160120_007.mzML   False    True    False     True  ...    True   False
# VT_160120_009.mzML   False    True    False     True  ...    True   False
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML    True    True     True     True  ...    True   False
# VT_160226_137.mzML   False    True     True     True  ...    True   False
# VT_160226_139.mzML   False    True     True     True  ...    True   False
# VT_160226_141.mzML   False    True    False     True  ...    True   False
# VT_160226_143.mzML    True    True    False     True  ...    True   False
#
#                     FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML   False   False   False   False   False    True   False
# VT_160120_003.mzML   False   False   False   False   False   False   False
# VT_160120_005.mzML   False   False   False   False   False    True   False
# VT_160120_007.mzML   False   False   False   False   False   False   False
# VT_160120_009.mzML   False   False   False   False   False   False   False
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML   False   False   False   False   False    True   False
# VT_160226_137.mzML   False   False   False   False   False    True   False
# VT_160226_139.mzML   False   False   False   False   False    True   False
# VT_160226_141.mzML   False   False   False   False   False    True   False
# VT_160226_143.mzML   False   False   False   False   False    True   False
#
#                     FT9980
# VT_160120_001.mzML    True
# VT_160120_003.mzML    True
# VT_160120_005.mzML    True
# VT_160120_007.mzML    True
# VT_160120_009.mzML    True
# ...                    ...
# VT_160226_135.mzML    True
# VT_160226_137.mzML   False
# VT_160226_139.mzML    True
# VT_160226_141.mzML    True
# VT_160226_143.mzML    True
#
# [2075 rows x 1744 columns]

# %%
new_nans
# Out:
#                     FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML     True     True     True    False     True     True
# VT_160120_003.mzML     True     True    False    False     True     True
# VT_160120_005.mzML     True     True    False    False     True     True
# VT_160120_007.mzML     True     True    False    False     True     True
# VT_160120_009.mzML     True     True    False    False     True     True
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML     True     True     True     True    False     True
# VT_160226_137.mzML     True     True     True     True    False     True
# VT_160226_139.mzML     True     True     True     True     True     True
# VT_160226_141.mzML     True     True     True     True     True     True
# VT_160226_143.mzML     True     True     True     True     True     True
#
#                     FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML   False    True    False    False  ...    True   False
# VT_160120_003.mzML   False    True    False    False  ...    True   False
# VT_160120_005.mzML   False    True    False    False  ...   False    True
# VT_160120_007.mzML   False    True    False     True  ...    True   False
# VT_160120_009.mzML   False    True    False     True  ...    True   False
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML    True    True     True     True  ...    True   False
# VT_160226_137.mzML   False    True     True     True  ...    True   False
# VT_160226_139.mzML   False    True     True     True  ...    True   False
# VT_160226_141.mzML   False    True    False     True  ...    True   False
# VT_160226_143.mzML    True    True    False     True  ...    True   False
#
#                     FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML   False   False   False   False   False    True   False
# VT_160120_003.mzML   False   False   False   False   False   False   False
# VT_160120_005.mzML   False   False   False   False   False    True   False
# VT_160120_007.mzML   False   False   False   False   False   False   False
# VT_160120_009.mzML   False   False   False   False   False   False   False
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML   False   False   False   False   False    True   False
# VT_160226_137.mzML   False   False   False   False   False    True   False
# VT_160226_139.mzML   False   False   False   False   False    True   False
# VT_160226_141.mzML   False   False   False   False   False    True   False
# VT_160226_143.mzML   False   False   False   False   False    True   False
#
#                     FT9980
# VT_160120_001.mzML    True
# VT_160120_003.mzML    True
# VT_160120_005.mzML    True
# VT_160120_007.mzML    True
# VT_160120_009.mzML    True
# ...                    ...
# VT_160226_135.mzML    True
# VT_160226_137.mzML   False
# VT_160226_139.mzML    True
# VT_160226_141.mzML    True
# VT_160226_143.mzML    True
#
# [2075 rows x 1744 columns]

# %%
all_nans.shape
# Out:
# (20667, 2874)

# %%
new_nans.shape
# Out:
# (2075, 1744)

# %%
new_int.shape
# Out:
# (2075, 1744)

# %%
new_int
# Out:
#                      FT10037   FT10039   FT10041   FT10042   FT10044  \
# VT_160120_001.mzML  0.093245  0.087186  0.146938 -0.113207  0.193099
# VT_160120_003.mzML  0.093245  0.087186 -0.755285  0.668846  0.193099
# VT_160120_005.mzML  0.093245  0.087186 -1.552251  0.355667  0.193099
# VT_160120_007.mzML  0.093245  0.087186 -0.164735 -0.074477  0.193099
# VT_160120_009.mzML  0.093245  0.087186  0.462431 -0.199698  0.193099
# ...                      ...       ...       ...       ...       ...
# VT_160226_135.mzML  0.093245  0.087186  0.146938  0.117229 -1.626793
# VT_160226_137.mzML  0.093245  0.087186  0.146938  0.117229 -1.551893
# VT_160226_139.mzML  0.093245  0.087186  0.146938  0.117229  0.193099
# VT_160226_141.mzML  0.093245  0.087186  0.146938  0.117229  0.193099
# VT_160226_143.mzML  0.093245  0.087186  0.146938  0.117229  0.193099
#
#                      FT10046    FT1006    FT1007   FT10071   FT10089  ...  \
# VT_160120_001.mzML  0.045698  0.220885  0.162623 -7.049922  2.928353  ...
# VT_160120_003.mzML  0.045698 -0.068341  0.162623 -5.403614  3.017734  ...
# VT_160120_005.mzML  0.045698  1.260408  0.162623 -4.655655  2.758262  ...
# VT_160120_007.mzML  0.045698  0.135376  0.162623  1.703833  0.072271  ...
# VT_160120_009.mzML  0.045698  1.846729  0.162623  0.314088  0.072271  ...
# ...                      ...       ...       ...       ...       ...  ...
# VT_160226_135.mzML  0.045698  0.204914  0.162623  0.114068  0.072271  ...
# VT_160226_137.mzML  0.045698  0.429783  0.162623  0.114068  0.072271  ...
# VT_160226_139.mzML  0.045698  1.813546  0.162623  0.114068  0.072271  ...
# VT_160226_141.mzML  0.045698  1.428069  0.162623 -5.448842  0.072271  ...
# VT_160226_143.mzML  0.045698  0.204914  0.162623 -4.934696  0.072271  ...
#
#                       FT9905    FT9907    FT9917    FT9928    FT9931  \
# VT_160120_001.mzML  0.123150  5.830387  7.862187  2.201605  6.725855
# VT_160120_003.mzML  0.123150  6.130938  8.362752  1.892175  7.114798
# VT_160120_005.mzML -1.851469  0.189385  7.967557  1.913950  6.892009
# VT_160120_007.mzML  0.123150  0.493929  1.475314  1.303236  0.439633
# VT_160120_009.mzML  0.123150  0.606838 -1.099593  1.690783 -1.886159
# ...                      ...       ...       ...       ...       ...
# VT_160226_135.mzML  0.123150 -0.886139 -0.677279 -0.167225 -1.336225
# VT_160226_137.mzML  0.123150  0.119782 -0.885039 -0.048337 -0.451324
# VT_160226_139.mzML  0.123150  2.143580  2.332047  4.921189  1.021539
# VT_160226_141.mzML  0.123150  2.322336  2.471448  4.681173  1.684924
# VT_160226_143.mzML  0.123150  1.058199  1.916485  5.120317  0.019500
#
#                       FT9935    FT9951    FT9972    FT9975    FT9980
# VT_160120_001.mzML  8.319380  2.192188  0.256119  1.037220  0.331534
# VT_160120_003.mzML  7.778943  2.756604 -2.357894  0.727733  0.331534
# VT_160120_005.mzML  7.738552  2.290906  0.256119  0.722744  0.331534
# VT_160120_007.mzML  2.856194  1.327647 -0.207083  0.172619  0.331534
# VT_160120_009.mzML  1.503944  0.669335  0.998173  0.040919  0.331534
# ...                      ...       ...       ...       ...       ...
# VT_160226_135.mzML  0.367993  0.094666  0.256119  0.174173  0.331534
# VT_160226_137.mzML -0.058759  0.334952  0.256119  0.161167 -2.464373
# VT_160226_139.mzML  1.809844  5.671010  0.256119 -1.215273  0.331534
# VT_160226_141.mzML  2.469160  6.261239  0.256119 -1.632521  0.331534
# VT_160226_143.mzML  2.242402  5.858837  0.256119 -1.550291  0.331534
#
# [2075 rows x 1744 columns]

# %%
new_nans
# Out:
#                     FT10037  FT10039  FT10041  FT10042  FT10044  FT10046  \
# VT_160120_001.mzML     True     True     True    False     True     True
# VT_160120_003.mzML     True     True    False    False     True     True
# VT_160120_005.mzML     True     True    False    False     True     True
# VT_160120_007.mzML     True     True    False    False     True     True
# VT_160120_009.mzML     True     True    False    False     True     True
# ...                     ...      ...      ...      ...      ...      ...
# VT_160226_135.mzML     True     True     True     True    False     True
# VT_160226_137.mzML     True     True     True     True    False     True
# VT_160226_139.mzML     True     True     True     True     True     True
# VT_160226_141.mzML     True     True     True     True     True     True
# VT_160226_143.mzML     True     True     True     True     True     True
#
#                     FT1006  FT1007  FT10071  FT10089  ...  FT9905  FT9907  \
# VT_160120_001.mzML   False    True    False    False  ...    True   False
# VT_160120_003.mzML   False    True    False    False  ...    True   False
# VT_160120_005.mzML   False    True    False    False  ...   False    True
# VT_160120_007.mzML   False    True    False     True  ...    True   False
# VT_160120_009.mzML   False    True    False     True  ...    True   False
# ...                    ...     ...      ...      ...  ...     ...     ...
# VT_160226_135.mzML    True    True     True     True  ...    True   False
# VT_160226_137.mzML   False    True     True     True  ...    True   False
# VT_160226_139.mzML   False    True     True     True  ...    True   False
# VT_160226_141.mzML   False    True    False     True  ...    True   False
# VT_160226_143.mzML    True    True    False     True  ...    True   False
#
#                     FT9917  FT9928  FT9931  FT9935  FT9951  FT9972  FT9975  \
# VT_160120_001.mzML   False   False   False   False   False    True   False
# VT_160120_003.mzML   False   False   False   False   False   False   False
# VT_160120_005.mzML   False   False   False   False   False    True   False
# VT_160120_007.mzML   False   False   False   False   False   False   False
# VT_160120_009.mzML   False   False   False   False   False   False   False
# ...                    ...     ...     ...     ...     ...     ...     ...
# VT_160226_135.mzML   False   False   False   False   False    True   False
# VT_160226_137.mzML   False   False   False   False   False    True   False
# VT_160226_139.mzML   False   False   False   False   False    True   False
# VT_160226_141.mzML   False   False   False   False   False    True   False
# VT_160226_143.mzML   False   False   False   False   False    True   False
#
#                     FT9980
# VT_160120_001.mzML    True
# VT_160120_003.mzML    True
# VT_160120_005.mzML    True
# VT_160120_007.mzML    True
# VT_160120_009.mzML    True
# ...                    ...
# VT_160226_135.mzML    True
# VT_160226_137.mzML   False
# VT_160226_139.mzML    True
# VT_160226_141.mzML    True
# VT_160226_143.mzML    True
#
# [2075 rows x 1744 columns]

# %%
new_nans
# Out:
#                                      FT10031  FT10041  FT10044  FT1006  \
# ZN3TBJM-1013_HILIC-pos-B1.mzML          True    False     True    True
# ZNED4XZ-4014_HILIC-pos-B1.mzML          True    False     True    True
# ZLZNCLZ-2013_HILIC-pos-B1.mzML          True     True     True    True
# ZLZQMEV-07_HILIC-pos-B1.mzML            True    False     True    True
# ZN0JE53-02_HILIC-pos-B1.mzML            True    False     True    True
# ...                                      ...      ...      ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML    False    False     True    True
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML    False     True     True    True
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML    False     True     True    True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML    False    False     True    True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    False     True     True   False
#
#                                      FT10068  FT10089  FT10091  FT10094  \
# ZN3TBJM-1013_HILIC-pos-B1.mzML          True    False    False    False
# ZNED4XZ-4014_HILIC-pos-B1.mzML         False    False    False    False
# ZLZNCLZ-2013_HILIC-pos-B1.mzML          True    False    False    False
# ZLZQMEV-07_HILIC-pos-B1.mzML            True    False    False    False
# ZN0JE53-02_HILIC-pos-B1.mzML            True    False    False    False
# ...                                      ...      ...      ...      ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML     True    False    False     True
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML     True    False    False     True
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML     True    False    False     True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML     True    False    False     True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML     True    False    False     True
#
#                                      FT10095  FT10097  ...  FT9911  FT9913  \
# ZN3TBJM-1013_HILIC-pos-B1.mzML         False    False  ...   False   False
# ZNED4XZ-4014_HILIC-pos-B1.mzML         False    False  ...   False   False
# ZLZNCLZ-2013_HILIC-pos-B1.mzML         False    False  ...   False   False
# ZLZQMEV-07_HILIC-pos-B1.mzML           False    False  ...   False   False
# ZN0JE53-02_HILIC-pos-B1.mzML           False    False  ...   False   False
# ...                                      ...      ...  ...     ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML    False    False  ...    True   False
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML    False    False  ...   False   False
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML    False    False  ...   False   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML    False    False  ...   False   False
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    False    False  ...   False   False
#
#                                      FT9914  FT9923  FT9978  FT9980  FT9984  \
# ZN3TBJM-1013_HILIC-pos-B1.mzML        False   False    True    True    True
# ZNED4XZ-4014_HILIC-pos-B1.mzML        False   False    True    True   False
# ZLZNCLZ-2013_HILIC-pos-B1.mzML        False   False    True    True   False
# ZLZQMEV-07_HILIC-pos-B1.mzML          False   False    True    True   False
# ZN0JE53-02_HILIC-pos-B1.mzML          False    True    True    True    True
# ...                                     ...     ...     ...     ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML   False   False   False    True   False
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML   False   False   False    True   False
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML   False    True   False    True   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML   False   False   False    True   False
# Exercise_HILIC-pos_ZS78KHV-E17.mzML   False   False   False    True   False
#
#                                      FT9985  FT9988  FT9997
# ZN3TBJM-1013_HILIC-pos-B1.mzML         True   False    True
# ZNED4XZ-4014_HILIC-pos-B1.mzML         True   False    True
# ZLZNCLZ-2013_HILIC-pos-B1.mzML        False   False    True
# ZLZQMEV-07_HILIC-pos-B1.mzML           True   False    True
# ZN0JE53-02_HILIC-pos-B1.mzML          False   False    True
# ...                                     ...     ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML    True   False   False
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML    True   False   False
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML    True   False   False
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML    True    True    True
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    True    True    True
#
# [726 rows x 1767 columns]

# %%
previous_nans
# Out:
#                                          FT10031  FT10035  FT10037  FT10039  \
# VT_171028_M314_167.mzML                     True     True     True     True
# VT_170729_M021_175.mzML                     True     True     True     True
# YW_200307_M431_189.mzML                     True     True     True     True
# VT_181116_M338_047.mzML                     True     True     True     True
# VT_170729_M021_179.mzML                     True     True     True     True
# ...                                          ...      ...      ...      ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML    False    False    False    False
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML    False    False    False    False
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML    False    False    False    False
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML    False    False    False    False
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML    False    False    False    False
#
#                                          FT10041  FT10042  FT10044  FT1006  \
# VT_171028_M314_167.mzML                     True     True     True    True
# VT_170729_M021_175.mzML                     True     True     True    True
# YW_200307_M431_189.mzML                     True     True     True    True
# VT_181116_M338_047.mzML                     True     True    False    True
# VT_170729_M021_179.mzML                     True     True     True    True
# ...                                          ...      ...      ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML    False    False    False   False
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML    False    False    False   False
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML    False    False     True   False
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML    False    False     True   False
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML    False    False    False   False
#
#                                          FT10068  FT1007  ...  FT9951  FT9975  \
# VT_171028_M314_167.mzML                     True   False  ...    True    True
# VT_170729_M021_175.mzML                     True   False  ...    True    True
# YW_200307_M431_189.mzML                     True    True  ...    True    True
# VT_181116_M338_047.mzML                     True    True  ...    True    True
# VT_170729_M021_179.mzML                     True   False  ...    True    True
# ...                                          ...     ...  ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML    False   False  ...   False    True
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML    False   False  ...   False    True
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML    False   False  ...   False   False
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML    False   False  ...   False   False
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML    False   False  ...   False   False
#
#                                          FT9978  FT9980  FT9984  FT9985  \
# VT_171028_M314_167.mzML                    True    True    True    True
# VT_170729_M021_175.mzML                    True    True    True    True
# YW_200307_M431_189.mzML                    True    True    True    True
# VT_181116_M338_047.mzML                   False    True    True    True
# VT_170729_M021_179.mzML                    True    True    True    True
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML   False   False   False   False
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML   False   False   False   False
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML   False   False   False   False
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML   False   False   False   False
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML   False   False   False   False
#
#                                          FT9988  FT9989  FT9997  FT9999
# VT_171028_M314_167.mzML                    True    True    True    True
# VT_170729_M021_175.mzML                    True    True    True    True
# YW_200307_M431_189.mzML                    True    True    True    True
# VT_181116_M338_047.mzML                    True    True    True    True
# VT_170729_M021_179.mzML                    True    True    True    True
# ...                                         ...     ...     ...     ...
# 0780a_Marios_PD1_Inhib2_HP-PREFA41.mzML   False   False   False   False
# 0900b_Marios_PD1_Inhib2_HP-PREFB47.mzML   False   False   False   False
# 1200a_Marios_PD1_Inhib2_HP-PREFA62.mzML   False   False   False   False
# 0960b_Marios_PD1_Inhib2_HP-PREFB50.mzML   False   False   False   False
# 0840b_Marios_PD1_Inhib2_HP-PREFB44.mzML   False   False   False   False
#
# [17685 rows x 2736 columns]

# %%
'FT10031' in new_nans.columns
# Out:
# False

# %%
all_nans
# Out:
#                                     FT10031 FT10035 FT10037 FT10039 FT10041  \
# VT_171028_M314_167.mzML                True    True    True    True    True
# VT_170729_M021_175.mzML                True    True    True    True    True
# YW_200307_M431_189.mzML                True    True    True    True    True
# VT_181116_M338_047.mzML                True    True    True    True    True
# VT_170729_M021_179.mzML                True    True    True    True    True
# ...                                     ...     ...     ...     ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML   False     NaN     NaN     NaN   False
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML   False     NaN     NaN     NaN    True
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML   False     NaN     NaN     NaN    True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML   False     NaN     NaN     NaN   False
# Exercise_HILIC-pos_ZS78KHV-E17.mzML   False     NaN     NaN     NaN    True
#
#                                     FT10042 FT10044 FT1006 FT10068 FT1007  \
# VT_171028_M314_167.mzML                True    True   True    True  False
# VT_170729_M021_175.mzML                True    True   True    True  False
# YW_200307_M431_189.mzML                True    True   True    True   True
# VT_181116_M338_047.mzML                True   False   True    True   True
# VT_170729_M021_179.mzML                True    True   True    True  False
# ...                                     ...     ...    ...     ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML     NaN    True  False    True    NaN
#
#                                      ... FT8832 FT8971 FT9101 FT9103 FT9339  \
# VT_171028_M314_167.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_175.mzML              ...    NaN    NaN    NaN    NaN    NaN
# YW_200307_M431_189.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_181116_M338_047.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_179.mzML              ...    NaN    NaN    NaN    NaN    NaN
# ...                                  ...    ...    ...    ...    ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  ...    NaN    NaN    NaN    NaN    NaN
#
#                                     FT9421 FT9449 FT9525 FT9710 FT9730
# VT_171028_M314_167.mzML                NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_175.mzML                NaN    NaN    NaN    NaN    NaN
# YW_200307_M431_189.mzML                NaN    NaN    NaN    NaN    NaN
# VT_181116_M338_047.mzML                NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_179.mzML                NaN    NaN    NaN    NaN    NaN
# ...                                    ...    ...    ...    ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML    NaN    NaN    NaN    NaN    NaN
#
# [22288 rows x 3226 columns]

# %%
new_nans.shape
# Out:
# (726, 1767)

# %%
all_nans
# Out:
#                                     FT10031 FT10035 FT10037 FT10039 FT10041  \
# VT_171028_M314_167.mzML                True    True    True    True    True
# VT_170729_M021_175.mzML                True    True    True    True    True
# YW_200307_M431_189.mzML                True    True    True    True    True
# VT_181116_M338_047.mzML                True    True    True    True    True
# VT_170729_M021_179.mzML                True    True    True    True    True
# ...                                     ...     ...     ...     ...     ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML   False     NaN     NaN     NaN   False
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML   False     NaN     NaN     NaN    True
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML   False     NaN     NaN     NaN    True
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML   False     NaN     NaN     NaN   False
# Exercise_HILIC-pos_ZS78KHV-E17.mzML   False     NaN     NaN     NaN    True
#
#                                     FT10042 FT10044 FT1006 FT10068 FT1007  \
# VT_171028_M314_167.mzML                True    True   True    True  False
# VT_170729_M021_175.mzML                True    True   True    True  False
# YW_200307_M431_189.mzML                True    True   True    True   True
# VT_181116_M338_047.mzML                True   False   True    True   True
# VT_170729_M021_179.mzML                True    True   True    True  False
# ...                                     ...     ...    ...     ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML     NaN    True   True    True    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML     NaN    True  False    True    NaN
#
#                                      ... FT2737 FT2760 FT2763 FT2774 FT2765  \
# VT_171028_M314_167.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_175.mzML              ...    NaN    NaN    NaN    NaN    NaN
# YW_200307_M431_189.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_181116_M338_047.mzML              ...    NaN    NaN    NaN    NaN    NaN
# VT_170729_M021_179.mzML              ...    NaN    NaN    NaN    NaN    NaN
# ...                                  ...    ...    ...    ...    ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML  ...    NaN    NaN    NaN    NaN    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML  ...    NaN    NaN    NaN    NaN    NaN
#
#                                     FT171 FT159 FT2796 FT168 FT2848
# VT_171028_M314_167.mzML               NaN   NaN    NaN   NaN    NaN
# VT_170729_M021_175.mzML               NaN   NaN    NaN   NaN    NaN
# YW_200307_M431_189.mzML               NaN   NaN    NaN   NaN    NaN
# VT_181116_M338_047.mzML               NaN   NaN    NaN   NaN    NaN
# VT_170729_M021_179.mzML               NaN   NaN    NaN   NaN    NaN
# ...                                   ...   ...    ...   ...    ...
# Exercise_HILIC-pos_ZN3TBJM-E17.mzML   NaN   NaN    NaN   NaN    NaN
# Exercise_HILIC-pos_ZPMBHPS-E18.mzML   NaN   NaN    NaN   NaN    NaN
# Exercise_HILIC-pos_ZPEL6L3-E18.mzML   NaN   NaN    NaN   NaN    NaN
# Exercise_HILIC-pos_ZWFDEY0-E18.mzML   NaN   NaN    NaN   NaN    NaN
# Exercise_HILIC-pos_ZS78KHV-E17.mzML   NaN   NaN    NaN   NaN    NaN
#
# [22288 rows x 5560 columns]

# %%
all_nans.to_csv(f'{save_dir}/all_nans.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[474], line 1
# ----> 1 all_nans.to_csv(f'{save_dir}/all_nans.csv')
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/io/formats/format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/io/formats/csvs.py:266, in CSVFormatter.save(self)
#     247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#    (...)
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
# --> 266     self._save()
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/io/formats/csvs.py:271, in CSVFormatter._save(self)
#     269 if self._need_to_save_header:
#     270     self._save_header()
# --> 271 self._save_body()
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/io/formats/csvs.py:309, in CSVFormatter._save_body(self)
#     307 if start_i >= end_i:
#     308     break
# --> 309 self._save_chunk(start_i, end_i)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/io/formats/csvs.py:316, in CSVFormatter._save_chunk(self, start_i, end_i)
#     313 slicer = slice(start_i, end_i)
#     314 df = self.obj.iloc[slicer]
# --> 316 res = df._mgr.to_native_types(**self._number_format)
#     317 data = [res.iget_values(i) for i in range(len(res.items))]
#     319 ix = self.data_index[slicer]._format_native_types(**self._number_format)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/internals/managers.py:438, in BaseBlockManager.to_native_types(self, **kwargs)
#     433 def to_native_types(self, **kwargs) -> Self:
#     434     """
#     435     Convert values to native types (strings / python objects) that are used
#     436     in formatting (repr / csv).
#     437     """
# --> 438     return self.apply("to_native_types", **kwargs)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/internals/blocks.py:636, in Block.to_native_types(self, na_rep, quoting, **kwargs)
#     633 @final
#     634 def to_native_types(self, na_rep: str = "nan", quoting=None, **kwargs) -> Block:
#     635     """convert to our native types format"""
# --> 636     result = to_native_types(self.values, na_rep=na_rep, quoting=quoting, **kwargs)
#     637     return self.make_block(result)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/internals/blocks.py:2570, in to_native_types(values, na_rep, quoting, float_format, decimal, **kwargs)
#    2567     return new_values
#    2569 else:
# -> 2570     mask = isna(values)
#    2571     itemsize = writers.word_len(na_rep)
#    2573     if values.dtype != _dtype_obj and not quoting and itemsize:
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:178, in isna(obj)
#     101 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     102     """
#     103     Detect missing values for an array-like object.
#     104
#    (...)
#     176     Name: 1, dtype: bool
#     177     """
# --> 178     return _isna(obj)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:207, in _isna(obj, inf_as_na)
#     205     return False
#     206 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 207     return _isna_array(obj, inf_as_na=inf_as_na)
#     208 elif isinstance(obj, ABCIndex):
#     209     # Try to use cached isna, which also short-circuits for integer dtypes
#     210     #  and avoids materializing RangeIndex._values
#     211     if not obj._can_hold_na:
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:292, in _isna_array(values, inf_as_na)
#     290     result = _isna_recarray_dtype(values, inf_as_na=inf_as_na)
#     291 elif is_string_or_object_np_dtype(values.dtype):
# --> 292     result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     293 elif dtype.kind in "mM":
#     294     # this is the NaT pattern
#     295     result = values.view("i8") == iNaT
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:313, in _isna_string_dtype(values, inf_as_na)
#     311 else:
#     312     if values.ndim in {1, 2}:
# --> 313         result = libmissing.isnaobj(values, inf_as_na=inf_as_na)
#     314     else:
#     315         # 0-D, reached via e.g. mask_missing
#     316         result = libmissing.isnaobj(values.ravel(), inf_as_na=inf_as_na)
#
# KeyboardInterrupt:

# %%
all_intensity.shape
# Out:
# (22288, 5560)

# %%
previous_metadata['Previous Study ID'] = previous_metadata['Study ID Expanded']
previous_metadata['Previous Job ID'] = previous_metadata['cohort_id']
previous_metadata['Matt Set Label'] = previous_metadata['Matt Set']
previous_metadata['Previous Set'] = previous_metadata['Set']
hilic_pos_metadata = hilic_pos.join(previous_metadata[['Previous Study ID','Previous Job ID','Matt Set Label','Previous Set']],how='outer')
print(hilic_pos_metadata.shape)
# Out:
# (22586, 43)

# %%
study_id_list = hilic_pos['Study ID'].unique()
all_save_dir = '/Users/jonaheaton/ReviveMed Dropbox/Jonah Eaton/mzLearn_preTraining/data_2024_July_08'                                             
                                             
for study_id in study_id_list:
    scaled_int_file = f'{all_save_dir}/{study_id}_scaled_intensity_matrix.csv'
    if os.path.exists(scaled_int_file):
        print('---')
        print(f'{study_id} already exists')
        continue

    print('------')
    print(study_id)
    subset_metadata = hilic_pos[hilic_pos['Study ID'] == study_id].copy()
    print(subset_metadata.shape)
    subset_samples = subset_metadata.index.to_list()
    print('N samples in metadata:', len(subset_samples))
    common_subset_samples = [x for x in subset_samples if x in all_intensity.index]
    print('N samples in common with intensity matrix:', len(common_subset_samples))

    if  len(common_subset_samples) < 0.8 * len(subset_samples):
        print('!!! Not enough samples to use this study !!!')
        break

    subset_metadata.loc[common_subset_samples,:].to_csv(f'{all_save_dir}/{study_id}_metadata.csv')
    subset_intensity = all_intensity.loc[common_subset_samples].copy()
    
    subset_nans = all_nans.loc[common_subset_samples].copy()
    subset_nans.to_csv(f'{all_save_dir}/{study_id}_nans.csv')

    # fill in the missing values with the mean of the feature (this should already be done)
    # subset_intensity.fillna(subset_intensity.mean(), inplace=True)

    if subset_intensity.isna().sum().sum() > 0:
        scaler = StandardScaler()
        subset_intensity_scaled = scaler.fit_transform(subset_intensity)
        subset_intensity_scaled = pd.DataFrame(subset_intensity_scaled, index=subset_intensity.index, columns=subset_intensity.columns)

        subset_intensity_scaled = subset_intensity_scaled.T
        subset_intensity_scaled.fillna(subset_intensity_scaled.mean(), inplace=True)

    else:
        subset_intensity_scaled = subset_intensity.copy()

    subset_intensity_scaled.T.to_csv(f'{all_save_dir}/{study_id}_scaled_intensity_matrix.csv')
# Out:
# ------
# ST000422
# (60, 39)
# N samples in metadata: 60
# N samples in common with intensity matrix: 60
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001932
# (4482, 39)
# N samples in metadata: 4482
# N samples in common with intensity matrix: 4482
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001918
# (273, 39)
# N samples in metadata: 273
# N samples in common with intensity matrix: 271
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001931
# (2044, 39)
# N samples in metadata: 2044
# N samples in common with intensity matrix: 2044
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002027
# (356, 39)
# N samples in metadata: 356
# N samples in common with intensity matrix: 356
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001428
# (1522, 39)
# N samples in metadata: 1522
# N samples in common with intensity matrix: 1522
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002244
# (122, 39)
# N samples in metadata: 122
# N samples in common with intensity matrix: 122
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002251
# (269, 39)
# N samples in metadata: 269
# N samples in common with intensity matrix: 242
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002331
# (1315, 39)
# N samples in metadata: 1315
# N samples in common with intensity matrix: 1315
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001408
# (349, 39)
# N samples in metadata: 349
# N samples in common with intensity matrix: 349
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001423
# (1455, 39)
# N samples in metadata: 1455
# N samples in common with intensity matrix: 1197
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001422
# (2076, 39)
# N samples in metadata: 2076
# N samples in common with intensity matrix: 2075
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002112
# (335, 39)
# N samples in metadata: 335
# N samples in common with intensity matrix: 335
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001237
# (1379, 39)
# N samples in metadata: 1379
# N samples in common with intensity matrix: 1379
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST001236
# (271, 39)
# N samples in metadata: 271
# N samples in common with intensity matrix: 271
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST000909
# (742, 39)
# N samples in metadata: 742
# N samples in common with intensity matrix: 742
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST000601
# (384, 39)
# N samples in metadata: 384
# N samples in common with intensity matrix: 384
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Users/jonaheaton/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ------
# ST002773
# (3455, 39)
# N samples in metadata: 3455
# N samples in common with intensity matrix: 3455
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[456], line 21
#      18 subset_metadata.loc[common_subset_samples,:].to_csv(f'{all_save_dir}/{study_id}_metadata.csv')
#      19 subset_intensity = all_intensity.loc[common_subset_samples].copy()
# ---> 21 subset_nans = all_nans.loc[common_subset_samples].copy()
#      22 subset_nans.to_csv(f'{all_save_dir}/{study_id}_nans.csv')
#      24 # fill in the missing values with the mean of the feature (this should already be done)
#      25 # subset_intensity.fillna(subset_intensity.mean(), inplace=True)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexing.py:1322, in _LocIndexer._getitem_iterable(self, key, axis)
#    1319 self._validate_key(key, axis)
#    1321 # A collection of keys
# -> 1322 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1323 return self.obj._reindex_with_indexers(
#    1324     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1325 )
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/opt/miniconda3/envs/mz_embed_engine/lib/python3.9/site-packages/pandas/core/indexes/base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['F076_200714_M331_001.mzML', 'F076_200714_M331_009.mzML',\n       'F076_200714_M331_017.mzML', 'F076_200714_M331_025.mzML',\n       'F076_200714_M331_033.mzML', 'F076_200714_M331_041.mzML',\n       'F076_200714_M331_049.mzML', 'F076_200714_M331_057.mzML',\n       'F076_200714_M331_065.mzML', 'F076_200714_M331_073.mzML',\n       ...\n       'F076_201011_M331_209.mzML', 'F076_201011_M331_217.mzML',\n       'F076_201011_M331_225.mzML', 'F076_201011_M331_233.mzML',\n       'F076_201011_M331_241.mzML', 'F076_201011_M331_249.mzML',\n       'F076_201011_M331_257.mzML', 'F076_201011_M331_265.mzML',\n       'F076_201011_M331_273.mzML', 'F076_201011_M331_281.mzML'],\n      dtype='object', length=3455)] are in the [index]"

# %%
all_nans.loc[common_subset_samples].copy()
# Out:
#                           FT10031 FT10035 FT10037 FT10039 FT10041 FT10042  \
# F076_200714_M331_001.mzML     NaN     NaN     NaN     NaN   False     NaN
# F076_200714_M331_009.mzML     NaN     NaN     NaN     NaN   False     NaN
# F076_200714_M331_017.mzML     NaN     NaN     NaN     NaN   False     NaN
# F076_200714_M331_025.mzML     NaN     NaN     NaN     NaN   False     NaN
# F076_200714_M331_033.mzML     NaN     NaN     NaN     NaN   False     NaN
# ...                           ...     ...     ...     ...     ...     ...
# F076_201011_M331_249.mzML     NaN     NaN     NaN     NaN    True     NaN
# F076_201011_M331_257.mzML     NaN     NaN     NaN     NaN    True     NaN
# F076_201011_M331_265.mzML     NaN     NaN     NaN     NaN    True     NaN
# F076_201011_M331_273.mzML     NaN     NaN     NaN     NaN    True     NaN
# F076_201011_M331_281.mzML     NaN     NaN     NaN     NaN    True     NaN
#
#                           FT10044 FT1006 FT10068 FT1007  ...  \
# F076_200714_M331_001.mzML     NaN    NaN    True    NaN  ...
# F076_200714_M331_009.mzML     NaN    NaN    True    NaN  ...
# F076_200714_M331_017.mzML     NaN    NaN    True    NaN  ...
# F076_200714_M331_025.mzML     NaN    NaN    True    NaN  ...
# F076_200714_M331_033.mzML     NaN    NaN    True    NaN  ...
# ...                           ...    ...     ...    ...  ...
# F076_201011_M331_249.mzML     NaN    NaN    True    NaN  ...
# F076_201011_M331_257.mzML     NaN    NaN    True    NaN  ...
# F076_201011_M331_265.mzML     NaN    NaN    True    NaN  ...
# F076_201011_M331_273.mzML     NaN    NaN    True    NaN  ...
# F076_201011_M331_281.mzML     NaN    NaN    True    NaN  ...
#
#                           Exercise_HILIC-pos_ZMBVNFM-E17.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZJXC41N-E14.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZRB0F6P-E12.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZTL5S2Y-E14.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZMBVNFM-E11.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZN3TBJM-E17.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZPMBHPS-E18.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZPEL6L3-E18.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZWFDEY0-E18.mzML  \
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
#                           Exercise_HILIC-pos_ZS78KHV-E17.mzML
# F076_200714_M331_001.mzML                                 NaN
# F076_200714_M331_009.mzML                                 NaN
# F076_200714_M331_017.mzML                                 NaN
# F076_200714_M331_025.mzML                                 NaN
# F076_200714_M331_033.mzML                                 NaN
# ...                                                       ...
# F076_201011_M331_249.mzML                                 NaN
# F076_201011_M331_257.mzML                                 NaN
# F076_201011_M331_265.mzML                                 NaN
# F076_201011_M331_273.mzML                                 NaN
# F076_201011_M331_281.mzML                                 NaN
#
# [3455 rows x 6286 columns]
